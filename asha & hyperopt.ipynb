# %% [markdown]
# <a href="https://colab.research.google.com/github/mAbbaspour/Hyperparameter-Optimization/blob/main/asha%20%26%20hyperopt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as f
import numpy as np
import math;

# %%
from google.colab import files
uploaded = files.upload()
uploaded2 = files.upload()
# Out:
#      <input type="file" id="files-161c01fc-0786-40b6-9783-1964c01e0d68" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-161c01fc-0786-40b6-9783-1964c01e0d68">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lipo(Lables).csv to lipo(Lables) (1).csv
#      <input type="file" id="files-6c51ad64-e1ce-468a-b2e7-9d3546a3eaf6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6c51ad64-e1ce-468a-b2e7-9d3546a3eaf6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lipo_global_cdf_rdkit.csv to lipo_global_cdf_rdkit (1).csv

# %%
import random
random.seed(1)
import pandas as pd
import io
from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv(io.BytesIO(uploaded2['lipo_global_cdf_rdkit.csv']))
dataY = pd.read_csv(io.BytesIO(uploaded['lipo(Lables).csv']))
print(data[data.isnull().any(axis=1)])
# Out:
#       ('RDKit2DNormalized_calculated', <class 'bool'>)  \
# 1561                                              True
#
#       ('BalabanJ', <class 'numpy.float64'>)  \
# 1561                                  0.895
#
#       ('BertzCT', <class 'numpy.float64'>)  ('Chi0', <class 'numpy.float64'>)  \
# 1561                              0.230752                           0.031331
#
#       ('Chi0n', <class 'numpy.float64'>)  ('Chi0v', <class 'numpy.float64'>)  \
# 1561                            0.032387                            0.061726
#
#       ('Chi1', <class 'numpy.float64'>)  ('Chi1n', <class 'numpy.float64'>)  \
# 1561                           0.050799                            0.045963
#
#       ('Chi1v', <class 'numpy.float64'>)  ('Chi2n', <class 'numpy.float64'>)  \
# 1561                            0.116251                             0.04344
#
#       ...  ('fr_sulfonamd', <class 'numpy.float64'>)  \
# 1561  ...                               1.593061e-17
#
#       ('fr_sulfone', <class 'numpy.float64'>)  \
# 1561                             5.766101e-14
#
#       ('fr_term_acetylene', <class 'numpy.float64'>)  \
# 1561                                    2.957989e-11
#
#       ('fr_tetrazole', <class 'numpy.float64'>)  \
# 1561                                   0.168378
#
#       ('fr_thiazole', <class 'numpy.float64'>)  \
# 1561                                   0.16738
#
#       ('fr_thiocyan', <class 'numpy.float64'>)  \
# 1561                              1.481515e-18
#
#       ('fr_thiophene', <class 'numpy.float64'>)  \
# 1561                               2.324150e-16
#
#       ('fr_unbrch_alkane', <class 'numpy.float64'>)  \
# 1561                                   4.703598e-08
#
#       ('fr_urea', <class 'numpy.float64'>)  ('qed', <class 'numpy.float64'>)
# 1561                              0.166633                          0.542261
#
# [1 rows x 201 columns]

# %%
data = data.drop(1561)
dataY = dataY.drop(1561)

# %%
arrayY = dataY.values
Y = arrayY[0: ,1 ]
array = data.values
X = array[0:,1:]

# %%
X_train, X_test ,Y_train , Y_test  = train_test_split(X, Y ,test_size=0.2)
scaler_data  = preprocessing.MinMaxScaler()
X_train = scaler_data.fit_transform(X_train)
X_test =  scaler_data.transform(X_test)
scaler_labels = preprocessing.MinMaxScaler()
Y_train = scaler_labels.fit_transform(Y_train.reshape(-1, 1))
Y_test = scaler_labels.transform(Y_test.reshape(-1, 1))

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
pca = PCA(n_components=200)
pca.fit(X_train)
print(pca.explained_variance_ratio_)
plt.plot(np.arange(200),pca.explained_variance_ratio_)
plt.show()
# Out:
# [1.90978332e-01 7.19312865e-02 6.12864556e-02 5.22881431e-02
#  4.61447518e-02 4.18837268e-02 3.37998044e-02 3.14491105e-02
#  2.66364545e-02 2.53106478e-02 2.14476206e-02 2.07745096e-02
#  1.78159663e-02 1.69296395e-02 1.58751201e-02 1.49917621e-02
#  1.42238686e-02 1.36138370e-02 1.31531835e-02 1.19225970e-02
#  1.42438236e-08 2.33313748e-23 1.00963905e-30 3.76638349e-32
#  1.08088612e-33 1.08088612e-33 1.08088612e-33 1.08088612e-33
#  1.08088612e-33 1.08088612e-33 1.08088612e-33 1.08088612e-33
#  1.08088612e-33 1.08088612e-33 1.08088612e-33 1.08088612e-33
#  1.08088612e-33 1.08088612e-33 1.08088612e-33 1.08088612e-33
#  1.08088612e-33 1.08088612e-33 1.08088612e-33 1.08088612e-33]

# %%
pca = PCA(n_components=75)
pca.fit(X_train)
X_train=pca.transform(X_train)



X_test = pca.transform(X_test)

# %%
print(X_test.shape)
print(Y_test.shape)
print(X_train.shape)
print(Y_train.shape)
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
# Out:
# (840, 75)
# (840, 1)
# (3359, 75)
# (3359, 1)

# %%
Y_train_new =  Y_train.astype(np.float)
Y_test_new = Y_test.astype(np.float)
print(Y_train_new.shape)
print(Y_test_new.shape)
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
tensor_x_train = torch.tensor(X_train, dtype=torch.float).to(device) 
tensor_x_test = torch.tensor(X_test, dtype=torch.float).to(device) 

tensor_y_train = torch.tensor(Y_train_new , dtype=torch.float).to(device)
tensor_y_test= torch.tensor(Y_test_new, dtype=torch.float).to(device)
# Out:
# (3359, 1)
# (840, 1)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
from torch.utils.data import TensorDataset
trainset = TensorDataset(tensor_x_train, tensor_y_train) 
testset = TensorDataset(tensor_x_test,tensor_y_test)

# %%
# %%capture
try:
    import ray
except:
    # !pip install -U ray
    import ray

# %%
from functools import partial
import numpy as np
import os
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import random_split
from torchsummary import summary

from ray import tune
# a = {"a":tune.quniform(50, 200, 10) , "b": 5}
# print(type(a.get("a")))
from ray.tune import CLIReporter
from ray.tune.schedulers import ASHAScheduler

# %%
def load_data(data_dir=None):
    return trainset, testset

# %%
# # Net().__init__(self , confing) 
#     config = {
#         "act1 ": tune.choice(["relu","tanh","selu"]),
#         "act2" : tune.choice(["relu","tanh","selu"]),
#         "act3" : tune.choice(["relu","tanh","selu"]),
#         "lr": tune.quniform(0.0005, 0.001, 0.0001),
#         "batch_size": tune.choice([8, 16, 32]),
#         "hidden_dim1" : tune.quniform(50, 200, 10),
#         "hidden_dim2" : tune.quniform(50, 200, 10),
#         "hidden_dim3" : tune.quniform(50, 200, 10),
#     }
#   self = { "confing": confing , "hd":}
class Net(nn.Module):
    def __init__(self, config):
        super().__init__()

        self.config = config
        self.hidden_dim1 = int(self.config.get("hidden_dim1", 100))
        self.hidden_dim2 = int(self.config.get("hidden_dim2", 100))
        self.hidden_dim3 = int(self.config.get("hidden_dim3", 100))

        self.act1 = self.config.get("act1", "relu") 
        self.act2 = self.config.get("act2", "relu") 
        self.act3 = self.config.get("act3", "relu")

        self.linear1 = nn.Linear(75, self.hidden_dim1)
        self.linear2 = nn.Linear(self.hidden_dim1, self.hidden_dim2)
        self.linear3 = nn.Linear(self.hidden_dim2, self.hidden_dim3)
        self.linear4 = nn.Linear(self.hidden_dim3, 1)
    
    @staticmethod
    def activation_func(act_str):
        if act_str=="tanh":
            return eval("torch."+act_str)
        elif act_str=="selu" or act_str=="relu":   
            return eval("torch.nn.functional."+act_str)

    def forward(self, x):
        output = self.linear1(x)
        output = self.activation_func(self.act1)(output)
        output = self.linear2(output)
        output = self.activation_func(self.act2)(output)
        output = self.linear3(output)
        output = self.activation_func(self.act3)(output)
        output = self.linear4(output)        
        return output

# %%
model = Net({})

# %%
from prettytable import PrettyTable

def count_parameters(model):
    table = PrettyTable(["Modules", "Parameters"])
    total_params = 0
    for name, parameter in model.named_parameters():
        if not parameter.requires_grad: continue
        param = parameter.numel()
        table.add_row([name, param])
        total_params+=param
    print(table)
    print(f"Total Trainable Params: {total_params}")
    return total_params

# %%
summary(model, (1,tensor_x_train.shape[1]))

count_parameters(model)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1               [-1, 1, 100]           7,600
#             Linear-2               [-1, 1, 100]          10,100
#             Linear-3               [-1, 1, 100]          10,100
#             Linear-4                 [-1, 1, 1]             101
# ================================================================
# Total params: 27,901
# Trainable params: 27,901
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.11
# Estimated Total Size (MB): 0.11
# ----------------------------------------------------------------
# +----------------+------------+
# |    Modules     | Parameters |
# +----------------+------------+
# | linear1.weight |    7500    |
# |  linear1.bias  |    100     |
# | linear2.weight |   10000    |
# |  linear2.bias  |    100     |
# | linear3.weight |   10000    |
# |  linear3.bias  |    100     |
# | linear4.weight |    100     |
# |  linear4.bias  |     1      |
# +----------------+------------+
# Total Trainable Params: 27901
# 27901

# %%
def trainable_func(config, checkpoint_dir=None, data_dir=None, epochs=10):

    net = Net(config)

    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda:0"
        if torch.cuda.device_count() > 1:
            net = nn.DataParallel(net)
    net.to(device)

    '''
    Define a loss function
    '''
    ## Classification
    # criterion = nn.CrossEntropyLoss()

    ## Regression
    criterion = nn.MSELoss(reduction='sum')

    # Define an optimizer 
    optimizer = optim.Adam(net.parameters(), lr=config.get("lr",0.0003))

    if checkpoint_dir:
        model_state, optimizer_state = torch.load(
            os.path.join(checkpoint_dir, "checkpoint"))
        net.load_state_dict(model_state)
        optimizer.load_state_dict(optimizer_state)

    # Load data
    trainset, testset = load_data(data_dir)

    # Split the dataset into training and validation sets
    train_size = int(len(trainset) * 0.8)
    train_subset, val_subset = random_split(trainset, [train_size, len(trainset) - train_size])

    # Define data loaders (which combines a dataset and a sampler, and provides an iterable over the given dataset)
    trainloader = torch.utils.data.DataLoader(
        train_subset,
        batch_size=int(config.get("batch_size",32)),
        shuffle=True,
        num_workers=2)
    valloader = torch.utils.data.DataLoader(
        val_subset,
        batch_size=int(config.get("batch_size",32)),
        shuffle=True,
        num_workers=2)

    for epoch in range(epochs):  # loop over the dataset multiple times
        epoch_train_loss = 0.0
        # epoch_steps = 0
        net.train() # Prepare model for training
        for i, data in enumerate(trainloader):
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            '''
            Compute train loss without scaling to print
            ''' 
            # outputs = torch.tensor(scaler_labels.inverse_transform(outputs.detach().cpu())).to(device)    
            # labels = torch.tensor(scaler_labels.inverse_transform(labels.cpu())).to(device)  
            # loss_train = criterion(outputs, labels) 
            # epoch_train_loss += loss_train.detach().item()
        # print("[%d] loss: %.3f" % (epoch + 1, epoch_train_loss / len(train_subset)))

        # Validation loss
        val_loss = 0.0
        net.eval() # Prepare model for evaluation
        for i, data in enumerate(valloader):
            with torch.no_grad():
                inputs, labels = data
                inputs, labels = inputs.to(device), labels.to(device)

                outputs = net(inputs)

                # Inverse transform of the labels' scaler
                outputs = torch.tensor(scaler_labels.inverse_transform(outputs.detach().cpu())).to(device)    
                labels = torch.tensor(scaler_labels.inverse_transform(labels.cpu())).to(device) 

                loss = criterion(outputs, labels)
                val_loss += loss.cpu().numpy()

        with tune.checkpoint_dir(epoch) as checkpoint_dir:
            path = os.path.join(checkpoint_dir, "checkpoint")
            torch.save((net.state_dict(), optimizer.state_dict()), path)

        tune.report(epoch = epoch, loss=(val_loss / len(val_subset)))
    print("Finished Training")

# %%
def test_score(config, net, device="cpu"):
    trainset, testset = load_data()

    testloader = torch.utils.data.DataLoader(
        testset, batch_size=int(config.get("batch_size",32)), shuffle=False, num_workers=2)
    
    ## Regression
    criterion = nn.MSELoss(reduction='sum')

    # Test loss
    test_loss = 0.0
    net.eval() # Prepare model for evaluation
    for i, data in enumerate(testloader):
        with torch.no_grad():
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = net(inputs)

            # Inverse transform of the labels' scaler
            outputs = torch.tensor(scaler_labels.inverse_transform(outputs.detach().cpu())).to(device)    
            labels = torch.tensor(scaler_labels.inverse_transform(labels.cpu())).to(device) 

            loss = criterion(outputs, labels)
            test_loss += loss.cpu().numpy()

    return test_loss / len(testset)

# %%
ray.shutdown()
ray.init() # Here we use ray.init() to evaluate available_resources for Ray
print(ray.available_resources())
ray.shutdown()  # Restart Ray defensively in case the ray connection is lost. 

# Start Ray runtime with specific resources (not nessesarily all resources)
# You can change this values based on your machine resources)
ray.init(num_cpus=2, num_gpus=0) 

"""Check Ray Tune is working properly (for trainable class)"""
# from ray.tune.utils import validate_save_restore
# validate_save_restore(Trainable)
# validate_save_restore(Trainable, use_object_store=True)
# print("Success!")
""""""
# Out:
# {'CPU': 2.0, 'object_store_memory': 4009970073.0, 'memory': 8019940148.0, 'node:172.28.0.2': 1.0}
# ''

# %%
# %%capture

# %pip install hpbandster ConfigSpace
# !pip install hpbandster ConfigSpace
# !pip install bayesian-optimization

# %%
ray.shutdown()
from ray.tune.schedulers import AsyncHyperBandScheduler
from ray.tune.suggest.hyperopt import HyperOptSearch
from ray.tune.suggest.bayesopt import BayesOptSearch
from ray.tune.suggest.hyperopt import HyperOptSearch
from ray.tune.schedulers import PopulationBasedTraining
ray.shutdown()
from ray.tune.schedulers import AsyncHyperBandScheduler
from ray.tune.suggest.hyperopt import HyperOptSearch
from ray.tune.suggest.bayesopt import BayesOptSearch
from ray.tune.suggest.hyperopt import HyperOptSearch
from ray.tune.schedulers import PopulationBasedTraining
def main(num_samples=10, max_num_epochs=10, gpus_per_trial=2):

    # define data directory here if you want to load data from files
    data_dir = os.path.abspath("./data")
    load_data(data_dir)

    # define the search space of hyperparameters
    config = {
        "act1 ": tune.choice(["relu","tanh","selu"]),
        "act2" : tune.choice(["relu","tanh","selu"]),
        "act3" : tune.choice(["relu","tanh","selu"]),
        "lr": tune.quniform(0.0005, 0.001, 0.0001),
        "batch_size": tune.choice([ 8,16, 32 , 64]),
        "hidden_dim1" : tune.quniform(120, 330, 15),
        "hidden_dim2" : tune.quniform(120, 330, 15),
        "hidden_dim3" : tune.quniform(120, 330, 15),
    }

    # Optuna search algorithm
    from ray.tune.suggest.optuna import OptunaSearch 
    from ray.tune.suggest import ConcurrencyLimiter
    search_alg = HyperOptSearch(
    # space=config,
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    n_initial_points=60,
    # gamma = 0.1,
    # random_state_seed=42,
    # points_to_evaluate=[{"max_norm_val": 2.5, 'GNN_Layers': 3, 'dropout': 0.25, 'dropout1': 0.35, 'dropout2': 0.15, 'lr': 0.001, 'hidden_size': 80, 'readout1_out': 150, 'readout2_out': 100, 'batch_size': 64}],
    )
    search_alg = ConcurrencyLimiter(search_alg, max_concurrent=10)

    scheduler = ASHAScheduler(
        metric ="loss",
        mode="min",
        max_t=max_num_epochs,
        reduction_factor=2, 
        grace_period=4,
        brackets=5
        )
    
    reporter = CLIReporter(
        # parameter_columns=["l1", "l2", "lr", "batch_size"],
        metric_columns=["loss", "training_iteration"]
        )
    
    # wrap data loading and training for tuning using `partial` 
    # (note that there exist other methods for this purpose)
    result = tune.run(
        partial(trainable_func, data_dir=data_dir, epochs=max_num_epochs),
        scheduler=scheduler,
        search_alg=search_alg,
        num_samples=num_samples,
        config=config,
        verbose=2,
        checkpoint_score_attr="loss",
        checkpoint_freq=0,
        keep_checkpoints_num=1,
        # checkpoint_at_end=True,
        # reuse_actors=reuse_actors_status,
        progress_reporter=reporter,
        resources_per_trial={"cpu": 0.5, "gpu": gpus_per_trial},
        stop={"training_iteration": max_num_epochs},                
        )

    best_trial = result.get_best_trial("loss", "min", "last")
    print("Best trial config: {}".format(best_trial.config))
    print("Best trial final validation score: {}".format(
        best_trial.last_result["loss"]))

    best_trained_model = Net(best_trial.config)
    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda:0"
        if gpus_per_trial > 1:
            best_trained_model = nn.DataParallel(best_trained_model)
    best_trained_model.to(device)

    best_checkpoint_dir = best_trial.checkpoint.value
    model_state, optimizer_state = torch.load(os.path.join(
        best_checkpoint_dir, "checkpoint"))
    best_trained_model.load_state_dict(model_state)

    test_score_value = test_score(best_trial.config, best_trained_model, device)
    print("Best trial test set score: {}".format(test_score_value))


if __name__ == "__main__":
    # You can change the number of GPUs per trial here:
    main(num_samples=50, max_num_epochs=50, gpus_per_trial=0)
# Out:
# 2022-07-26 13:50:37,887	INFO tune.py:874 -- Initializing Ray automatically.For cluster usage or custom Ray initialization, call `ray.init(...)` before `tune.run`.
# 2022-07-26 13:50:43,294	WARNING callback.py:106 -- The TensorboardX logger cannot be instantiated because either TensorboardX or one of it's dependencies is not installed. Please make sure you have the latest version of TensorboardX installed: `pip install -U tensorboardx`
# == Status ==
# Current time: 2022-07-26 13:50:43 (running for 00:00:00.35)
# Memory usage on this node: 1.4/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 0.5/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_13-50-43
# Number of trials: 1/50 (1 RUNNING)
#
#
# == Status ==
# Current time: 2022-07-26 13:50:49 (running for 00:00:05.73)
# Memory usage on this node: 1.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_13-50-43
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
#
#
# == Status ==
# Current time: 2022-07-26 13:50:54 (running for 00:00:10.74)
# Memory usage on this node: 1.9/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_13-50-43
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
#
#
# Trial trainable_func_f17a5478 reported epoch=0,loss=0.7487953742083273,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0009000000000000001, 'batch_size': 32, 'hidden_dim1': 165.0, 'hidden_dim2': 255.0, 'hidden_dim3': 165.0}.
# == Status ==
# Current time: 2022-07-26 13:51:00 (running for 00:00:16.92)
# Memory usage on this node: 2.2/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_13-50-43
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
#
#
# Trial trainable_func_f144b610 reported epoch=0,loss=0.8952001086531435,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0008, 'batch_size': 8, 'hidden_dim1': 285.0, 'hidden_dim2': 255.0, 'hidden_dim3': 225.0}.
# Trial trainable_func_f17a5478 reported epoch=3,loss=0.5846942369138501,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0009000000000000001, 'batch_size': 32, 'hidden_dim1': 165.0, 'hidden_dim2': 255.0, 'hidden_dim3': 165.0}.
# Trial trainable_func_f188ac4e reported epoch=0,loss=0.815733659242201,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 64, 'hidden_dim1': 330.0, 'hidden_dim2': 300.0, 'hidden_dim3': 180.0}.
# == Status ==
# Current time: 2022-07-26 13:51:05 (running for 00:00:22.30)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: -0.5846942369138501
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_13-50-43
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
#
#
# Trial trainable_func_f198f554 reported epoch=0,loss=0.6939176007769899,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 32, 'hidden_dim1': 315.0, 'hidden_dim2': 285.0, 'hidden_dim3': 210.0}.
# Trial trainable_func_f17a5478 reported epoch=5,loss=0.5613844056716315,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0009000000000000001, 'batch_size': 32, 'hidden_dim1': 165.0, 'hidden_dim2': 255.0, 'hidden_dim3': 165.0}.
# Trial trainable_func_f188ac4e reported epoch=3,loss=0.5582619649732634,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 64, 'hidden_dim1': 330.0, 'hidden_dim2': 300.0, 'hidden_dim3': 180.0}.
# == Status ==
# Current time: 2022-07-26 13:51:11 (running for 00:00:28.66)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: -0.5714781009435568
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_13-50-43
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
#
#
# Trial trainable_func_f198f554 reported epoch=2,loss=0.5623168271866977,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 32, 'hidden_dim1': 315.0, 'hidden_dim2': 285.0, 'hidden_dim3': 210.0}.
# Trial trainable_func_f144b610 reported epoch=1,loss=0.6061466147712876,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0008, 'batch_size': 8, 'hidden_dim1': 285.0, 'hidden_dim2': 255.0, 'hidden_dim3': 225.0}.
# Trial trainable_func_f17a5478 reported epoch=7,loss=0.5608096088483373,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0009000000000000001, 'batch_size': 32, 'hidden_dim1': 165.0, 'hidden_dim2': 255.0, 'hidden_dim3': 165.0}.
# Trial trainable_func_f188ac4e reported epoch=6,loss=0.5385282820613325,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 64, 'hidden_dim1': 330.0, 'hidden_dim2': 300.0, 'hidden_dim3': 180.0}.
# == Status ==
# Current time: 2022-07-26 13:51:18 (running for 00:00:34.72)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: -0.5608096088483373 | Iter 4.000: -0.5616998662485163
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_13-50-43
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
#
#
# Trial trainable_func_f198f554 reported epoch=4,loss=0.7005773140265539,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 32, 'hidden_dim1': 315.0, 'hidden_dim2': 285.0, 'hidden_dim3': 210.0}.
# Trial trainable_func_f17a5478 reported epoch=9,loss=0.5698252684224754,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0009000000000000001, 'batch_size': 32, 'hidden_dim1': 165.0, 'hidden_dim2': 255.0, 'hidden_dim3': 165.0}.
# == Status ==
# Current time: 2022-07-26 13:51:23 (running for 00:00:40.10)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: -0.5571101635210147 | Iter 4.000: -0.5616998662485163
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_13-50-43
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
#
#
# Trial trainable_func_f144b610 reported epoch=2,loss=0.5620578615974452,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0008, 'batch_size': 8, 'hidden_dim1': 285.0, 'hidden_dim2': 255.0, 'hidden_dim3': 225.0}.
# Trial trainable_func_f188ac4e reported epoch=9,loss=0.6042118310820371,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 64, 'hidden_dim1': 330.0, 'hidden_dim2': 300.0, 'hidden_dim3': 180.0}.
# Trial trainable_func
should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 300.0, 'hidden_dim2': 315.0, 'hidden_dim3': 330.0}.
# Trial trainable_func_f144b610 reported epoch=17,loss=0.5086661663394559,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0008, 'batch_size': 8, 'hidden_dim1': 285.0, 'hidden_dim2': 255.0, 'hidden_dim3': 225.0}.
# == Status ==
# Current time: 2022-07-26 13:53:14 (running for 00:02:31.09)
# Memory usage on this node: 2.5/12.7 GiB
# Using AsyncHyperBand: num_stopped=1
# Bracket: Iter 32.000: -0.564483713616412 | Iter 16.000: -0.5459232976715203 | Iter 8.000: -0.5551199889248526 | Iter 4.000: -0.5599809156108899
# Bracket: Iter 32.000: None | Iter 16.000: -0.5531975790098947 | Iter 8.000: -0.5825234950092666
# Bracket: Iter 32.000: None | Iter 16.000: -0.5100714277879111
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_13-50-43
# Number of trials: 8/50 (1 PENDING, 4 RUNNING, 3 TERMINATED)
#
#
# Trial trainable_func_38a7f85a reported epoch=0,loss=0.6983647940472993,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 255.0, 'hidden_dim3': 165.0}.
# Trial trainable_func_f1a77a0c reported epoch=21,loss=0.48351724244862576,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 300.0, 'hidden_dim2': 315.0, 'hidden_dim3': 330.0}.
# Trial trainable_func_10e06e6a reported epoch=29,loss=0.5494122381279072,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0005, 'batch_size': 64, 'hidden_dim1': 180.0, 'hidden_dim2': 195.0, 'hidden_dim3': 210.0}.
# == Status ==
# Current time: 2022-07-26 13:53:20 (running for 00:02:36.94)
# Memory usage on this node: 2.4/12.7 GiB
# Using AsyncHyperBand: num_stopped=1
# Bracket: Iter 32.000: -0.564483713616412 | Iter 16.000: -0.5459232976715203 | Iter 8.000: -0.5551199889248526 | Iter 4.000: -0.5599809156108899
# Bracket: Iter 32.000: None | Iter 16.000: -0.5531975790098947 | Iter 8.000: -0.5825234950092666
# Bracket: Iter 32.000: None | Iter 16.000: -0.5100714277879111
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_13-50-43
# Number of trials: 8/50 (1 PENDING, 4 RUNNING, 3 TERMINATED)
#
#
# Trial trainable_func_38a7f85a reported epoch=3,loss=0.5647903797402588,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 255.0, 'hidden_dim3': 165.0}. This trial completed.
# Trial trainable_func_f144b610 reported epoch=18,loss=0.49700582206425215,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0008, 'batch_size': 8, 'hidden_dim1': 285.0, 'hidden_dim2': 255.0, 'hidden_dim3': 225.0}.
# Trial trainable_func_49d23d8e reported epoch=0,loss=0.8370817000864447,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 315.0, 'hidden_dim2': 195.0, 'hidden_dim3': 180.0}.
# Trial trainable_func_10e06e6a reported epoch=34,loss=0.5903535258453796,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0005, 'batch_size': 64, 'hidden_dim1': 180.0, 'hidden_dim2': 195.0, 'hidden_dim3': 210.0}.
# == Status ==
# Current time: 2022-07-26 13:53:26 (running for 00:02:43.10)
# Memory usage on this node: 2.4/12.7 GiB
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 32.000: -0.564483713616412 | Iter 16.000: -0.5459232976715203 | Iter 8.000: -0.5551199889248526 | Iter 4.000: -0.5616998662485163
# Bracket: Iter 32.000: -0.5682975555929192 | Iter 16.000: -0.5531975790098947 | Iter 8.000: -0.5825234950092666
# Bracket: Iter 32.000: None | Iter 16.000: -0.5100714277879111
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_13-50-43
# Number of trials: 9/50 (1 PENDING, 4 RUNNING, 4 TERMINATED)
#
#
# Trial trainable_func_f1a77a0c reported epoch=23,loss=0.4538083045511695,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 300.0, 'hidden_dim2': 315.0, 'hidden_dim3': 330.0}.
# Trial trainable_func_f144b610 reported epoch=19,loss=0.49149829427141256,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0008, 'batch_size': 8, 'hidden_dim1': 285.0, 'hidden_dim2': 255.0, 'hidden_dim3': 225.0}.
# Trial trainable_func_49d23d8e reported epoch=3,loss=0.7041657575295047,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 315.0, 'hidden_dim2': 195.0, 'hidden_dim3': 180.0}.
# Trial trainable_func_10e06e6a reported epoch=38,loss=0.5695398589550882,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0005, 'batch_size': 64, 'hidden_dim1': 180.0, 'hidden_dim2': 195.0, 'hidden_dim3': 210.0}.
# == Status ==
# Current time: 2022-07-26 13:53:31 (running for 00:02:48.13)
# Memory usage on this node: 2.4/12.7 GiB
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 32.000: -0.564483713616412 | Iter 16.000: -0.5459232976715203 | Iter 8.000: -0.5551199889248526 | Iter 4.000: -0.5616998662485163
# Bracket: Iter 32.000: -0.5682975555929192 | Iter 16.000: -0.5531975790098947 | Iter 8.000: -0.5825234950092666
# Bracket: Iter 32.000: None | Iter 16.000: -0.5100714277879111
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_13-50-43
# Number of trials: 9/50 (1 PENDING, 4 RUNNING, 4 TERMINATED)
#
#
# Trial trainable_func_49d23d8e reported epoch=6,loss=0.6055191561533364,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 315.0, 'hidden_dim2': 195.0, 'hidden_dim3': 180.0}.
# Trial trainable_func_f144b610 reported epoch=20,loss=0.5152127653882699,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0008, 'batch_size': 8, 'hidden_dim1': 285.0, 'hidden_dim2': 255.0, 'hidden_dim3': 225.0}.
# Trial trainable_func_10e06e6a reported epoch=43,loss=0.5745279406332239,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0005, 'batch_size': 64, 'hidden_dim1': 180.0, 'hidden_dim2': 195.0, 'hidden_dim3': 210.0}.
# == Status ==
# Current time: 2022-07-26 13:53:36 (running for 00:02:53.13)
# Memory usage on this node: 2.4/12.7 GiB
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 32.000: -0.564483713616412 | Iter 16.000: -0.5459232976715203 | Iter 8.000: -0.5551199889248526 | Iter 4.000: -0.5616998662485163
# Bracket: Iter 32.000: -0.5682975555929192 | Iter 16.000: -0.5531975790098947 | Iter 8.000: -0.5825234950092666
# Bracket: Iter 32.000: None | Iter 16.000: -0.5100714277879111
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_13-50-43
# Number of trials: 9/50 (1 PENDING, 4 RUNNING, 4 TERMINATED)
#
#
# Trial trainable_func_49d23d8e reported epoch=7,loss=0.6160795749379508,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 315.0, 'hidden_dim2': 195.0, 'hidden_dim3': 180.0}. This trial completed.
# Trial trainable_func_f1a77a0c reported epoch=25,loss=0.48634241341542567,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 300.0, 'hidden_dim2': 315.0, 'hidden_dim3': 330.0}.
# Trial trainable_func_4f40ae7c reported epoch=0,loss=1.0295623269140852,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'relu', 'act3': 'relu', 'lr': 0.0007, 'batch_size': 64, 'hidden_dim1': 255.0, 'hidden_dim2': 255.0, 'hidden_dim3': 195.0}.
# == Status ==
# Current time: 2022-07-26 13:53:41 (running for 00:02:58.56)
# Memory usage on this node: 2.4/12.7 GiB
# Using AsyncHyperBand: num_stopped=3
# Bracket: Iter 32.000: -0.564483713616412 | Iter 16.000: -0.5459232976715203 | Iter 8.000: -0.5551199889248526 | Iter 4.000: -0.5616998662485163
# Bracket: Iter 32.000: -0.5682975555929192 | Iter 16.000: -0.5531975790098947 | Iter 8.000: -0.5993015349736087
# Bracket: Iter 32.000: None | Iter 16.000: -0.5100714277879111
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_13-50-43
# Number of trials: 10/50 (1 PENDING, 4 RUNNING, 5 TERMINATED)
#
#
# ...
# Bracket: Iter 32.000: -0.6253372834500096
# Bracket:
# Resources requested: 0.5/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_13-50-43
# Number of trials: 50/50 (1 RUNNING, 49 TERMINATED)
#
#
# Trial trainable_func_a8609160 reported epoch=40,loss=0.49246545147147486,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0009000000000000001, 'batch_size': 8, 'hidden_dim1': 150.0, 'hidden_dim2': 330.0, 'hidden_dim3': 285.0}.
# == Status ==
# Current time: 2022-07-26 14:05:51 (running for 00:15:08.56)
# Memory usage on this node: 1.8/12.7 GiB
# Using AsyncHyperBand: num_stopped=33
# Bracket: Iter 32.000: -0.5093873920647516 | Iter 16.000: -0.5241145296043471 | Iter 8.000: -0.516476052315436 | Iter 4.000: -0.5755792124743211
# Bracket: Iter 32.000: -0.5345410936162631 | Iter 16.000: -0.5286231415411561 | Iter 8.000: -0.5702727240783383
# Bracket: Iter 32.000: -0.5073583902450699 | Iter 16.000: -0.5100714277879111
# Bracket: Iter 32.000: -0.6253372834500096
# Bracket:
# Resources requested: 0.5/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_13-50-43
# Number of trials: 50/50 (1 RUNNING, 49 TERMINATED)
#
#
# Trial trainable_func_a8609160 reported epoch=43,loss=0.49818106190105804,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0009000000000000001, 'batch_size': 8, 'hidden_dim1': 150.0, 'hidden_dim2': 330.0, 'hidden_dim3': 285.0}.
# == Status ==
# Current time: 2022-07-26 14:05:58 (running for 00:15:15.37)
# Memory usage on this node: 1.8/12.7 GiB
# Using AsyncHyperBand: num_stopped=33
# Bracket: Iter 32.000: -0.5093873920647516 | Iter 16.000: -0.5241145296043471 | Iter 8.000: -0.516476052315436 | Iter 4.000: -0.5755792124743211
# Bracket: Iter 32.000: -0.5345410936162631 | Iter 16.000: -0.5286231415411561 | Iter 8.000: -0.5702727240783383
# Bracket: Iter 32.000: -0.5073583902450699 | Iter 16.000: -0.5100714277879111
# Bracket: Iter 32.000: -0.6253372834500096
# Bracket:
# Resources requested: 0.5/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_13-50-43
# Number of trials: 50/50 (1 RUNNING, 49 TERMINATED)
#
#
# Trial trainable_func_a8609160 reported epoch=46,loss=0.5079979421478171,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0009000000000000001, 'batch_size': 8, 'hidden_dim1': 150.0, 'hidden_dim2': 330.0, 'hidden_dim3': 285.0}.
# == Status ==
# Current time: 2022-07-26 14:06:05 (running for 00:15:22.15)
# Memory usage on this node: 1.8/12.7 GiB
# Using AsyncHyperBand: num_stopped=33
# Bracket: Iter 32.000: -0.5093873920647516 | Iter 16.000: -0.5241145296043471 | Iter 8.000: -0.516476052315436 | Iter 4.000: -0.5755792124743211
# Bracket: Iter 32.000: -0.5345410936162631 | Iter 16.000: -0.5286231415411561 | Iter 8.000: -0.5702727240783383
# Bracket: Iter 32.000: -0.5073583902450699 | Iter 16.000: -0.5100714277879111
# Bracket: Iter 32.000: -0.6253372834500096
# Bracket:
# Resources requested: 0.5/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_13-50-43
# Number of trials: 50/50 (1 RUNNING, 49 TERMINATED)
# 2022-07-26 14:06:12,402	INFO tune.py:748 -- Total run time: 929.19 seconds (928.95 seconds for the tuning loop).
# Trial trainable_func_a8609160 reported epoch=49,loss=0.4764102422847168,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0009000000000000001, 'batch_size': 8, 'hidden_dim1': 150.0, 'hidden_dim2': 330.0, 'hidden_dim3': 285.0}. This trial completed.
# == Status ==
# Current time: 2022-07-26 14:06:12 (running for 00:15:28.94)
# Memory usage on this node: 1.8/12.7 GiB
# Using AsyncHyperBand: num_stopped=33
# Bracket: Iter 32.000: -0.5093873920647516 | Iter 16.000: -0.5241145296043471 | Iter 8.000: -0.516476052315436 | Iter 4.000: -0.5755792124743211
# Bracket: Iter 32.000: -0.5345410936162631 | Iter 16.000: -0.5286231415411561 | Iter 8.000: -0.5702727240783383
# Bracket: Iter 32.000: -0.5073583902450699 | Iter 16.000: -0.5100714277879111
# Bracket: Iter 32.000: -0.6253372834500096
# Bracket:
# Resources requested: 0.5/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_13-50-43
# Number of trials: 50/50 (1 RUNNING, 49 TERMINATED)
#
#
# == Status ==
# Current time: 2022-07-26 14:06:12 (running for 00:15:28.98)
# Memory usage on this node: 1.7/12.7 GiB
# Using AsyncHyperBand: num_stopped=33
# Bracket: Iter 32.000: -0.5093873920647516 | Iter 16.000: -0.5241145296043471 | Iter 8.000: -0.516476052315436 | Iter 4.000: -0.5755792124743211
# Bracket: Iter 32.000: -0.5345410936162631 | Iter 16.000: -0.5286231415411561 | Iter 8.000: -0.5702727240783383
# Bracket: Iter 32.000: -0.5073583902450699 | Iter 16.000: -0.5100714277879111
# Bracket: Iter 32.000: -0.6253372834500096
# Bracket:
# Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_13-50-43
# Number of trials: 50/50 (50 TERMINATED)
# +-------------------------+------------+-------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# | Trial name              | status     | loc               | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |     loss |   training_iteration |
# |-------------------------+------------+-------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------|
# | trainable_func_f144b610 | TERMINATED | 172.28.0.2:222035 | selu    | selu   | selu   |            8 |           285 |           255 |           225 | 0.0008 | 0.519127 |                   50 |
# | trainable_func_f17a5478 | TERMINATED | 172.28.0.2:222036 | tanh    | selu   | relu   |           32 |           165 |           255 |           165 | 0.0009 | 0.528945 |                   50 |
# | trainable_func_f188ac4e | TERMINATED | 172.28.0.2:222100 | relu    | selu   | tanh   |           64 |           330 |           300 |           180 | 0.0007 | 0.586403 |                   16 |
# | trainable_func_f198f554 | TERMINATED | 172.28.0.2:222089 | tanh    | tanh   | tanh   |           32 |           315 |           285 |           210 | 0.0007 | 0.539932 |                   50 |
# | trainable_func_f1a77a0c | TERMINATED | 172.28.0.2:222100 | tanh    | selu   | tanh   |           16 |           300 |           315 |           330 | 0.001  | 0.456271 |                   50 |
# | trainable_func_10e06e6a | TERMINATED | 172.28.0.2:222036 | tanh    | tanh   | relu   |           64 |           180 |           195 |           210 | 0.0005 | 0.581169 |                   50 |
# | trainable_func_38a7f85a | TERMINATED | 172.28.0.2:222089 | relu    | tanh   | tanh   |           32 |           255 |           255 |           165 | 0.0006 | 0.56479  |                    4 |
# | trainable_func_49d23d8e | TERMINATED | 172.28.0.2:222089 | tanh    | tanh   | selu   |           32 |           315 |           195 |           180 | 0.0008 | 0.61608  |                    8 |
# | trainable_func_4f40ae7c | TERMINATED | 172.28.0.2:222089 | selu    | relu   | relu   |           64 |           255 |           255 |           195 | 0.0007 | 0.638489 |                    4 |
# | trainable_func_58df22a6 | TERMINATED | 172.28.0.2:222089 | tanh    | relu   | selu   |           64 |           270 |           225 |           285 | 0.001  | 0.530561 |                   50 |
# | trainable_func_5c3860e8 | TERMINATED | 172.28.0.2:222036 | tanh    | tanh   | tanh   |            8 |           240 |           255 |           255 | 0.0005 | 0.571171 |                    4 |
# | trainable_func_5ccbe93a | TERMINATED | 172.28.0.2:222036 | tanh    | tanh   | tanh   |           16 |           165 |           240 |           300 | 0.001  | 0.575579 |                    4 |
# | trainable_func_6d2c98c4 | TERMINATED | 172.28.0.2:222036 | selu    | tanh   | selu   |            8 |           285 |           210 |           300 | 0.0005 | 0.599674 |                    4 |
# | trainable_func_750ee998 | TERMINATED | 172.28.0.2:222036 | selu    | relu   | tanh   |           64 |           270 |           330 |           285 | 0.0007 | 0.511091 |                   50 |
# | trainable_func_84dc610c | TERMINATED | 172.28.0.2:222089 | tanh    | selu   | relu   |           32 |           150 |           255 |           255 | 0.0008 | 0.632152 |                    4 |
# | trainable_func_87a49b16 | TERMINATED | 172.28.0.2:222089 | relu    | selu   | tanh   |           64 |           195 |           150 |           225 | 0.0007 | 0.5084   |                   50 |
# | trainable_func_8c58fa58 | TERMINATED | 172.28.0.2:222100 | selu    | selu   | relu   |            8 |           195 |           285 |           210 | 0.001  | 0.559653 |                   16 |
# | trainable_func_99b2b6ee | TERMINATED | 172.28.0.2:222089 | selu    | relu   | selu   |            8 |           150 |           255 |           315 | 0.0006 | 0.494875 |                   50 |
# | trainable_func_afb8eb48 | TERMINATED | 172.28.0.2:222036 | tanh    | tanh   | relu   |           16 |           195 |           270 |           270 | 0.0008 | 0.573591 |                    8 |
# | trainable_func_b5b56792 | TERMINATED | 172.28.0.2:222036 | relu    | relu   | tanh   |           32 |           120 |           240 |           300 | 0.0008 | 0.560823 |                    8 |
# | trainable_func_c77c030a | TERMINATED | 172.28.0.2:222036 | tanh    | tanh   | tanh   |           32 |           210 |           285 |           135 | 0.0006 | 0.57727  |                    4 |
# | trainable_func_d0a39f6a | TERMINATED | 172.28.0.2:222035 | selu    | tanh   | selu   |           32 |           135 |           255 |           165 | 0.001  | 0.658528 |                   50 |
# | trainable_func_d2adefc2 | TERMINATED | 172.28.0.2:222036 | tanh    | tanh   | tanh   |           64 |           270 |           300 |           135 | 0.0009 | 0.555894 |                   32 |
# | trainable_func_d5595068 | TERMINATED | 172.28.0.2:222100 | tanh    | relu   | selu   |            8 |           315 |           150 |           270 | 0.0009 | 0.546343 |                   16 |
# | trainable_func_d8757e5c | TERMINATED | 172.28.0.2:222036 | selu    | selu   | relu   |           32 |           150 |           315 |           315 | 0.0007 | 0.58856  |                    4 |
# | trainable_func_f10ffbb8 | TERMINATED | 172.28.0.2:222036 | relu    | selu   | relu   |           16 |           255 |           240 |           330 | 0.0005 | 0.521017 |                   50 |
# | trainable_func_f6791148 | TERMINATED | 172.28.0.2:222035 | selu    | selu   | selu   |           64 |           225 |           300 |           315 | 0.0005 | 0.666928 |                    4 |
# | trainable_func_0b6bafb6 | TERMINATED | 172.28.0.2:222035 | selu    | tanh   | tanh   |           32 |           180 |           240 |           285 | 0.0008 | 0.588739 |                    4 |
# | trainable_func_0eed7976 | TERMINATED | 172.28.0.2:222035 | relu    | relu   | selu   |           16 |           120 |           195 |           270 | 0.0009 | 0.591242 |                    4 |
# | trainable_func_13fe91e8 | TERMINATED | 172.28.0.2:222035 | relu    | relu   | selu   |           64 |           315 |           150 |           150 | 0.0008 | 0.564518 |                    8 |
# | trainable_func_1b8532f0 | TERMINATED | 172.28.0.2:222100 | selu    | selu   | relu   |           32 |           300 |           135 |           225 | 0.001  | 0.570735 |                    8 |
# | trainable_func_1c4d1b08 | TERMINATED | 172.28.0.2:222035 | tanh    | selu   | tanh   |           32 |           150 |           120 |           315 | 0.0006 | 0.749976 |                    4 |
# | trainable_func_2147dbfc | TERMINATED | 172.28.0.2:222035 | relu    | tanh   | relu   |           64 |           210 |           150 |           255 | 0.0007 | 0.569811 |                    8 |
# | trainable_func_254518dc | TERMINATED | 172.28.0.2:222100 | selu    | tanh   | selu   |           16 |           330 |           255 |           270 | 0.0007 | 0.613382 |                    8 |
# | trainable_func_259f82ea | TERMINATED | 172.28.0.2:222035 | selu    | selu   | tanh   |           64 |           240 |           315 |           300 | 0.0005 | 0.607545 |                    4 |
# | trainable_func_2af85d20 | TERMINATED | 172.28.0.2:222035 | relu    | selu   | tanh   |           16 |           210 |           225 |           165 | 0.0007 | 0.534913 |                   16 |
# | trainable_func_2ea67b3c | TERMINATED | 172.28.0.2:222100 | relu    | relu   | selu   |            8 |           195 |           150 |           210 | 0.001  | 0.599342 |                    4 |
# | trainable_func_397ff8e4 | TERMINATED | 172.28.0.2:222100 | relu    | tanh   | selu   |           16 |           165 |           210 |           270 | 0.0008 | 0.586795 |                    8 |
# | trainable_func_47fa41e0 | TERMINATED | 172.28.0.2:222035 | selu    | tanh   | relu   |           64 |           255 |           315 |           255 | 0.0007 | 0.458253 |                   50 |
# | trainable_func_4f2a07a2 | TERMINATED | 172.28.0.2:222100 | tanh    | selu   | selu   |           32 |           270 |           315 |           285 | 0.001  | 0.445304 |                   50 |
# | trainable_func_5956e0e2 | TERMINATED | 172.28.0.2:222036 | selu    | selu   | tanh   |           32 |           165 |           150 |           210 | 0.0007 | 0.58342  |                    4 |
# | trainable_func_6d4be354 | TERMINATED | 172.28.0.2:222036 | tanh    | relu   | tanh   |           32 |           255 |           270 |           315 | 0.0006 | 0.629871 |                    8 |
# | trainable_func_71cd967a | TERMINATED | 172.28.0.2:222036 | relu    | tanh   | selu   |            8 |           240 |           330 |           285 | 0.0005 | 0.650457 |                    4 |
# | trainable_func_7dd62784 | TERMINATED | 172.28.0.2:222035 | tanh    | tanh   | selu   |           64 |           270 |           120 |           270 | 0.0007 | 0.505011 |                   50 |
# | trainable_func_7ff5c90c | TERMINATED | 172.28.0.2:222036 | tanh    | relu   | relu   |           16 |           210 |           270 |           120 | 0.0009 | 0.400106 |                   50 |
# | trainable_func_91bfc23c | TERMINATED | 172.28.0.2:222089 | tanh    | tanh   | relu   |           16 |           150 |           180 |           135 | 0.0006 | 0.668424 |                    4 |
# | trainable_func_967ccfb8 | TERMINATED | 172.28.0.2:222089 | relu    | selu   | relu   |            8 |           195 |           255 |           255 | 0.0008 | 0.700915 |                    4 |
# | trainable_func_9eb40340 | TERMINATED | 172.28.0.2:222035 | selu    | selu   | tanh   |           16 |           210 |           180 |           120 | 0.0009 | 0.509651 |                   50 |
# | trainable_func_a63cb5e4 | TERMINATED | 172.28.0.2:222100 | relu    | relu   | selu   |           64 |           270 |           195 |           255 | 0.0006 | 0.547296 |                   32 |
# | trainable_func_a8609160 | TERMINATED | 172.28.0.2:222089 | selu    | selu   | relu   |            8 |           150 |           330 |           285 | 0.0009 | 0.47641  |                   50 |
# +-------------------------+------------+-------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
#
#
# Best trial config: {'act1 ': 'tanh', 'act2': 'relu', 'act3': 'relu', 'lr': 0.0009000000000000001, 'batch_size': 16, 'hidden_dim1': 210.0, 'hidden_dim2': 270.0, 'hidden_dim3': 120.0}
# Best trial final validation score: 0.40010568686835296
# Best trial test set score: 0.5180841269186803
