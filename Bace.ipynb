# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset
from pandas import read_csv
from sklearn.impute import SimpleImputer
import pandas as pd
import io
#visualizations
import matplotlib as mpl
import matplotlib.pyplot as plt
import random

# %%
from google.colab import files
uploaded1 = files.upload()
# Out:
#      <input type="file" id="files-6c161827-805a-4bce-b388-ac46ac15cc4d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6c161827-805a-4bce-b388-ac46ac15cc4d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bace_global_cdf_rdkit.csv to bace_global_cdf_rdkit.csv

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c9254d73-6423-44ce-b7b0-4d9a714fe806" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c9254d73-6423-44ce-b7b0-4d9a714fe806">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bace(lables).csv to bace(lables).csv

# %%
dataX = pd.read_csv(io.BytesIO(uploaded1['bace_global_cdf_rdkit.csv']))
dataX.head()
# Out:
#    ('RDKit2DNormalized_calculated', <class 'bool'>)  \
# 0                                              True
# 1                                              True
# 2                                              True
# 3                                              True
# 4                                              True
#
#    ('BalabanJ', <class 'numpy.float64'>)  \
# 0                               0.271693
# 1                               0.392419
# 2                               0.149225
# 3                               0.577532
# 4                               0.138106
#
#    ('BertzCT', <class 'numpy.float64'>)  ('Chi0', <class 'numpy.float64'>)  \
# 0                              0.685231                           0.715429
# 1                              0.830920                           0.964192
# 2                              0.951733                           0.924019
# 3                              0.782187                           0.924370
# 4                              0.967050                           0.945002
#
#    ('Chi0n', <class 'numpy.float64'>)  ('Chi0v', <class 'numpy.float64'>)  \
# 0                            0.780380                            0.750726
# 1                            0.966658                            0.963590
# 2                            0.927351                            0.932271
# 3                            0.906913                            0.913072
# 4                            0.930853                            0.935559
#
#    ('Chi1', <class 'numpy.float64'>)  ('Chi1n', <class 'numpy.float64'>)  \
# 0                           0.689887                            0.776209
# 1                           0.957524                            0.968433
# 2                           0.923493                            0.923177
# 3                           0.876879                            0.885455
# 4                           0.936328                            0.928579
#
#    ('Chi1v', <class 'numpy.float64'>)  ('Chi2n', <class 'numpy.float64'>)  \
# 0                            0.716683                            0.850783
# 1                            0.959626                            0.970019
# 2                            0.942919                            0.908699
# 3                            0.922284                            0.928759
# 4                            0.946799                            0.921161
#
#    ...  ('fr_sulfonamd', <class 'numpy.float64'>)  \
# 0  ...                               1.593061e-17
# 1  ...                               1.593061e-17
# 2  ...                               9.999565e-01
# 3  ...                               1.593061e-17
# 4  ...                               9.999565e-01
#
#    ('fr_sulfone', <class 'numpy.float64'>)  \
# 0                             5.766101e-14
# 1                             5.766101e-14
# 2                             5.766101e-14
# 3                             1.000000e+00
# 4                             5.766101e-14
#
#    ('fr_term_acetylene', <class 'numpy.float64'>)  \
# 0                                    2.957989e-11
# 1                                    2.957989e-11
# 2                                    2.957989e-11
# 3                                    2.957989e-11
# 4                                    2.957989e-11
#
#    ('fr_tetrazole', <class 'numpy.float64'>)  \
# 0                                   0.168378
# 1                                   0.168378
# 2                                   0.168378
# 3                                   0.168378
# 4                                   0.168378
#
#    ('fr_thiazole', <class 'numpy.float64'>)  \
# 0                                   0.16738
# 1                                   0.16738
# 2                                   0.16738
# 3                                   0.16738
# 4                                   0.16738
#
#    ('fr_thiocyan', <class 'numpy.float64'>)  \
# 0                              1.481515e-18
# 1                              1.481515e-18
# 2                              1.481515e-18
# 3                              1.481515e-18
# 4                              1.481515e-18
#
#    ('fr_thiophene', <class 'numpy.float64'>)  \
# 0                               2.324150e-16
# 1                               2.324150e-16
# 2                               2.324150e-16
# 3                               2.324150e-16
# 4                               2.324150e-16
#
#    ('fr_unbrch_alkane', <class 'numpy.float64'>)  \
# 0                                   4.703598e-08
# 1                                   4.703598e-08
# 2                                   4.703598e-08
# 3                                   4.703598e-08
# 4                                   4.703598e-08
#
#    ('fr_urea', <class 'numpy.float64'>)  ('qed', <class 'numpy.float64'>)
# 0                              0.166633                          0.494794
# 1                              0.166633                          0.072174
# 2                              0.166633                          0.090157
# 3                              0.166633                          0.121917
# 4                              0.166633                          0.091591
#
# [5 rows x 201 columns]

# %%
dataY = pd.read_csv(io.BytesIO(uploaded['bace(lables).csv']))
dataY.head()
# Out:
#                                                  mol  Class
# 0  O1CC[C@@H](NC(=O)[C@@H](Cc2cc3cc(ccc3nc2N)-c2c...      1
# 1  Fc1cc(cc(F)c1)C[C@H](NC(=O)[C@@H](N1CC[C@](NC(...      1
# 2  S1(=O)(=O)N(c2cc(cc3c2n(cc3CC)CC1)C(=O)N[C@H](...      1
# 3  S1(=O)(=O)C[C@@H](Cc2cc(O[C@H](COCC)C(F)(F)F)c...      1
# 4  S1(=O)(=O)N(c2cc(cc3c2n(cc3CC)CC1)C(=O)N[C@H](...      1

# %%
del dataX["('RDKit2DNormalized_calculated', <class 'bool'>)"]

dataX.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1513 entries, 0 to 1512
# Columns: 200 entries, ('BalabanJ', <class 'numpy.float64'>) to ('qed', <class 'numpy.float64'>)
# dtypes: float64(200)
# memory usage: 2.3 MB

# %%
Y = dataY.iloc[:, 1:2]

# %%
Y.value_counts()
# Out:
# Class
# 0        822
# 1        691
# dtype: int64

# %%
Y.value_counts().plot(kind='bar')

# %%
dataX.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# **Corrolation** **matrix**

# %%
corr_matrix = dataX.corr()
 #This approach is fatsitc it looks at the previous column if the correlation is high it removes it

# Create correlation matrix
corr_matrix = dataX.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(
    np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

# Find features with correlation greater than 0.90
to_drop = [column for column in upper.columns if any(upper[column] > 0.90)]

# Drop features
data = dataX.drop(to_drop, axis=1)
data
# Out:
#       ('BalabanJ', <class 'numpy.float64'>)  \
# 0                                  0.271693
# 1                                  0.392419
# 2                                  0.149225
# 3                                  0.577532
# 4                                  0.138106
# ...                                     ...
# 1508                               0.454177
# 1509                               0.529157
# 1510                               0.674842
# 1511                               0.391085
# 1512                               0.324566
#
#       ('BertzCT', <class 'numpy.float64'>)  ('Chi0', <class 'numpy.float64'>)  \
# 0                                 0.685231                           0.715429
# 1                                 0.830920                           0.964192
# 2                                 0.951733                           0.924019
# 3                                 0.782187                           0.924370
# 4                                 0.967050                           0.945002
# ...                                    ...                                ...
# 1508                              0.285403                           0.363414
# 1509                              0.426769                           0.363414
# 1510                              0.243040                           0.102538
# 1511                              0.499128                           0.279238
# 1512                              0.214257                           0.161372
#
#       ('EState_VSA1', <class 'numpy.float64'>)  \
# 0                                 4.074888e-10
# 1                                 9.340848e-01
# 2                                 8.783594e-01
# 3                                 9.574360e-01
# 4                                 9.316988e-01
# ...                                        ...
# 1508                              4.074888e-10
# 1509                              4.074888e-10
# 1510                              4.074888e-10
# 1511                              4.074888e-10
# 1512                              4.074888e-10
#
#       ('EState_VSA10', <class 'numpy.float64'>)  \
# 0                                      0.264870
# 1                                      0.934238
# 2                                      0.798711
# 3                                      0.952547
# 4                                      0.954729
# ...                                         ...
# 1508                                   0.264870
# 1509                                   0.264870
# 1510                                   0.264870
# 1511                                   0.264870
# 1512                                   0.264870
#
#       ('EState_VSA11', <class 'numpy.float64'>)  \
# 0                                  6.893569e-07
# 1                                  6.893569e-07
# 2                                  6.893569e-07
# 3                                  6.893569e-07
# 4                                  6.893569e-07
# ...                                         ...
# 1508                               6.893569e-07
# 1509                               6.893569e-07
# 1510                               6.893569e-07
# 1511                               6.893569e-07
# 1512                               6.893569e-07
#
#       ('EState_VSA2', <class 'numpy.float64'>)  \
# 0                                     0.779518
# 1                                     0.985669
# 2                                     0.413496
# 3                                     0.957611
# 4                                     0.804052
# ...                                        ...
# 1508                                  0.424202
# 1509                                  0.424202
# 1510                                  0.407802
# 1511                                  0.573235
# 1512                                  0.218593
#
#       ('EState_VSA3', <class 'numpy.float64'>)  \
# 0                                     0.536603
# 1                                     0.957047
# 2                                     0.871830
# 3                                     0.159301
# 4                                     0.788742
# ...                                        ...
# 1508                                  0.776475
# 1509                                  0.663689
# 1510                                  0.323794
# 1511                                  0.141578
# 1512                                  0.776475
#
#       ('EState_VSA4', <class 'numpy.float64'>)  \
# 0                                     0.756983
# 1                                     0.454374
# 2                                     0.816899
# 3                                     0.563856
# 4                                     0.747271
# ...                                        ...
# 1508                                  0.854796
# 1509                                  0.561654
# 1510                                  0.421338
# 1511                                  0.314961
# 1512                                  0.578299
#
#       ('EState_VSA5', <class 'numpy.float64'>)  ...  \
# 0                                 7.566355e-01  ...
# 1                                 8.549856e-01  ...
# 2                                 5.841230e-01  ...
# 3                                 6.680504e-01  ...
# 4                                 8.392643e-01  ...
# ...                                        ...  ...
# 1508                              9.258417e-11  ...
# 1509                              9.258417e-11  ...
# 1510                              7.389729e-01  ...
# 1511                              8.734759e-01  ...
# 1512                              7.835259e-01  ...
#
#       ('fr_sulfide', <class 'numpy.float64'>)  \
# 0                                1.552592e-23
# 1                                1.552592e-23
# 2                                1.552592e-23
# 3                                1.552592e-23
# 4                                1.552592e-23
# ...                                       ...
# 1508                             1.552592e-23
# 1509                             1.552592e-23
# 1510                             1.552592e-23
# 1511                             1.552592e-23
# 1512                             1.552592e-23
#
#       ('fr_sulfonamd', <class 'numpy.float64'>)  \
# 0                                  1.593061e-17
# 1                                  1.593061e-17
# 2                                  9.999565e-01
# 3                                  1.593061e-17
# 4                                  9.999565e-01
# ...                                         ...
# 1508                               1.593061e-17
# 1509                               1.593061e-17
# 1510                               1.593061e-17
# 1511                               1.593061e-17
# 1512                               1.593061e-17
#
#       ('fr_sulfone', <class 'numpy.float64'>)  \
# 0                                5.766101e-14
# 1                                5.766101e-14
# 2                                5.766101e-14
# 3                                1.000000e+00
# 4                                5.766101e-14
# ...                                       ...
# 1508                             5.766101e-14
# 1509                             5.766101e-14
# 1510                             5.766101e-14
# 1511                             5.766101e-14
# 1512                             5.766101e-14
#
#       ('fr_term_acetylene', <class 'numpy.float64'>)  \
# 0                                       2.957989e-11
# 1                                       2.957989e-11
# 2                                       2.957989e-11
# 3                                       2.957989e-11
# 4                                       2.957989e-11
# ...                                              ...
# 1508                                    2.957989e-11
# 1509                                    2.957989e-11
# 1510                                    2.957989e-11
# 1511                                    2.957989e-11
# 1512                                    2.957989e-11
#
#       ('fr_tetrazole', <class 'numpy.float64'>)  \
# 0                                      0.168378
# 1                                      0.168378
# 2                                      0.168378
# 3                                      0.168378
# 4                                      0.168378
# ...                                         ...
# 1508                                   0.168378
# 1509                                   0.168378
# 1510                                   0.168378
# 1511                                   0.168378
# 1512                                   0.168378
#
#       ('fr_thiazole', <class 'numpy.float64'>)  \
# 0                                      0.16738
# 1                                      0.16738
# 2                                      0.16738
# 3                                      0.16738
# 4                                      0.16738
# ...                                        ...
# 1508                                   0.16738
# 1509                                   0.16738
# 1510                                   0.16738
# 1511                                   0.16738
# 1512                                   0.16738
#
#       ('fr_thiocyan', <class 'numpy.float64'>)  \
# 0                                 1.481515e-18
# 1                                 1.481515e-18
# 2                                 1.481515e-18
# 3                                 1.481515e-18
# 4                                 1.481515e-18
# ...                                        ...
# 1508                              1.481515e-18
# 1509                              1.481515e-18
# 1510                              1.481515e-18
# 1511                              1.481515e-18
# 1512                              1.481515e-18
#
#       ('fr_thiophene', <class 'numpy.float64'>)  \
# 0                                  2.324150e-16
# 1                                  2.324150e-16
# 2                                  2.324150e-16
# 3                                  2.324150e-16
# 4                                  2.324150e-16
# ...                                         ...
# 1508                               2.324150e-16
# 1509                               2.324150e-16
# 1510                               2.324150e-16
# 1511                               2.324150e-16
# 1512                               2.324150e-16
#
#       ('fr_unbrch_alkane', <class 'numpy.float64'>)  \
# 0                                      4.703598e-08
# 1                                      4.703598e-08
# 2                                      4.703598e-08
# 3                                      4.703598e-08
# 4                                      4.703598e-08
# ...                                             ...
# 1508                                   4.703598e-08
# 1509                                   4.703598e-08
# 1510                                   4.703598e-08
# 1511                                   4.703598e-08
# 1512                                   4.703598e-08
#
#       ('fr_urea', <class 'numpy.float64'>)
# 0                                 0.166633
# 1                                 0.166633
# 2                                 0.166633
# 3                                 0.166633
# 4                                 0.166633
# ...                                    ...
# 1508                              0.166633
# 1509                              0.166633
# 1510                              0.166633
# 1511                              0.166633
# 1512                              0.166633
#
# [1513 rows x 153 columns]

# %% [markdown]
# **Split** **Data**

# %%
random.seed(10)

# %%
from sklearn.model_selection import train_test_split
X=dataX.iloc[:,1:154]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3,random_state=1)

# %%
X_train = np.array(X_train)
X_test = np.array(X_test)
Y_train = np.array(Y_train)
Y_test = np.array(Y_test)

# %% [markdown]
# **Scaling** **data**

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import random
np.random.seed(10)
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
from sklearn import preprocessing

# scaler_data = preprocessing.MinMaxScaler()
# X_train = scaler_data.fit_transform(X_train)
# X_test = scaler_data.transform(X_test)
scaler_labels = preprocessing.MinMaxScaler()
Y_train = scaler_labels.fit_transform(Y_train.values.reshape(-1, 1))
Y_test = scaler_labels.transform(Y_test.values.reshape(-1, 1))

print(X_train.shape, Y_train.shape, X_test.shape, Y_test.shape)
#print(X_train)
#print("Train labels before scaling: {} {} {}Train labels after scaling: {} {}".format('\n',train_labels_before,'\n', '\n', train_labels))
# Out:
# (1059, 153) (1059, 1) (454, 153) (454, 1)

# %% [markdown]
# **PCA**

# %%
from sklearn.decomposition import PCA as sklearnPCA
pca = sklearnPCA(n_components=40)
pca.fit(X_train_scaled)
X_train_scaled=pca.transform(X_train_scaled)
X_test_scaled=pca.transform(X_test_scaled)
#print(pca.explained_variance_ratio_)
plt.plot(np.arange(40),pca.explained_variance_ratio_)
plt.show()

X_test_scaled.shape
# Out:
# (454, 40)

# %% [markdown]
# **transform** **to** **torch** **tensor**

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
# transform to torch tensor

tensor_x = torch.tensor(X_train_scaled, dtype=torch.float).to(device) 
tensor_x2 = torch.tensor(X_test_scaled, dtype=torch.float).to(device) 

tensor_y = torch.tensor(Y_train, dtype=torch.float).to(device)
tensor_y2 = torch.tensor(Y_test, dtype=torch.float).to(device)

# %%
# create your dataset

trainset = TensorDataset(tensor_x, tensor_y) 
testset = TensorDataset(tensor_x2,tensor_y2)

# %%
# %%capture
try:
    import ray
except:
    # !pip install -U ray
    import ray

# %%
from functools import partial
import numpy as np
import os
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import random_split
from torchsummary import summary

from ray import tune
from ray.tune import CLIReporter
from ray.tune.schedulers import ASHAScheduler

# %%
def load_data(data_dir=None):
    return trainset, testset

# %%
class Net(nn.Module):
    def __init__(self, config):
        super().__init__()
        
        self.config = config
        self.hidden_dim1 = int(self.config.get("hidden_dim1", 100))
        self.hidden_dim2 = int(self.config.get("hidden_dim2", 100))
        self.hidden_dim3 = int(self.config.get("hidden_dim3", 100))

        self.act1 = self.config.get("act1", "relu") 
        self.act2 = self.config.get("act2", "relu") 
        self.act3 = self.config.get("act3", "relu")

        self.linear1 = nn.Linear(40, self.hidden_dim1)
        self.linear2 = nn.Linear(self.hidden_dim1, self.hidden_dim2)
        self.linear3 = nn.Linear(self.hidden_dim2, self.hidden_dim3)
        self.linear4 = nn.Linear(self.hidden_dim3, 1)
    
    @staticmethod
    def activation_func(act_str):
        if act_str=="tanh":
            return eval("torch."+act_str)
        elif act_str=="selu" or act_str=="relu":   
            return eval("torch.nn.functional."+act_str)

    def forward(self, x):
        output = self.linear1(x)
        output = self.activation_func(self.act1)(output)
        output = self.linear2(output)
        output = self.activation_func(self.act2)(output)
        output = self.linear3(output)
        output = self.activation_func(self.act3)(output)
        output = self.linear4(output)        
        return output

# %%
model = Net({})

# %%
from prettytable import PrettyTable

def count_parameters(model):
    table = PrettyTable(["Modules", "Parameters"])
    total_params = 0
    for name, parameter in model.named_parameters():
        if not parameter.requires_grad: continue
        param = parameter.numel()
        table.add_row([name, param])
        total_params+=param
    print(table)
    print(f"Total Trainable Params: {total_params}")
    return total_params

# %%
#summary(model, (1,tensor_x.shape[1]))

count_parameters(model)
# Out:
# +----------------+------------+
# |    Modules     | Parameters |
# +----------------+------------+
# | linear1.weight |    4000    |
# |  linear1.bias  |    100     |
# | linear2.weight |   10000    |
# |  linear2.bias  |    100     |
# | linear3.weight |   10000    |
# |  linear3.bias  |    100     |
# | linear4.weight |    100     |
# |  linear4.bias  |     1      |
# +----------------+------------+
# Total Trainable Params: 24401
# 24401

# %%
def trainable_func(config, checkpoint_dir=None, data_dir=None, epochs=10):

    net = Net(config)

    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda:0"
        if torch.cuda.device_count() > 1:
            net = nn.DataParallel(net)
    net.to(device)

    '''
    Define a loss function
    '''
    ## Classification
    # criterion = nn.CrossEntropyLoss()

    ## Regression
    criterion = nn.MSELoss(reduction='sum')

    # Define an optimizer 
    optimizer = optim.Adam(net.parameters(), lr=config.get("lr",0.0003))

    if checkpoint_dir:
        model_state, optimizer_state = torch.load(
            os.path.join(checkpoint_dir, "checkpoint"))
        net.load_state_dict(model_state)
        optimizer.load_state_dict(optimizer_state)

    # Load data
    trainset, testset = load_data(data_dir)

    # Split the dataset into training and validation sets
    train_size = int(len(trainset) * 0.8)
    train_subset, val_subset = random_split(trainset, [train_size, len(trainset) - train_size])

    # Define data loaders (which combines a dataset and a sampler, and provides an iterable over the given dataset)
    trainloader = torch.utils.data.DataLoader(
        train_subset,
        batch_size=int(config.get("batch_size",32)),
        shuffle=True,
        num_workers=2)
    valloader = torch.utils.data.DataLoader(
        val_subset,
        batch_size=int(config.get("batch_size",32)),
        shuffle=True,
        num_workers=2)

    for epoch in range(epochs):  # loop over the dataset multiple times
        epoch_train_loss = 0.0
        # epoch_steps = 0
        net.train() # Prepare model for training
        for i, data in enumerate(trainloader):
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            '''
            Compute train loss without scaling to print
            ''' 
            # outputs = torch.tensor(scaler_labels.inverse_transform(outputs.detach().cpu())).to(device)    
            # labels = torch.tensor(scaler_labels.inverse_transform(labels.cpu())).to(device)  
            # loss_train = criterion(outputs, labels) 
            # epoch_train_loss += loss_train.detach().item()
        # print("[%d] loss: %.3f" % (epoch + 1, epoch_train_loss / len(train_subset)))

        # Validation loss
        val_loss = 0.0
        net.eval() # Prepare model for evaluation
        for i, data in enumerate(valloader):
            with torch.no_grad():
                inputs, labels = data
                inputs, labels = inputs.to(device), labels.to(device)

                outputs = net(inputs)

                # Inverse transform of the labels' scaler
                outputs = torch.tensor(scaler_labels.inverse_transform(outputs.detach().cpu())).to(device)    
                labels = torch.tensor(scaler_labels.inverse_transform(labels.cpu())).to(device) 

                loss = criterion(outputs, labels)
                val_loss += loss.cpu().numpy()

        with tune.checkpoint_dir(epoch) as checkpoint_dir:
            path = os.path.join(checkpoint_dir, "checkpoint")
            torch.save((net.state_dict(), optimizer.state_dict()), path)

        tune.report(epoch = epoch, loss=(val_loss / len(val_subset)))
    print("Finished Training")

# %% [markdown]
# **Test** **set** **score**

# %%
def test_score(config, net, device="cpu"):
    trainset, testset = load_data()

    testloader = torch.utils.data.DataLoader(
        testset, batch_size=int(config.get("batch_size",32)), shuffle=False, num_workers=2)
    
    criterion = nn.CrossEntropyLoss()

    # Test loss
    test_loss = 0.0
    net.eval() # Prepare model for evaluation
    for i, data in enumerate(testloader):
        with torch.no_grad():
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = net(inputs)

            # Inverse transform of the labels' scaler
            outputs = torch.tensor(scaler_labels.inverse_transform(outputs.detach().cpu())).to(device)    
            labels = torch.tensor(scaler_labels.inverse_transform(labels.cpu())).to(device) 

            loss = criterion(outputs, labels)
            test_loss += loss.cpu().numpy()

    return test_loss / len(testset)

# %% [markdown]
# Start Ray runtime

# %%
ray.shutdown()
ray.init(num_cpus=2, num_gpus=0) # Here we use ray.init() to evaluate available_resources for Ray
print(ray.available_resources())
  # Restart Ray defensively in case the ray connection is lost. 

# Start Ray runtime with specific resources (not nessesarily all resources)
# You can change this values based on your machine resources)
#ray.init(num_cpus=2, num_gpus=0) 

"""Check Ray Tune is working properly (for trainable class)"""
# from ray.tune.utils import validate_save_restore
# validate_save_restore(Trainable)
# validate_save_restore(Trainable, use_object_store=True)
# print("Success!")
# Out:
# {'CPU': 2.0, 'node:172.28.0.2': 1.0, 'memory': 7904192103.0, 'object_store_memory': 3952096051.0}
# 'Check Ray Tune is working properly (for trainable class)'

# %% [markdown]
# Start hyperparameter tuning

# %%
# %%capture
try:
    import optuna
except:
    # %pip install optuna
    import optuna

# %%
def main(num_samples=10, max_num_epochs=10, gpus_per_trial=2):

    # define data directory here if you want to load data from files
    data_dir = os.path.abspath("./data")
    load_data(data_dir)

    # define the search space of hyperparameters
    config = {
        "act1 ": tune.choice(["relu","tanh","selu"]),
        "act2" : tune.choice(["relu","tanh","selu"]),
        "act3" : tune.choice(["relu","tanh","selu"]),
        "lr": tune.quniform(0.0005, 0.001, 0.0001),
        "batch_size": tune.choice([8, 16, 32]),
        "hidden_dim1" : tune.quniform(50, 200, 10),
        "hidden_dim2" : tune.quniform(50, 200, 10),
        "hidden_dim3" : tune.quniform(50, 200, 10),
    }

    # Optuna search algorithm
    from ray.tune.suggest.optuna import OptunaSearch 
    from ray.tune.suggest import ConcurrencyLimiter
    search_alg = OptunaSearch(
        metric="loss", #or accuracy, etc.
        mode="min", #or max
        # seed = 42,
        # points_to_evaluate=[
        # {'lr': 0.0005, 'hidden_size': 150.0, 'readout1_out': 200.0, 'readout2_out': 180.0}
        # ],
        )
    search_alg = ConcurrencyLimiter(search_alg, max_concurrent=10)

    scheduler = ASHAScheduler(
        metric ="loss",
        mode="min",
        max_t=max_num_epochs,
        reduction_factor=2, 
        grace_period=4,
        brackets=5
        )
    
    reporter = CLIReporter(
        # parameter_columns=["l1", "l2", "lr", "batch_size"],
        metric_columns=["loss", "training_iteration"]
        )
    
    # wrap data loading and training for tuning using `partial` 
    # (note that there exist other methods for this purpose)
    result = tune.run(
        partial(trainable_func, data_dir=data_dir, epochs=max_num_epochs),
        scheduler=scheduler,
        search_alg=search_alg,
        num_samples=num_samples,
        config=config,
        verbose=2,
        checkpoint_score_attr="loss",
        checkpoint_freq=0,
        keep_checkpoints_num=1,
        # checkpoint_at_end=True,
        # reuse_actors=reuse_actors_status,
        progress_reporter=reporter,
        resources_per_trial={"cpu": 0.5, "gpu": gpus_per_trial},
        stop={"training_iteration": max_num_epochs},                
        )

    best_trial = result.get_best_trial("loss", "min", "last")
    print("Best trial config: {}".format(best_trial.config))
    print("Best trial final validation score: {}".format(
        best_trial.last_result["loss"]))

    best_trained_model = Net(best_trial.config)
    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda:0"
        if gpus_per_trial > 1:
            best_trained_model = nn.DataParallel(best_trained_model)
    best_trained_model.to(device)

    best_checkpoint_dir = best_trial.checkpoint.value
    model_state, optimizer_state = torch.load(os.path.join(
        best_checkpoint_dir, "checkpoint"))
    best_trained_model.load_state_dict(model_state)

    test_score_value = test_score(best_trial.config, best_trained_model, device)
    print("Best trial test set score: {}".format(test_score_value))


if __name__ == "__main__":
    # You can change the number of GPUs per trial here:
    main(num_samples=50, max_num_epochs=50, gpus_per_trial=0)
# Out:
# 2022-07-15 18:17:26,585	WARNING callback.py:106 -- The TensorboardX logger cannot be instantiated because either TensorboardX or one of it's dependencies is not installed. Please make sure you have the latest version of TensorboardX installed: `pip install -U tensorboardx`
# == Status ==
# Current time: 2022-07-15 18:17:26 (running for 00:00:00.19)
# Memory usage on this node: 2.0/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 0.5/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_18-17-26
# Number of trials: 1/50 (1 RUNNING)
#
#
# == Status ==
# Current time: 2022-07-15 18:17:31 (running for 00:00:05.28)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_18-17-26
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
#
#
# Trial trainable_func_616c511a reported epoch=0,loss=0.17710825153731807,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0005, 'batch_size': 16, 'hidden_dim1': 70.0, 'hidden_dim2': 150.0, 'hidden_dim3': 50.0}.
# Trial trainable_func_6189c51a reported epoch=0,loss=0.1852196792039282,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0008, 'batch_size': 8, 'hidden_dim1': 180.0, 'hidden_dim2': 120.0, 'hidden_dim3': 200.0}.
# == Status ==
# Current time: 2022-07-15 18:17:37 (running for 00:00:10.50)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_18-17-26
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
#
#
# Trial trainable_func_618d4a14 reported epoch=0,loss=0.1704613770622589,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 16, 'hidden_dim1': 180.0, 'hidden_dim2': 130.0, 'hidden_dim3': 180.0}.
# Trial trainable_func_6191d9d0 reported epoch=0,loss=0.1757914867894786,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.001, 'batch_size': 8, 'hidden_dim1': 160.0, 'hidden_dim2': 100.0, 'hidden_dim3': 200.0}.
# Trial trainable_func_616c511a reported epoch=7,loss=0.15072917851292586,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0005, 'batch_size': 16, 'hidden_dim1': 70.0, 'hidden_dim2': 150.0, 'hidden_dim3': 50.0}.
# Trial trainable_func_618d4a14 reported epoch=3,loss=0.18962346874203667,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 16, 'hidden_dim1': 180.0, 'hidden_dim2': 130.0, 'hidden_dim3': 180.0}. This trial completed.
# Trial trainable_func_6189c51a reported epoch=4,loss=0.16490503534724094,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0008, 'batch_size': 8, 'hidden_dim1': 180.0, 'hidden_dim2': 120.0, 'hidden_dim3': 200.0}.
# == Status ==
# Current time: 2022-07-15 18:17:42 (running for 00:00:16.24)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=1
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: -0.16569933976614054
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: -0.15072917851292586
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_18-17-26
# Number of trials: 6/50 (1 PENDING, 4 RUNNING, 1 TERMINATED)
#
#
# Trial trainable_func_61955f92 reported epoch=0,loss=0.1873694120440894,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 8, 'hidden_dim1': 140.0, 'hidden_dim2': 160.0, 'hidden_dim3': 170.0}.
# Trial trainable_func_6191d9d0 reported epoch=3,loss=0.17135478262018156,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.001, 'batch_size': 8, 'hidden_dim1': 160.0, 'hidden_dim2': 100.0, 'hidden_dim3': 200.0}. This trial completed.
# Trial trainable_func_616c511a reported epoch=13,loss=0.1520980088312036,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0005, 'batch_size': 16, 'hidden_dim1': 70.0, 'hidden_dim2': 150.0, 'hidden_dim3': 50.0}.
# Trial trainable_func_6a6bed3e reported epoch=0,loss=0.19044729191449106,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 8, 'hidden_dim1': 50.0, 'hidden_dim2': 180.0, 'hidden_dim3': 160.0}.
# Trial trainable_func_61955f92 reported epoch=3,loss=0.17780234550967164,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 8, 'hidden_dim1': 140.0, 'hidden_dim2': 160.0, 'hidden_dim3': 170.0}. This trial completed.
# == Status ==
# Current time: 2022-07-15 18:17:47 (running for 00:00:21.41)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=3
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: -0.15017853588708957 | Iter 4.000: -0.1745785640649266
# Bracket: Iter 32.000: None | Iter 16.000: -0.16274523898451737 | Iter 8.000: -0.15072917851292586
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_18-17-26
# Number of trials: 7/50 (1 PENDING, 4 RUNNING, 2 TERMINATED)
#
#
# Trial trainable_func_6189c51a reported epoch=8,loss=0.14620326989088217,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0008, 'batch_size': 8, 'hidden_dim1': 180.0, 'hidden_dim2': 120.0, 'hidden_dim3': 200.0}.
# Trial trainable_func_6c1c0e2a reported epoch=0,loss=0.18627281789688235,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0009, 'batch_size': 32, 'hidden_dim1': 70.0, 'hidden_dim2': 120.0, 'hidden_dim3': 100.0}.
# Trial trainable_func_6a6bed3e reported epoch=3,loss=0.1788169471811132,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 8, 'hidden_dim1': 50.0, 'hidden_dim2': 180.0, 'hidden_dim3': 160.0}. This trial completed.
# Trial trainable_func_616c511a reported epoch=19,loss=0.17288542930706832,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0005, 'batch_size': 16, 'hidden_dim1': 70.0, 'hidden_dim2': 150.0, 'hidden_dim3': 50.0}.
# Trial trainable_func_6e307bec reported epoch=0,loss=0.19653631807290642,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 8, 'hidden_dim1': 200.0, 'hidden_dim2': 200.0, 'hidden_dim3': 130.0}.
# == Status ==
# Current time: 2022-07-15 18:17:53 (running for 00:00:26.64)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=4
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: -0.14948534563673216 | Iter 4.000: -0.1745785640649266
# Bracket: Iter 32.000: None | Iter 16.000: -0.16274523898451737 | Iter 8.000: -0.15072917851292586
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_18-17-26
# Number of trials: 9/50 (1 PENDING, 4 RUNNING, 4 TERMINATED)
#
#
# Trial trainable_func_6189c51a reported epoch=11,loss=0.1630407955332871,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0008, 'batch_size': 8, 'hidden_dim1': 180.0, 'hidden_dim2': 120.0, 'hidden_dim3': 200.0}.
# Trial trainable_func_6c1c0e2a reported epoch=9,loss=0.15713940825134562,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0009, 'batch_size': 32, 'hidden_dim1': 70.0, 'hidden_dim2': 120.0, 'hidden_dim3': 100.0}.
# Trial trainable_func_616c511a reported epoch=25,loss=0.17962406429710348,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0005, 'batch_size': 16, 'hidden_dim1': 70.0, 'hidden_dim2': 150.0, 'hidden_dim3': 50.0}.
# Trial trainable_func_6e307bec reported epoch=3,loss=0.15588212994722378,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 8, 'hidden_dim1': 200.0, 'hidden_dim2': 200.0, 'hidden_dim3': 130.0}.
# == Status ==
# Current time: 2022-07-15 18:17:58 (running for 00:00:31.88)
# Memory usage on this node: 2.7/12.7 GiB
# Using AsyncHyperBand: num_stopped=4
# Bracket: Iter 32.000: None | Iter 16.000: -0.16150213582223163 | Iter 8.000: -0.14948534563673216 | Iter 4.000: -0.17135478262018156
# Bracket: Iter 32.000: None | Iter 16.000: -0.16274523898451737 | Iter 8.000: -0.15072917851292586
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_18-17-26
# Number of trials: 9/50 (1 PENDING, 4 RUNNING, 4 TERMINATED)
#
#
# Trial trainable_func_6189c51a reported epoch=14,loss=0.16532283835913023,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0008, 'batch_size': 8, 'hidden_dim1': 180.0, 'hidden_dim2': 120.0, 'hidden_dim3': 200.0}.
# Trial trainable_func_6c1c0e2a reported epoch=18,loss=0.17124651657365936,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0009, 'batch_size': 32, 'hidden_dim1': 70.0, 'hidden_dim2': 120.0, 'hidden_dim3': 100.0}.
# Trial trainable_func_6189c51a reported epoch=15,loss=0.17582398926593623,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0008, 'batch_size': 8, 'hidden_dim1': 180.0, 'hidden_dim2': 120.0, 'hidden_dim3': 200.0}. This trial completed.
# Trial trainable_func_6fcc5b24 reported epoch=0,loss=0.15778554800767092,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'relu', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 100.0, 'hidden_dim2': 70.0, 'hidden_dim3': 110.0}.
# Trial trainable_func_616c511a reported epoch=31,loss=0.1897264257202844,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0005, 'batch_size': 16, 'hidden_dim1': 70.0, 'hidden_dim2': 150.0, 'hidden_dim3': 50.0}.
# Trial trainable_func_6e307bec reported epoch=6,loss=0.1529212774708653,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 8, 'hidden_dim1': 200.0, 'hidden_dim2': 200.0, 'hidden_dim3': 130.0}.
# == Status ==
# Current time: 2022-07-15 18:18:03 (running for 00:00:36.89)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=5
# Bracket: Iter 32.000: None | Iter 16.000: -0.16866306254408392 | Iter 8.000: -0.14948534563673216 | Iter 4.000: -0.17135478262018156
# Bracket: Iter 32.000: -0.1897264257202844 | Iter 16.000: -0.16274523898451737 | Iter 8.000: -0.15072917851292586
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_18-17-26
# Number of trials: 10/50 (1 PENDING, 4 RUNNING, 5 TERMINATED)
#
#
# Trial trainable_func_6c1c0e2a reported epoch=27,loss=0.17558752368429623,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0009, 'batch_size': 32, 'hidden_dim1': 70.0, 'hidden_dim2': 120.0, 'hidden_dim3': 100.0}.
# Trial trainable_func_6e307bec reported epoch=7,loss=0.15300688409983593,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 8, 'hidden_dim1': 200.0, 'hidden_dim2': 200.0, 'hidden_dim3': 130.0}. This trial completed.
# Trial trainable_func_75aafed8 reported epoch=0,loss=0.15027123033233858,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 190.0, 'hidden_dim2': 80.0, 'hidden_dim3': 150.0}.
# Trial trainable_func_6fcc5b24 reported epoch=6,loss=0.13694557646397265,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'relu', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 100.0, 'hidden_dim2': 70.0, 'hidden_dim3': 110.0}.
# Trial trainable_func_6fcc5b24 reported epoch=7,loss=0.15338656200166806,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'relu', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 100.0, 'hidden_dim2': 70.0, 'hidden_dim3': 110.0}. This trial completed.
# Trial trainable_func_616c511a reported epoch=37,loss=0.20536833044667913,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0005, 'batch_size': 16, 'hidden_dim1': 70.0, 'hidden_dim2': 150.0, 'hidden_dim3': 50.0}.
# == Status ==
# Current time: 2022-07-15 18:18:08 (running for 00:00:42.31)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=7
# Bracket: Iter 32.000: -0.1785968272804772 | Iter 16.000: -0.16866306254408392 | Iter 8.000: -0.15159270999346275 | Iter 4.000: -0.16068975533073074
# Bracket: Iter 32.000: -0.1897264257202844 | Iter 16.000: -0.16274523898451737 | Iter 8.000: -0.15072917851292586
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_18-17-26
# Number of trials: 12/50 (1 PENDING, 4 RUNNING, 7 TERMINATED)
#
#
# Trial trainable_func_784894a2 reported epoch=0,loss=0.18458036882242662,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0008, 'batch_size': 16, 'hidden_dim1': 150.0, 'hidden_dim2': 110.0, 'hidden_dim3': 190.0}.
# Trial trainable_func_6c1c0e2a reported epoch=35,loss=0.1743129737849868,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0009, 'batch_size': 32, 'hidden_dim1': 70.0, 'hidden_dim2': 120.0, 'hidden_dim3': 100.0}.
# Trial trainable_func_75aafed8 reported epoch=7,loss=0.15490215786675496,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 190.0, 'hidden_dim2': 80.0, 'hidden_dim3': 150.0}. This trial completed.
# Trial trainable_func_7a3a9eb8 reported epoch=0,loss=0.16824726255786226,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0007, 'batch_size': 8, 'hidden_dim1': 200.0, 'hidden_dim2': 110.0, 'hidden_dim3': 100.0}.
# Trial trainable_func_784894a2 reported epoch=3,loss=0.16377163049526539,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0008, 'batch_size': 16, 'hidden_dim1': 150.0, 'hidden_dim2': 110.0, 'hidden_dim3': 190.0}. This trial completed.
# Trial trainable_func_7b6f2d9e reported epoch=0,loss=0.17144756993771268,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 190.0, 'hidden_dim2': 90.0, 'hidden_dim3': 180.0}.
# == Status ==
# Current time: 2022-07-15 18:18:14 (running for 00:00:47.46)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=9
# Bracket: Iter 32.000: -0.1785968272804772 | Iter 16.000: -0.16866306254408392 | Iter 8.000: -0.15300688409983593 | Iter 4.000: -0.16223069291299808
# Bracket: Iter 32.000: -0.1897264257202844 | Iter 16.000: -0.16274523898451737 | Iter 8.000: -0.15072917851292586
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_18-17-26
# Number of trials: 14/50 (1 PENDING, 4 RUNNING, 9 TERMINATED)
#
#
# Trial trainable_func_616c511a reported epoch=43,loss=0.2020511296529503,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0005, 'batch_size': 16, 'hidden_dim1': 70.0, 'hidden_dim2': 150.0, 'hidden_dim3': 50.0}.
# Trial trainable_func_6c1c0e2a reported epoch=43,loss=0.18834243827206607,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0009, 'batch_size': 32, 'hidden_dim1': 70.0, 'hidden_dim2': 120.0, 'hidden_dim3': 100.0}.
# Trial trainable_func_7a3a9eb8 reported epoch=3,loss=0.15842849246332416,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0007, 'batch_size': 8, 'hidden_dim1': 200.0, 'hidden_dim2': 110.0, 'hidden_dim3': 100.0}.
# Trial trainable_func_7b6f2d9e reported epoch=7,loss=0.14052775042261204,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 190.0, 'hidden_dim2': 90.0, 'hidden_dim3': 180.0}.
# == Status ==
# Current time: 2022-07-15 18:18:19 (running for 00:00:52.53)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=9
# Bracket: Iter 32.000: -0.1785968272804772 | Iter 16.000: -0.16866306254408392 | Iter 8.000: -0.15159270999346275 | Iter 4.000: -0.15955912389702745
# Bracket: Iter 32.000: -0.1897264257202844 | Iter 16.000: -0.16274523898451737 | Iter 8.000: -0.15072917851292586
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_18-17-26
# Number of trials: 14/50 (1 PENDING, 4 RUNNING, 9 TERMINATED)
#
#
# Trial trainable_func_6c1c0e2a reported epoch=49,loss=0.1855387301324216,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0009, 'batch_size': 32, 'hidden_dim1': 70.0, 'hidden_dim2': 120.0, 'hidden_dim3': 100.0}. This trial completed.
# Trial trainable_func_616c511a reported epoch=48,loss=0.20567217126144394,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0005, 'batch_size': 16, 'hidden_dim1': 70.0, 'hidden_dim2': 150.0, 'hidden_dim3': 50.0}.
# Trial trainable_func_7c8bb53a reported epoch=0,loss=0.167350337359422,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 140.0, 'hidden_dim2': 160.0, 'hidden_dim3': 100.0}.
# Trial trainable_func_616c511a reported epoch=49,loss=0.20785225407613342,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0005, 'batch_size': 16, 'hidden_dim1': 70.0, 'hidden_dim2': 150.0, 'hidden_dim3': 50.0}. This trial completed.
# Trial trainable_func_80d3aef4 reported epoch=0,loss=0.1851404264191526,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0005, 'batch_size': 8, 'hidden_dim1': 110.0, 'hidden_dim2': 200.0, 'hidden_dim3': 50.0}.
# Trial trainable_func_7b6f2d9e reported epoch=15,loss=0.14905411735181107,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 190.0, 'hidden_dim2': 90.0, 'hidden_dim3': 180.0}.
# Trial trainable_func_7a3a9eb8 reported epoch=7,loss=0.15778720564733273,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0007, 'batch_size': 8, 'hidden_dim1': 200.0, 'hidden_dim2': 110.0, 'hidden_dim3': 100.0}. This trial completed.
# == Status ==
# Current time: 2022-07-15 18:18:24 (running for 00:00:57.60)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=10
# Bracket: Iter 32.000: -0.1785968272804772 | Iter 16.000: -0.16150213582223163 | Iter 8.000: -0.15300688409983593 | Iter 4.000: -0.15880887634486368
# Bracket: Iter 32.000: -0.1897264257202844 | Iter 16.000: -0.16274523898451737 | Iter 8.000: -0.15072917851292586
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_18-17-26
# Number of trials: 17/50 (1 PENDING, 4 RUNNING, 12 TERMINATED)
#
#
# Trial trainable_func_81c580d0 reported epoch=0,loss=0.19083004952792454,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'relu', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 110.0, 'hidden_dim2': 50.0, 'hidden_dim3': 110.0}.
# Trial trainable_func_7c8bb53a reported epoch=6,loss=0.16859208873613069,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 140.0, 'hidden_dim2': 160.0, 'hidden_dim3': 100.0}.
# Trial trainable_func_7c8bb53a reported epoch=7,loss=0.1619958437263936,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 140.0, 'hidden_dim2': 160.0, 'hidden_dim3': 100.0}. This trial completed.
# Trial trainable_func_80d3aef4 reported epoch=3,loss=0.15408355194311812,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0005, 'batch_size': 8, 'hidden_dim1': 110.0, 'hidden_dim2': 200.0, 'hidden_dim3': 50.0}.
# Trial trainable_func_8397a910 reported epoch=0,loss=0.17246630257440693,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 110.0, 'hidden_dim2': 50.0, 'hidden_dim3': 130.0}.
# Trial trainable_func_7b6f2d9e reported epoch=23,loss=0.15272678939603487,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 190.0, 'hidden_dim2': 90.0, 'hidden_dim3': 180.0}.
# == Status ==
# Current time: 2022-07-15 18:18:29 (running for 00:01:02.64)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=11
# Bracket: Iter 32.000: -0.1785968272804772 | Iter 16.000: -0.16150213582223163 | Iter 8.000: -0.153196723050752 | Iter 4.000: -0.15842849246332416
# Bracket: Iter 32.000: -0.1897264257202844 | Iter 16.000: -0.16274523898451737 | Iter 8.000: -0.15072917851292586
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_18-17-26
# Number of trials: 18/50 (1 PENDING, 4 RUNNING, 13 TERMINATED)
#
#
# Trial trainable_func_81c580d0 reported epoch=6,loss=0.1466076256715196,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'relu', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 110.0, 'hidden_dim2': 50.0, 'hidden_dim3': 110.0}.
# Trial trainable_func_8397a910 reported epoch=6,loss=0.15219974663045466,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 110.0, 'hidden_dim2': 50.0, 'hidden_dim3': 130.0}.
# Trial trainable_func_80d3aef4 reported epoch=7,loss=0.15248014360764503,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0005, 'batch_size': 8, 'hidden_dim1': 110.0, 'hidden_dim2': 200.0, 'hidden_dim3': 50.0}.
# == Status ==
# Current time: 2022-07-15 18:18:34 (running for 00:01:07.65)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=11
# Bracket: Iter 32.000: -0.1785968272804772 | Iter 16.000: -0.16150213582223163 | Iter 8.000: -0.15274351385374046 | Iter 4.000: -0.15842849246332416
# Bracket: Iter 32.000: -0.1897264257202844 | Iter 16.000: -0.16274523898451737 | Iter 8.000: -0.15072917851292586
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_18-17-26
# Number of trials: 18/50 (1 PENDING, 4 RUNNING, 13 TERMINATED)
#
#
# Trial trainable_func_7b6f2d9e reported epoch=31,loss=0.16455355158359286,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 190.0, 'hidden_dim2': 90.0, 'hidden_dim3': 180.0}.
# Trial trainable_func_81c580d0 reported epoch=12,loss=0.15462356622125253,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'relu', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 110.0, 'hidden_dim2': 50.0, 'hidden_dim3': 110.0}.
# == Status ==
# Current time: 2022-07-15 18:18:39 (running for 00:01:12.69)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=11
# Bracket: Iter 32.000: -0.17157518943203504 | Iter 16.000: -0.1580594135523183 | Iter 8.000: -0.15274351385374046 | Iter 4.000: -0.15842849246332416
# Bracket: Iter 32.000: -0.1897264257202844 | Iter 16.000: -0.16274523898451737 | Iter 8.000: -0.14452297064168956
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_18-17-26
# Number of trials: 18/50 (1 PENDING, 4 RUNNING, 13 TERMINATED)
#
#
# Trial trainable_func_7b6f2d9e reported epoch=39,loss=0.16962827189133073,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 190.0, 'hidden_dim2': 90.0, 'hidden_dim3': 180.0}.
# Trial trainable_func_8397a910 reported epoch=12,loss=0.1481462353817784,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 110.0, 'hidden_dim2': 50.0, 'hidden_dim3': 130.0}.
# Trial trainable_func_80d3aef4 reported epoch=11,loss=0.15132989825481555,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0005, 'batch_size': 8, 'hidden_dim1': 110.0, 'hidden_dim2': 200.0, 'hidden_dim3': 50.0}.
# Trial trainable_func_81c580d0 reported epoch=18,loss=0.16481003393405733,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'relu', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 110.0, 'hidden_dim2': 50.0, 'hidden_dim3': 110.0}.
# == Status ==
# Current time: 2022-07-15 18:18:44 (running for 00:01:17.74)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=11
# Bracket: Iter 32.000: -0.17157518943203504 | Iter 16.000: -0.1580594135523183 | Iter 8.000: -0.15274351385374046 | Iter 4.000: -0.15842849246332416
# Bracket: Iter 32.000: -0.1897264257202844 | Iter 16.000: -0.15436327561257301 | Iter 8.000: -0.14452297064168956
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_18-17-26
# Number of trials: 18/50 (1 PENDING, 4 RUNNING, 13 TERMINATED)
#
#
# Trial trainable_func_7b6f2d9e reported epoch=47,loss=0.16675344583709015,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 190.0, 'hidden_dim2': 90.0, 'hidden_dim3': 180.0}.
# Trial trainable_func_8397a910 reported epoch=18,loss=0.15049934839808699,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 110.0, 'hidden_dim2': 50.0, 'hidden_dim3': 130.0}.
# Trial trainable_func_7b6f2d9e reported epoch=49,loss=0.18388891708926972,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 190.0, 'hidden_dim2': 90.0, 'hidden_dim3': 180.0}. This trial completed.
# Trial trainable_func_80d3aef4 reported epoch=14,loss=0.17238026912631654,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0005, 'batch_size': 8, 'hidden_dim1': 110.0, 'hidden_dim2': 200.0, 'hidden_dim3': 50.0}.
# Trial trainable_func_858d24de reported epoch=0,loss=0.16143049335755655,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 110.0, 'hidden_dim2': 50.0, 'hidden_dim3': 130.0}.
# Trial trainable_func_81c580d0 reported epoch=24,loss=0.1814610909734512,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'relu', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 110.0, 'hidden_dim2': 50.0, 'hidden_dim3': 110.0}.
# Trial trainable_func_80d3aef4 reported epoch=15,loss=0.16705012794037813,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0005, 'batch_size': 8, 'hidden_dim1': 110.0, 'hidden_dim2': 200.0, 'hidden_dim3': 50.0}. This trial completed.
# Trial trainable_func_90aae004 reported epoch=0,loss=0.17068867637528268,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 110.0, 'hidden_dim2': 50.0, 'hidden_dim3': 120.0}.
# == Status ==
# Current time: 2022-07-15 18:18:49 (running for 00:01:23.23)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=12
# Bracket: Iter 32.000: -0.17157518943203504 | Iter 16.000: -0.16150213582223163 | Iter 8.000: -0.15274351385374046 | Iter 4.000: -0.15842849246332416
# Bracket: Iter 32.000: -0.1897264257202844 | Iter 16.000: -0.15436327561257301 | Iter 8.000: -0.14452297064168956
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_18-17-26
# Number of trials: 20/50 (1 PENDING, 4 RUNNING, 15 TERMINATED)
#
#
# Trial trainable_func_8397a910 reported epoch=24,loss=0.14251113151929384,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 110.0, 'hidden_dim2': 50.0, 'hidden_dim3': 130.0}.
# Trial trainable_func_858d24de reported epoch=6,loss=0.14938519368714936,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 110.0, 'hidden_dim2': 50.0, 'hidden_dim3': 130.0}.
# Trial trainable_func_81c580d0 reported epoch=30,loss=0.1783592390053644,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'relu', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 110.0, 'hidden_dim2': 50.0, 'hidden_dim3': 110.0}.
# Trial trainable_func_858d24de reported epoch=7,loss=0.14766183329159727,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 110.0, 'hidden_dim2': 50.0, 'hidden_dim3': 130.0}. This trial completed.
# Trial trainable_func_81c580d0 reported epoch=31,loss=0.1908067629967868,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'relu', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 110.0, 'hidden_dim2': 50.0, 'hidden_dim3': 110.0}. This trial completed.
# Trial trainable_func_91ff58c2 reported epoch=0,loss=0.17309685192168459,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'relu', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 100.0, 'hidden_dim2': 70.0, 'hidden_dim3': 130.0}.
# Trial trainable_func_95568fe0 reported epoch=0,loss=0.16467801768491727,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 110.0, 'hidden_dim2': 60.0, 'hidden_dim3': 140.0}.
# == Status ==
# Current time: 2022-07-15 18:18:54 (running for 00:01:28.27)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=14
# Bracket: Iter 32.000: -0.1785968272804772 | Iter 16.000: -0.16150213582223163 | Iter 8.000: -0.15274351385374046 | Iter 4.000: -0.15715531120527398
# Bracket: Iter 32.000: -0.1897264257202844 | Iter 16.000: -0.15436327561257301 | Iter 8.000: -0.14766183329159727
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_18-17-26
# Number of trials: 22/50 (1 PENDING, 4 RUNNING, 17 TERMINATED)
#
#
# Trial trainable_func_90aae004 reported epoch=6,loss=0.16253262341327077,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 110.0, 'hidden_dim2': 50.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_90aae004 reported epoch=7,loss=0.15467650499141095,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 110.0, 'hidden_dim2': 50.0, 'hidden_dim3': 120.0}. This trial completed.
# Trial trainable_func_8397a910 reported epoch=30,loss=0.14928550569644505,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 110.0, 'hidden_dim2': 50.0, 'hidden_dim3': 130.0}.
# Trial trainable_func_9573e5ae reported epoch=0,loss=0.1593185224075633,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 8, 'hidden_dim1': 120.0, 'hidden_dim2': 200.0, 'hidden_dim3': 140.0}.
# Trial trainable_func_95568fe0 reported epoch=3,loss=0.16022080384643186,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 110.0, 'hidden_dim2': 60.0, 'hidden_dim3': 140.0}. This trial completed.
# == Status ==
# Current time: 2022-07-15 18:19:00 (running for 00:01:33.60)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=16
# Bracket: Iter 32.000: -0.1785968272804772 | Iter 16.000: -0.16150213582223163 | Iter 8.000: -0.15300688409983593 | Iter 4.000: -0.15842849246332416
# Bracket: Iter 32.000: -0.1685978036837009 | Iter 16.000: -0.15436327561257301 | Iter 8.000: -0.14766183329159727
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_18-17-26
# Number of trials: 24/50 (1 PENDING, 4 RUNNING, 19 TERMINATED)
#
#
# Trial trainable_func_91ff58c2 reported epoch=5,loss=0.13026502267088108,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'relu', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 100.0, 'hidden_dim2': 70.0, 'hidden_dim3': 130.0}.
# Trial trainable_func_96af0444 reported epoch=0,loss=0.1772858484228879,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 8, 'hidden_dim1': 90.0, 'hidden_dim2': 200.0, 'hidden_dim3': 140.0}.
# Trial trainable_func_8397a910 reported epoch=34,loss=0.1536235491269329,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 110.0, 'hidden_dim2': 50.0, 'hidden_dim3': 130.0}.
# Trial trainable_func_9573e5ae reported epoch=3,loss=0.14947896898037316,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 8, 'hidden_dim1': 120.0, 'hidden_dim2': 200.0, 'hidden_dim3': 140.0}.
# == Status ==
# Current time: 2022-07-15 18:19:05 (running for 00:01:38.88)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=16
# Bracket: Iter 32.000: -0.1785968272804772 | Iter 16.000: -0.16150213582223163 | Iter 8.000: -0.15300688409983593 | Iter 4.000: -0.15715531120527398
# Bracket: Iter 32.000: -0.1685978036837009 | Iter 16.000: -0.15436327561257301 | Iter 8.000: -0.14298929803102525
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_18-17-26
# Number of trials: 24/50 (1 PENDING, 4 RUNNING, 19 TERMINATED)
#
#
# Trial trainable_func_91ff58c2 reported epoch=11,loss=0.13890650073302974,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'relu', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 100.0, 'hidden_dim2': 70.0, 'hidden_dim3': 130.0}.
# Trial trainable_func_96af0444 reported epoch=4,loss=0.15091903944582444,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 8, 'hidden_dim1': 90.0, 'hidden_dim2': 200.0, 'hidden_dim3': 140.0}.
# Trial trainable_func_8397a910 reported epoch=40,loss=0.15755910242163362,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 110.0, 'hidden_dim2': 50.0, 'hidden_dim3': 130.0}.
# Trial trainable_func_9573e5ae reported epoch=6,loss=0.16127690149979587,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 8, 'hidden_dim1': 120.0, 'hidden_dim2': 200.0, 'hidden_dim3': 140.0}.
# == Status ==
# Current time: 2022-07-15 18:19:10 (running for 00:01:44.24)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=16
# Bracket: Iter 32.000: -0.1785968272804772 | Iter 16.000: -0.16150213582223163 | Iter 8.000: -0.15300688409983593 | Iter 4.000: -0.15715531120527398
# Bracket: Iter 32.000: -0.1685978036837009 | Iter 16.000: -0.14598131224062863 | Iter 8.000: -0.14298929803102525
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_18-17-26
# Number of trials: 24/50 (1 PENDING, 4 RUNNING, 19 TERMINATED)
#
#
# Trial trainable_func_91ff58c2 reported epoch=16,loss=0.1498957644096982,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'relu', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 100.0, 'hidden_dim2': 70.0, 'hidden_dim3': 130.0}.
# Trial trainable_func_9573e5ae reported epoch=7,loss=0.17221070408464975,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 8, 'hidden_dim1': 120.0, 'hidden_dim2': 200.0, 'hidden_dim3': 140.0}. This trial completed.
# Trial trainable_func_8397a910 reported epoch=45,loss=0.15084036807490375,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 110.0, 'hidden_dim2': 50.0, 'hidden_dim3': 130.0}.
# Trial trainable_func_96af0444 reported epoch=7,loss=0.1379563136430221,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 8, 'hidden_dim1': 90.0, 'hidden_dim2': 200.0, 'hidden_dim3': 140.0}.
# Trial trainable_func_983ff8ae reported epoch=0,loss=0.15979700928835763,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 8, 'hidden_dim1': 90.0, 'hidden_dim2': 200.0, 'hidden_dim3': 80.0}.
# == Status ==
# Current time: 2022-07-15 18:19:16 (running for 00:01:49.93)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=17
# Bracket: Iter 32.000: -0.1785968272804772 | Iter 16.000: -0.16150213582223163 | Iter 8.000: -0.153196723050752 | Iter 4.000: -0.15715531120527398
# Bracket: Iter 32.000: -0.1685978036837009 | Iter 16.000: -0.14598131224062863 | Iter 8.000: -0.13831676277045324
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_18-17-26
# Number of trials: 25/50 (1 PENDING, 4 RUNNING, 20 TERMINATED)
#
#
# Trial trainable_func_91ff58c2 reported epoch=21,loss=0.13543798188302839,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'relu', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 100.0, 'hidden_dim2': 70.0, 'hidden_dim3': 130.0}.
# Trial trainable_func_8397a910 reported epoch=49,loss=0.15653401864637884,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 110.0, 'hidden_dim2': 50.0, 'hidden_dim3': 130.0}. This trial completed.
# Trial trainable_func_a07687a4 reported epoch=0,loss=0.18308912127884774,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 32, 'hidden_dim1': 80.0, 'hidden_dim2': 180.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_96af0444 reported epoch=10,loss=0.14141162123758141,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 8, 'hidden_dim1': 90.0, 'hidden_dim2': 200.0, 'hidden_dim3': 140.0}.
# Trial trainable_func_983ff8ae reported epoch=3,loss=0.14107654739035086,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 8, 'hidden_dim1': 90.0, 'hidden_dim2': 200.0, 'hidden_dim3': 80.0}.
# == Status ==
# Current time: 2022-07-15 18:19:22 (running for 00:01:55.57)
# Memory usage on this node: 2.7/12.7 GiB
# Using AsyncHyperBand: num_stopped=17
# Bracket: Iter 32.000: -0.1785968272804772 | Iter 16.000: -0.16150213582223163 | Iter 8.000: -0.153196723050752 | Iter 4.000: -0.15532373683638862
# Bracket: Iter 32.000: -0.1685978036837009 | Iter 16.000: -0.14598131224062863 | Iter 8.000: -0.13831676277045324
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_18-17-26
# Number of trials: 26/50 (1 PENDING, 4 RUNNING, 21 TERMINATED)
#
#
# Trial trainable_func_91ff58c2 reported epoch=26,loss=0.13989514967010036,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'relu', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 100.0, 'hidden_dim2': 70.0, 'hidden_dim3': 130.0}.
# Trial trainable_func_a07687a4 reported epoch=7,loss=0.16117671513690465,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 32, 'hidden_dim1': 80.0, 'hidden_dim2': 180.0, 'hidden_dim3': 80.0}. This trial completed.
# Trial trainable_func_a407f3d0 reported epoch=0,loss=0.17257514353424624,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 90.0, 'hidden_dim2': 80.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_96af0444 reported epoch=13,loss=0.14289855260405965,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 8, 'hidden_dim1': 90.0, 'hidden_dim2': 200.0, 'hidden_dim3': 140.0}.
# == Status ==
# Current time: 2022-07-15 18:19:27 (running for 00:02:00.58)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=18
# Bracket: Iter 32.000: -0.1785968272804772 | Iter 16.000: -0.16150213582223163 | Iter 8.000: -0.15338656200166806 | Iter 4.000: -0.15532373683638862
# Bracket: Iter 32.000: -0.1685978036837009 | Iter 16.000: -0.14598131224062863 | Iter 8.000: -0.13831676277045324
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_18-17-26
# Number of trials: 27/50 (1 PENDING, 4 RUNNING, 22 TERMINATED)
#
#
# Trial trainable_func_983ff8ae reported epoch=6,loss=0.15405119532174377,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 8, 'hidden_dim1': 90.0, 'hidden_dim2': 200.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_91ff58c2 reported epoch=30,loss=0.13246521821446042,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'relu', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 100.0, 'hidden_dim2': 70.0, 'hidden_dim3': 130.0}.
# Trial trainable_func_a407f3d0 reported epoch=4,loss=0.14687467538906548,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 90.0, 'hidden_dim2': 80.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_96af0444 reported epoch=15,loss=0.15113986721292721,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 8, 'hidden_dim1': 90.0, 'hidden_dim2': 200.0, 'hidden_dim3': 140.0}. This trial completed.
# == Status ==
# Current time: 2022-07-15 18:19:32 (running for 00:02:05.68)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=19
# Bracket: Iter 32.000: -0.1785968272804772 | Iter 16.000: -0.16150213582223163 | Iter 8.000: -0.153196723050752 | Iter 4.000: -0.15532373683638862
# Bracket: Iter 32.000: -0.1474691816471174 | Iter 16.000: -0.14856058972677794 | Iter 8.000: -0.13831676277045324
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_18-17-26
# Number of trials: 28/50 (1 PENDING, 4 RUNNING, 23 TERMINATED)
#
#
# Trial trainable_func_a7c56444 reported epoch=0,loss=0.20051525197141767,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'relu', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 90.0, 'hidden_dim2': 70.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_91ff58c2 reported epoch=34,loss=0.148797020686292,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'relu', 'lr': 0.001, 'batch_size': 16, 'hidden_dim1': 100.0, 'hidden_dim2': 70.0, 'hidden_dim3': 130.0}.
# Trial trainable_func_983ff8ae reported epoch=9,loss=0.1445626846550937,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 8, 'hidden_dim1': 90.0, 'hidden_dim2': 200.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_a407f3d0 reported epoch=9,loss=0.1495875715376237,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 90.0, 'hidden_dim2': 80.0, 'hidden_dim3': 120.0}.
# == Status ==
# Current time: 2022-07-15 18:19:37 (running for 00:02:10.79)
# Memory usage on this node: 2.7/12.7 GiB
# ...
# Bracket: Iter 32.000: -0.1561525707863251 | Iter 16.000: -0.14776861360232318 | Iter 8.000: -0.14561788375087154
# Bracket: Iter 32.000: -0.20611677050903685 | Iter 16.000: -0.15854779072529004
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_18-17-26
# Number of trials: 50/50 (4 RUNNING, 46 TERMINATED)
#
#
# Trial trainable_func_e011fc5e reported epoch=31,loss=0.16001303219953175,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 8, 'hidden_dim1': 60.0, 'hidden_dim2': 100.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_f0d5e6e0 reported epoch=15,loss=0.15876473776672367,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 8, 'hidden_dim1': 60.0, 'hidden_dim2': 50.0, 'hidden_dim3': 120.0}. This trial completed.
# Trial trainable_func_f5be2672 reported epoch=3,loss=0.16034010296107726,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 8, 'hidden_dim1': 80.0, 'hidden_dim2': 50.0, 'hidden_dim3': 130.0}. This trial completed.
# Trial trainable_func_ef254b38 reported epoch=35,loss=0.12760398608884596,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 60.0, 'hidden_dim2': 90.0, 'hidden_dim3': 120.0}.
# == Status ==
# Current time: 2022-07-15 18:22:03 (running for 00:04:36.97)
# Memory usage on this node: 2.2/12.7 GiB
# Using AsyncHyperBand: num_stopped=37
# Bracket: Iter 32.000: -0.16106431236309904 | Iter 16.000: -0.154616691282405 | Iter 8.000: -0.15017853588708957 | Iter 4.000: -0.15498915962968549
# Bracket: Iter 32.000: -0.1561525707863251 | Iter 16.000: -0.14776861360232318 | Iter 8.000: -0.14561788375087154
# Bracket: Iter 32.000: -0.1830649013542843 | Iter 16.000: -0.15854779072529004
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 1.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_18-17-26
# Number of trials: 50/50 (2 RUNNING, 48 TERMINATED)
#
#
# Trial trainable_func_e011fc5e reported epoch=36,loss=0.16152934702220084,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 8, 'hidden_dim1': 60.0, 'hidden_dim2': 100.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_ef254b38 reported epoch=46,loss=0.12107078132315598,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 60.0, 'hidden_dim2': 90.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_ef254b38 reported epoch=49,loss=0.12055114014021562,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 60.0, 'hidden_dim2': 90.0, 'hidden_dim3': 120.0}. This trial completed.
# == Status ==
# Current time: 2022-07-15 18:22:08 (running for 00:04:42.08)
# Memory usage on this node: 2.2/12.7 GiB
# Using AsyncHyperBand: num_stopped=37
# Bracket: Iter 32.000: -0.16106431236309904 | Iter 16.000: -0.154616691282405 | Iter 8.000: -0.15017853588708957 | Iter 4.000: -0.15498915962968549
# Bracket: Iter 32.000: -0.1561525707863251 | Iter 16.000: -0.14776861360232318 | Iter 8.000: -0.14561788375087154
# Bracket: Iter 32.000: -0.1830649013542843 | Iter 16.000: -0.15854779072529004
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 1.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_18-17-26
# Number of trials: 50/50 (2 RUNNING, 48 TERMINATED)
#
#
# Trial trainable_func_e011fc5e reported epoch=44,loss=0.16831963286044158,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 8, 'hidden_dim1': 60.0, 'hidden_dim2': 100.0, 'hidden_dim3': 120.0}.
# 2022-07-15 18:22:12,321	INFO tune.py:748 -- Total run time: 285.76 seconds (285.59 seconds for the tuning loop).
# Trial trainable_func_e011fc5e reported epoch=49,loss=0.1772749468822609,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 8, 'hidden_dim1': 60.0, 'hidden_dim2': 100.0, 'hidden_dim3': 120.0}. This trial completed.
# == Status ==
# Current time: 2022-07-15 18:22:12 (running for 00:04:45.62)
# Memory usage on this node: 1.9/12.7 GiB
# Using AsyncHyperBand: num_stopped=37
# Bracket: Iter 32.000: -0.16106431236309904 | Iter 16.000: -0.154616691282405 | Iter 8.000: -0.15017853588708957 | Iter 4.000: -0.15498915962968549
# Bracket: Iter 32.000: -0.1561525707863251 | Iter 16.000: -0.14776861360232318 | Iter 8.000: -0.14561788375087154
# Bracket: Iter 32.000: -0.1830649013542843 | Iter 16.000: -0.15854779072529004
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_18-17-26
# Number of trials: 50/50 (50 TERMINATED)
# +-------------------------+------------+------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# | Trial name              | status     | loc              | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |     loss |   training_iteration |
# |-------------------------+------------+------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------|
# | trainable_func_616c511a | TERMINATED | 172.28.0.2:11381 | selu    | relu   | tanh   |           16 |            70 |           150 |            50 | 0.0005 | 0.207852 |                   50 |
# | trainable_func_6189c51a | TERMINATED | 172.28.0.2:11382 | relu    | tanh   | relu   |            8 |           180 |           120 |           200 | 0.0008 | 0.175824 |                   16 |
# | trainable_func_618d4a14 | TERMINATED | 172.28.0.2:11444 | selu    | relu   | tanh   |           16 |           180 |           130 |           180 | 0.0008 | 0.189623 |                    4 |
# | trainable_func_6191d9d0 | TERMINATED | 172.28.0.2:11433 | relu    | tanh   | relu   |            8 |           160 |           100 |           200 | 0.001  | 0.171355 |                    4 |
# | trainable_func_61955f92 | TERMINATED | 172.28.0.2:11444 | relu    | relu   | tanh   |            8 |           140 |           160 |           170 | 0.0006 | 0.177802 |                    4 |
# | trainable_func_6a6bed3e | TERMINATED | 172.28.0.2:11433 | relu    | tanh   | tanh   |            8 |            50 |           180 |           160 | 0.0006 | 0.178817 |                    4 |
# | trainable_func_6c1c0e2a | TERMINATED | 172.28.0.2:11444 | selu    | tanh   | relu   |           32 |            70 |           120 |           100 | 0.0009 | 0.185539 |                   50 |
# | trainable_func_6e307bec | TERMINATED | 172.28.0.2:11433 | tanh    | tanh   | tanh   |            8 |           200 |           200 |           130 | 0.0007 | 0.153007 |                    8 |
# | trainable_func_6fcc5b24 | TERMINATED | 172.28.0.2:11382 | relu    | relu   | relu   |           16 |           100 |            70 |           110 | 0.001  | 0.153387 |                    8 |
# | trainable_func_75aafed8 | TERMINATED | 172.28.0.2:11433 | relu    | selu   | selu   |           32 |           190 |            80 |           150 | 0.0008 | 0.154902 |                    8 |
# | trainable_func_784894a2 | TERMINATED | 172.28.0.2:11382 | tanh    | selu   | selu   |           16 |           150 |           110 |           190 | 0.0008 | 0.163772 |                    4 |
# | trainable_func_7a3a9eb8 | TERMINATED | 172.28.0.2:11433 | selu    | selu   | relu   |            8 |           200 |           110 |           100 | 0.0007 | 0.157787 |                    8 |
# | trainable_func_7b6f2d9e | TERMINATED | 172.28.0.2:11382 | selu    | tanh   | selu   |           32 |           190 |            90 |           180 | 0.0006 | 0.183889 |                   50 |
# | trainable_func_7c8bb53a | TERMINATED | 172.28.0.2:11444 | selu    | tanh   | relu   |           16 |           140 |           160 |           100 | 0.0006 | 0.161996 |                    8 |
# | trainable_func_80d3aef4 | TERMINATED | 172.28.0.2:11381 | tanh    | tanh   | tanh   |            8 |           110 |           200 |            50 | 0.0005 | 0.16705  |                   16 |
# | trainable_func_81c580d0 | TERMINATED | 172.28.0.2:11433 | tanh    | relu   | relu   |           16 |           110 |            50 |           110 | 0.0007 | 0.190807 |                   32 |
# | trainable_func_8397a910 | TERMINATED | 172.28.0.2:11444 | tanh    | relu   | tanh   |           16 |           110 |            50 |           130 | 0.001  | 0.156534 |                   50 |
# | trainable_func_858d24de | TERMINATED | 172.28.0.2:11382 | tanh    | relu   | tanh   |           16 |           110 |            50 |           130 | 0.001  | 0.147662 |                    8 |
# | trainable_func_90aae004 | TERMINATED | 172.28.0.2:11381 | tanh    | relu   | tanh   |           16 |           110 |            50 |           120 | 0.001  | 0.154677 |                    8 |
# | trainable_func_91ff58c2 | TERMINATED | 172.28.0.2:11382 | tanh    | relu   | relu   |           16 |           100 |            70 |           130 | 0.001  | 0.135539 |                   50 |
# | trainable_func_95568fe0 | TERMINATED | 172.28.0.2:11433 | tanh    | relu   | tanh   |           16 |           110 |            60 |           140 | 0.0009 | 0.160221 |                    4 |
# | trainable_func_9573e5ae | TERMINATED | 172.28.0.2:11381 | tanh    | relu   | tanh   |            8 |           120 |           200 |           140 | 0.0009 | 0.172211 |                    8 |
# | trainable_func_96af0444 | TERMINATED | 172.28.0.2:11433 | tanh    | relu   | tanh   |            8 |            90 |           200 |           140 | 0.0009 | 0.15114  |                   16 |
# | trainable_func_983ff8ae | TERMINATED | 172.28.0.2:11381 | tanh    | selu   | tanh   |            8 |            90 |           200 |            80 | 0.0009 | 0.187285 |                   32 |
# | trainable_func_a07687a4 | TERMINATED | 172.28.0.2:11444 | tanh    | selu   | tanh   |           32 |            80 |           180 |            80 | 0.0007 | 0.161177 |                    8 |
# | trainable_func_a407f3d0 | TERMINATED | 172.28.0.2:11444 | tanh    | relu   | tanh   |           16 |            90 |            80 |           120 | 0.0009 | 0.149556 |                   16 |
# | trainable_func_a7c56444 | TERMINATED | 172.28.0.2:11433 | relu    | relu   | relu   |           16 |            90 |            70 |            80 | 0.0009 | 0.17201  |                   50 |
# | trainable_func_ac0d2a46 | TERMINATED | 172.28.0.2:11444 | tanh    | relu   | tanh   |            8 |            80 |           180 |           130 | 0.0009 | 0.171516 |                    4 |
# | trainable_func_b332c592 | TERMINATED | 172.28.0.2:11382 | tanh    | relu   | tanh   |           16 |            90 |            70 |            80 | 0.0009 | 0.174868 |                   50 |
# | trainable_func_b7f2247e | TERMINATED | 172.28.0.2:11444 | tanh    | relu   | selu   |           16 |            90 |            70 |            70 | 0.001  | 0.189482 |                   50 |
# | trainable_func_b80dcb52 | TERMINATED | 172.28.0.2:11381 | tanh    | relu   | selu   |           16 |            50 |            70 |            80 | 0.001  | 0.163121 |                    8 |
# | trainable_func_c89a69ee | TERMINATED | 172.28.0.2:11433 | tanh    | relu   | selu   |           16 |            50 |            80 |           150 | 0.001  | 0.166404 |                    4 |
# | trainable_func_cc5e79da | TERMINATED | 172.28.0.2:11381 | tanh    | relu   | selu   |           16 |           130 |            80 |           160 | 0.001  | 0.169944 |                    4 |
# | trainable_func_cd7c87f8 | TERMINATED | 172.28.0.2:11433 | tanh    | relu   | selu   |           16 |           130 |            80 |           160 | 0.001  | 0.169045 |                   16 |
# | trainable_func_ced068a4 | TERMINATED | 172.28.0.2:11381 | tanh    | relu   | relu   |           16 |           130 |            90 |           120 | 0.001  | 0.161953 |                    8 |
# | trainable_func_cfe25c52 | TERMINATED | 172.28.0.2:11381 | tanh    | relu   | tanh   |           16 |            90 |           140 |           140 | 0.0009 | 0.175526 |                    4 |
# | trainable_func_d48f6b64 | TERMINATED | 172.28.0.2:11381 | tanh    | relu   | tanh   |           16 |            90 |            60 |           140 | 0.0009 | 0.153007 |                    8 |
# | trainable_func_d7646704 | TERMINATED | 172.28.0.2:11444 | tanh    | relu   | tanh   |           16 |            70 |            60 |           110 | 0.0009 | 0.165612 |                    4 |
# | trainable_func_d7e71de8 | TERMINATED | 172.28.0.2:11382 | tanh    | relu   | tanh   |           16 |            70 |            60 |           110 | 0.0008 | 0.164427 |                    4 |
# | trainable_func_d8a7aea0 | TERMINATED | 172.28.0.2:11433 | tanh    | relu   | tanh   |           16 |            60 |            60 |           110 | 0.0008 | 0.149769 |                    8 |
# | trainable_func_d8ca88bc | TERMINATED | 172.28.0.2:11444 | tanh    | relu   | tanh   |           32 |            70 |            60 |           110 | 0.0008 | 0.166529 |                   50 |
# | trainable_func_da899364 | TERMINATED | 172.28.0.2:11382 | tanh    | relu   | tanh   |           32 |            60 |           100 |           150 | 0.0008 | 0.200158 |                   50 |
# | trainable_func_db0843c6 | TERMINATED | 172.28.0.2:11381 | selu    | relu   | tanh   |           32 |           100 |           130 |           150 | 0.0008 | 0.161565 |                    8 |
# | trainable_func_dcb337f8 | TERMINATED | 172.28.0.2:11433 | selu    | relu   | relu   |            8 |           100 |           100 |           150 | 0.0008 | 0.157688 |                    4 |
# | trainable_func_dd60236e | TERMINATED | 172.28.0.2:11381 | selu    | relu   | relu   |           32 |            60 |            90 |           120 | 0.0008 | 0.157119 |                   50 |
# | trainable_func_e011fc5e | TERMINATED | 172.28.0.2:11433 | tanh    | relu   | tanh   |            8 |            60 |           100 |           120 | 0.0008 | 0.177275 |                   50 |
# | trainable_func_e1ab21c6 | TERMINATED | 172.28.0.2:11444 | tanh    | relu   | tanh   |           16 |            80 |            50 |           120 | 0.0009 | 0.164836 |                   32 |
# | trainable_func_ef254b38 | TERMINATED | 172.28.0.2:11382 | relu    | relu   | tanh   |           16 |            60 |            90 |           120 | 0.0009 | 0.120551 |                   50 |
# | trainable_func_f0d5e6e0 | TERMINATED | 172.28.0.2:11381 | relu    | relu   | tanh   |            8 |            60 |            50 |           120 | 0.0009 | 0.158765 |                   16 |
# | trainable_func_f5be2672 | TERMINATED | 172.28.0.2:11444 | relu    | relu   | tanh   |            8 |            80 |            50 |           130 | 0.0009 | 0.16034  |                    4 |
# +-------------------------+------------+------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
#
#
# Best trial config: {'act1 ': 'relu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 60.0, 'hidden_dim2': 90.0, 'hidden_dim3': 120.0}
# Best trial final validation score: 0.12055114014021562
# Best trial test set score: 0.0

# %% [markdown]
# # Other Schedulers and search algorithms of Ray Tune

# %%
# !pip install -U hyperopt
# !pip install hpbandster ConfigSpace
# !pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.7/dist-packages (0.1.2)
# Collecting hyperopt
#   Downloading hyperopt-0.2.7-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 28.0 MB/s
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from hyperopt) (1.3.0)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.7/dist-packages (from hyperopt) (2.6.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from hyperopt) (1.21.6)
# Collecting py4j
#   Downloading py4j-0.10.9.5-py2.py3-none-any.whl (199 kB)
#      |████████████████████████████████| 199 kB 61.4 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from hyperopt) (4.64.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from hyperopt) (1.15.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from hyperopt) (1.7.3)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from hyperopt) (0.16.0)
# Installing collected packages: py4j, hyperopt
#   Attempting uninstall: hyperopt
#     Found existing installation: hyperopt 0.1.2
#     Uninstalling hyperopt-0.1.2:
#       Successfully uninstalled hyperopt-0.1.2
# Successfully installed hyperopt-0.2.7 py4j-0.10.9.5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting hpbandster
#   Downloading hpbandster-0.7.4.tar.gz (51 kB)
#      |████████████████████████████████| 51 kB 115 kB/s
# Collecting ConfigSpace
#   Downloading ConfigSpace-0.5.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 30.2 MB/s
# Collecting Pyro4
#   Downloading Pyro4-4.82-py2.py3-none-any.whl (89 kB)
#      |████████████████████████████████| 89 kB 8.7 MB/s
# Collecting serpent
#   Downloading serpent-1.41-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from hpbandster) (1.21.6)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.7/dist-packages (from hpbandster) (0.10.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from hpbandster) (1.7.3)
# Collecting netifaces
#   Downloading netifaces-0.11.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (32 kB)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from ConfigSpace) (3.0.9)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from ConfigSpace) (0.29.30)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from statsmodels->hpbandster) (1.3.5)
# Requirement already satisfied: patsy>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from statsmodels->hpbandster) (0.5.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->statsmodels->hpbandster) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->statsmodels->hpbandster) (2.8.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.4.0->statsmodels->hpbandster) (1.15.0)
# Building wheels for collected packages: hpbandster
#   Building wheel for hpbandster (setup.py) ... done
#   Created wheel for hpbandster: filename=hpbandster-0.7.4-py3-none-any.whl size=80006 sha256=312b73b4d51dd2adf93c5ff2e22cef4d808f4a3c9d112807416e81401f85801a
#   Stored in directory: /root/.cache/pip/wheels/d9/88/fc/61ab6b9f386a386839668631c39a6dc3c2fb0ec7000d552faa
# Successfully built hpbandster
# Installing collected packages: serpent, Pyro4, netifaces, ConfigSpace, hpbandster
# Successfully installed ConfigSpace-0.5.0 Pyro4-4.82 hpbandster-0.7.4 netifaces-0.11.0 serpent-1.41
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: optuna in /usr/local/lib/python3.7/dist-packages (2.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (21.3)
# Requirement already satisfied: cliff in /usr/local/lib/python3.7/dist-packages (from optuna) (3.10.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.7/dist-packages (from optuna) (6.6.0)
# Requirement already satisfied: cmaes>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from optuna) (0.8.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from optuna) (4.64.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from optuna) (3.13)
# Requirement already satisfied: scipy!=1.4.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.7.3)
# Requirement already satisfied: alembic in /usr/local/lib/python3.7/dist-packages (from optuna) (1.8.1)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.4.39)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from optuna) (1.21.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->optuna) (3.0.9)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (1.1.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (4.12.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.7/dist-packages (from alembic->optuna) (1.2.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from alembic->optuna) (5.8.0)
# Requirement already satisfied: autopage>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (0.5.1)
# Requirement already satisfied: cmd2>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (2.4.2)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (5.9.0)
# Requirement already satisfied: stevedore>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (3.5.0)
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (3.3.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (4.1.1)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (0.2.5)
# Requirement already satisfied: pyperclip>=1.6 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (1.8.2)
# Requirement already satisfied: attrs>=16.3.0 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (21.4.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy>=1.1.0->optuna) (3.8.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from Mako->alembic->optuna) (2.0.1)

# %%
from ray.tune.suggest.hyperopt import HyperOptSearch
from ray.tune.suggest.optuna import OptunaSearch  
from ray.tune.suggest.dragonfly import DragonflySearch
from ray.tune.suggest.bayesopt import BayesOptSearch
from ray.tune.schedulers.hb_bohb import HyperBandForBOHB
from ray.tune.schedulers import AsyncHyperBandScheduler
from ray.tune.schedulers import MedianStoppingRule
from ray.tune.schedulers import PopulationBasedTraining
from ray.tune.suggest.bohb import TuneBOHB
from ray.tune.suggest.basic_variant import BasicVariantGenerator
from ray.tune.suggest import ConcurrencyLimiter
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# **Schedulers**

# %%
training_iteration = 50 #max_num_epochs

## ASHA
scheduler = AsyncHyperBandScheduler(
    time_attr="training_iteration",
    max_t=training_iteration,
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    reduction_factor=2, 
    grace_period=4,
    brackets=5,
    )

## BOHB
scheduler = HyperBandForBOHB(
    time_attr="training_iteration",
    max_t=training_iteration, 
    reduction_factor=8, 
    stop_last_trials=True,
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    )

## Median
scheduler = MedianStoppingRule(
    time_attr="training_iteration",
    grace_period=10,
    min_samples_required=10,
    hard_stop = True,
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    )

## PBT
scheduler = PopulationBasedTraining(
    time_attr="training_iteration",
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    perturbation_interval=10,  # every 10 `time_attr` units
                            # (training_iterations in this case)
    # hyperparam_mutations={
    #     "lr": [8e-3, 7e-3, 6e-3, 5e-3, 4e-3],
    #     "dropout": tune.quniform(0.0, 0.4, 0.05),
    #     "dropout1": tune.quniform(0.0, 0.4, 0.05),
    #     "dropout2": tune.quniform(0.0, 0.4, 0.05),
    #     "max_norm_val":tune.choice([2.5, 3, 3.5, 4]),
    #     }
    )

# %% [markdown]
# # Search algorithms

# %%
pip install dragonfly-opt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting dragonfly-opt
#   Downloading dragonfly-opt-0.1.6.tar.gz (252 kB)
#      |████████████████████████████████| 252 kB 12.4 MB/s
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from dragonfly-opt) (0.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from dragonfly-opt) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from dragonfly-opt) (1.7.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from dragonfly-opt) (1.15.0)
# Building wheels for collected packages: dragonfly-opt
#   Building wheel for dragonfly-opt (setup.py) ... done
#   Created wheel for dragonfly-opt: filename=dragonfly_opt-0.1.6-cp37-cp37m-linux_x86_64.whl size=411419 sha256=f901a3843dcc753c19e6a83e33712e1520b1215d749c90e513a956fe8c4650f8
#   Stored in directory: /root/.cache/pip/wheels/bb/79/94/461f622bdd697be30dfe11c2590b574deee78320aa6f5cc2ba
# Successfully built dragonfly-opt
# Installing collected packages: dragonfly-opt
# Successfully installed dragonfly-opt-0.1.6

# %%
from ray.tune.suggest.dragonfly import DragonflySearch as DragonflySearch1

# %%
## BOHB
search_alg = TuneBOHB(
    # space=config_space,  # If you want to set the space manually
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    # seed = 42,
    # points_to_evaluate=[
    # ],
    )

## Hyperopt
search_alg = HyperOptSearch(
    # space=config,
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    n_initial_points=60,
    # gamma = 0.1,
    # random_state_seed=42,
    # points_to_evaluate=[{"max_norm_val": 2.5, 'GNN_Layers': 3, 'dropout': 0.25, 'dropout1': 0.35, 'dropout2': 0.15, 'lr': 0.001, 'hidden_size': 80, 'readout1_out': 150, 'readout2_out': 100, 'batch_size': 64}],
    )

## Optuna
search_alg = OptunaSearch(
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    # seed = 42,
    # points_to_evaluate=[
    # {'dropout': 0.2, 'dropout1': 0.1, 'dropout2': 0.25, 'lr': 0.0005, 'hidden_size': 150.0, 'readout1_out': 200.0, 'readout2_out': 180.0, 'max_norm_val': 2.5}
    # ],
    )

## Dragonfly
#search_alg = DragonflySearch1(
#    metric="loss", #or accuracy, etc.
#    mode="min", #or max
#    optimizer="bandit", #[random, bandit, genetic]
    # points_to_evaluate=[
    # {'max_norm_val': 2.5, 'dropout': 0.3, 'dropout1': 0.1, 'dropout2': 0.0, 'lr': 0.0008, 'hidden_size': 90, 'readout1_out': 150, 'readout2_out': 140}
    # ],
    # domain=euclidean, #[cartesian, euclidean]
#    )

## Bayesopt
#search_alg = BayesOptSearch(
#    metric="loss", #or accuracy, etc.
#    mode="min", #or max
#    random_search_steps = 60, 
    # points_to_evaluate=[
    # {'max_norm_val': 2.5, 'dropout': 0.3, 'dropout1': 0.1, 'dropout2': 0.0, 'lr': 0.0008, 'hidden_size': 90, 'readout1_out': 150, 'readout2_out': 140}
    # ],
#    )
