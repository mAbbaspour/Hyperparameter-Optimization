# %% [markdown]
# <a href="https://colab.research.google.com/github/mAbbaspour/Hyperparameter-Optimization/blob/main/Bace(7nd_versian)(multi_layers_version).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset
from pandas import read_csv
from sklearn.impute import SimpleImputer
import pandas as pd
import io
#visualizations
import matplotlib as mpl
import matplotlib.pyplot as plt
import random

# %%
from google.colab import files
uploaded1 = files.upload()
# Out:
#      <input type="file" id="files-bd56e80c-1b6e-4f75-aef9-8628bc29d145" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bd56e80c-1b6e-4f75-aef9-8628bc29d145">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bace(lables).csv to bace(lables) (1).csv

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9282f1d2-100b-4109-a441-c9f34f70742b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9282f1d2-100b-4109-a441-c9f34f70742b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bace_global_cdf_rdkit.csv to bace_global_cdf_rdkit (1).csv

# %%
dataX = pd.read_csv(io.BytesIO(uploaded['bace_global_cdf_rdkit.csv']))
dataX.head()
# Out:
#    ('RDKit2DNormalized_calculated', <class 'bool'>)  \
# 0                                              True
# 1                                              True
# 2                                              True
# 3                                              True
# 4                                              True
#
#    ('BalabanJ', <class 'numpy.float64'>)  \
# 0                               0.271693
# 1                               0.392419
# 2                               0.149225
# 3                               0.577532
# 4                               0.138106
#
#    ('BertzCT', <class 'numpy.float64'>)  ('Chi0', <class 'numpy.float64'>)  \
# 0                              0.685231                           0.715429
# 1                              0.830920                           0.964192
# 2                              0.951733                           0.924019
# 3                              0.782187                           0.924370
# 4                              0.967050                           0.945002
#
#    ('Chi0n', <class 'numpy.float64'>)  ('Chi0v', <class 'numpy.float64'>)  \
# 0                            0.780380                            0.750726
# 1                            0.966658                            0.963590
# 2                            0.927351                            0.932271
# 3                            0.906913                            0.913072
# 4                            0.930853                            0.935559
#
#    ('Chi1', <class 'numpy.float64'>)  ('Chi1n', <class 'numpy.float64'>)  \
# 0                           0.689887                            0.776209
# 1                           0.957524                            0.968433
# 2                           0.923493                            0.923177
# 3                           0.876879                            0.885455
# 4                           0.936328                            0.928579
#
#    ('Chi1v', <class 'numpy.float64'>)  ('Chi2n', <class 'numpy.float64'>)  \
# 0                            0.716683                            0.850783
# 1                            0.959626                            0.970019
# 2                            0.942919                            0.908699
# 3                            0.922284                            0.928759
# 4                            0.946799                            0.921161
#
#    ...  ('fr_sulfonamd', <class 'numpy.float64'>)  \
# 0  ...                               1.593061e-17
# 1  ...                               1.593061e-17
# 2  ...                               9.999565e-01
# 3  ...                               1.593061e-17
# 4  ...                               9.999565e-01
#
#    ('fr_sulfone', <class 'numpy.float64'>)  \
# 0                             5.766101e-14
# 1                             5.766101e-14
# 2                             5.766101e-14
# 3                             1.000000e+00
# 4                             5.766101e-14
#
#    ('fr_term_acetylene', <class 'numpy.float64'>)  \
# 0                                    2.957989e-11
# 1                                    2.957989e-11
# 2                                    2.957989e-11
# 3                                    2.957989e-11
# 4                                    2.957989e-11
#
#    ('fr_tetrazole', <class 'numpy.float64'>)  \
# 0                                   0.168378
# 1                                   0.168378
# 2                                   0.168378
# 3                                   0.168378
# 4                                   0.168378
#
#    ('fr_thiazole', <class 'numpy.float64'>)  \
# 0                                   0.16738
# 1                                   0.16738
# 2                                   0.16738
# 3                                   0.16738
# 4                                   0.16738
#
#    ('fr_thiocyan', <class 'numpy.float64'>)  \
# 0                              1.481515e-18
# 1                              1.481515e-18
# 2                              1.481515e-18
# 3                              1.481515e-18
# 4                              1.481515e-18
#
#    ('fr_thiophene', <class 'numpy.float64'>)  \
# 0                               2.324150e-16
# 1                               2.324150e-16
# 2                               2.324150e-16
# 3                               2.324150e-16
# 4                               2.324150e-16
#
#    ('fr_unbrch_alkane', <class 'numpy.float64'>)  \
# 0                                   4.703598e-08
# 1                                   4.703598e-08
# 2                                   4.703598e-08
# 3                                   4.703598e-08
# 4                                   4.703598e-08
#
#    ('fr_urea', <class 'numpy.float64'>)  ('qed', <class 'numpy.float64'>)
# 0                              0.166633                          0.494794
# 1                              0.166633                          0.072174
# 2                              0.166633                          0.090157
# 3                              0.166633                          0.121917
# 4                              0.166633                          0.091591
#
# [5 rows x 201 columns]

# %%
dataY = pd.read_csv(io.BytesIO(uploaded1['bace(lables).csv']))
dataY.head()
# Out:
#                                                  mol  Class
# 0  O1CC[C@@H](NC(=O)[C@@H](Cc2cc3cc(ccc3nc2N)-c2c...      1
# 1  Fc1cc(cc(F)c1)C[C@H](NC(=O)[C@@H](N1CC[C@](NC(...      1
# 2  S1(=O)(=O)N(c2cc(cc3c2n(cc3CC)CC1)C(=O)N[C@H](...      1
# 3  S1(=O)(=O)C[C@@H](Cc2cc(O[C@H](COCC)C(F)(F)F)c...      1
# 4  S1(=O)(=O)N(c2cc(cc3c2n(cc3CC)CC1)C(=O)N[C@H](...      1

# %%
#del dataX["('RDKit2DNormalized_calculated', <class 'bool'>)"]

dataX.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1513 entries, 0 to 1512
# Columns: 201 entries, ('RDKit2DNormalized_calculated', <class 'bool'>) to ('qed', <class 'numpy.float64'>)
# dtypes: bool(1), float64(200)
# memory usage: 2.3 MB

# %%
Y = dataY.iloc[:, 1]

# %%
Y.value_counts()
# Out:
# 0    822
# 1    691
# Name: Class, dtype: int64

# %%
Y.value_counts().plot(kind='bar')

# %%
dataX.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# **Corrolation** **matrix**

# %%
# corr_matrix = dataX.corr()
#  #This approach is fatsitc it looks at the previous column if the correlation is high it removes it

# # Create correlation matrix
# corr_matrix = dataX.corr().abs()

# # Select upper triangle of correlation matrix
# upper = corr_matrix.where(
#     np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

# # Find features with correlation greater than 0.90
# to_drop = [column for column in upper.columns if any(upper[column] > 0.90)]

# # Drop features
# data = dataX.drop(to_drop, axis=1)
# data

# %% [markdown]
# **Split** **Data**

# %%
random.seed(1234)

# %%
# %%capture
try:
    from featurewiz import featurewiz
except:
    # !pip install featurewiz==0.1.70
    from featurewiz import featurewiz

# %%
from sklearn.model_selection import train_test_split
X=dataX.iloc[:,1:201]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.15,random_state=1234)

# %%
# X_train = np.array(X_train)
# X_test = np.array(X_test)
# Y_train = np.array(Y_train)
# Y_test = np.array(Y_test)

# %% [markdown]
# **Scaling** **data**

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import random
# np.random.seed(10)
# scaler = StandardScaler()
# scaler.fit(X_train)
# X_train_scaled = scaler.transform(X_train)
# X_test_scaled = scaler.transform(X_test)
from sklearn import preprocessing

scaler_data = preprocessing.MinMaxScaler()
X_train = scaler_data.fit_transform(X_train)
X_test = scaler_data.transform(X_test)
scaler_labels = preprocessing.MinMaxScaler()
Y_train = scaler_labels.fit_transform(Y_train.values.reshape(-1, 1))
Y_test = scaler_labels.transform(Y_test.values.reshape(-1, 1))

# print(X_train.shape, Y_train.shape, X_test.shape, Y_test.shape)
#print(X_train)
#print("Train labels before scaling: {} {} {}Train labels after scaling: {} {}".format('\n',train_labels_before,'\n', '\n', train_labels))

# %% [markdown]
# **PCA**

# %%
# from sklearn.decomposition import PCA as sklearnPCA
# pca = sklearnPCA(n_components=40)
# pca.fit(X_train)
# X_train=pca.transform(X_train)
# X_test=pca.transform(X_test)
# #print(pca.explained_variance_ratio_)
# plt.plot(np.arange(40),pca.explained_variance_ratio_)
# plt.show()

# X_test.shape

# %% [markdown]
# **transform** **to** **torch** **tensor**

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
# transform to torch tensor

tensor_x = torch.tensor(X_train, dtype=torch.float).to(device) 
tensor_x2 = torch.tensor(X_test, dtype=torch.float).to(device) 

tensor_y = torch.tensor(Y_train, dtype=torch.float).to(device)
tensor_y2 = torch.tensor(Y_test, dtype=torch.float).to(device)

# %%
# create your dataset

trainset = TensorDataset(tensor_x, tensor_y) 
testset = TensorDataset(tensor_x2,tensor_y2)

# %%
trainset

# %%
# %%capture
try:
    import ray
except:
    # !pip install -U ray
    import ray

# %%
from functools import partial
import numpy as np
import os
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import random_split
from torchsummary import summary

from ray import tune
from ray.tune import CLIReporter
from ray.tune.schedulers import ASHAScheduler

# %%
def load_data(data_dir=None):
    return trainset, testset

# %%
from sklearn.metrics import roc_auc_score

def compute_score(model, data_loader, device="cpu"):
    model.eval()
    metric = roc_auc_score
    with torch.no_grad():
        prediction_all= torch.empty(0, device=device)
        labels_all= torch.empty(0, device=device)
        for i, (feats, labels) in enumerate(data_loader):
            feats=feats.to(device)
            labels=labels.to(device)
            prediction = model(feats).to(device)
            prediction = torch.sigmoid(prediction).to(device)
            prediction_all = torch.cat((prediction_all, prediction), 0)
            labels_all = torch.cat((labels_all, labels), 0)                
        try:
            t = metric(labels_all.int().cpu(), prediction_all.cpu()).item()
        except ValueError:
            t = 0
    return t

# %%
class Net(nn.Module):
    def __init__(self, config):
        super().__init__()
        
        self.config = config
        self.hidden_dim1 = int(self.config.get("hidden_dim1", 100))
        self.hidden_dim2 = int(self.config.get("hidden_dim2", 100))
        self.hidden_dim3 = int(self.config.get("hidden_dim3", 100))
        self.hidden_dim4 = int(self.config.get("hidden_dim4", 100))
        self.hidden_dim5 = int(self.config.get("hidden_dim5", 100))
        self.hidden_dim6 = int(self.config.get("hidden_dim6", 100)) 
        self.hidden_dim7 = int(self.config.get("hidden_dim7", 100))
        self.hidden_dim8 = int(self.config.get("hidden_dim8", 100))

        self.act1 = self.config.get("act1", "relu") 
        self.act2 = self.config.get("act2", "relu") 
        self.act3 = self.config.get("act3", "relu")
        self.act4 = self.config.get("act4", "relu") 
        self.act5 = self.config.get("act5", "relu") 
        self.act6 = self.config.get("act6", "relu")
        self.act7 = self.config.get("act7", "relu") 
        self.act8 = self.config.get("act8", "relu")
        
        self.linear1 = nn.Linear(200, self.hidden_dim1)
        self.linear2 = nn.Linear(self.hidden_dim1, self.hidden_dim2)
        self.linear3 = nn.Linear(self.hidden_dim2, self.hidden_dim3)
        self.linear4 = nn.Linear(self.hidden_dim3, self.hidden_dim4)
        self.linear5 = nn.Linear(self.hidden_dim4, self.hidden_dim5)
        self.linear6 = nn.Linear(self.hidden_dim5, self.hidden_dim6)
        self.linear7 = nn.Linear(self.hidden_dim6, self.hidden_dim7)
        self.linear8 = nn.Linear(self.hidden_dim7, self.hidden_dim8)
        self.linear9 = nn.Linear(self.hidden_dim8, 1)
    
    @staticmethod
    def activation_func(act_str):
        if act_str=="tanh" or act_str=="sigmoid":
            return eval("torch."+act_str)
        elif act_str=="silu" or act_str=="relu" or act_str=="leaky_relu" or act_str=="gelu":   
            return eval("torch.nn.functional."+act_str)

    def forward(self, x):
        output = self.linear1(x)
        output = self.activation_func(self.act1)(output)
        output = self.linear2(output)
        output = self.activation_func(self.act2)(output)
        output = self.linear3(output)
        output = self.activation_func(self.act3)(output)
        output = self.linear4(output)
        output = self.activation_func(self.act4)(output)
        output = self.linear5(output)
        output = self.activation_func(self.act5)(output)
        output = self.linear6(output)
        output = self.activation_func(self.act6)(output)
        output = self.linear7(output)
        output = self.activation_func(self.act7)(output)
        output = self.linear8(output)  
        output = self.activation_func(self.act8)(output)
        output = self.linear9(output)          
        output = torch.sigmoid(output)
        return output

# %%
model = Net({})

# %%
from prettytable import PrettyTable

def count_parameters(model):
    table = PrettyTable(["Modules", "Parameters"])
    total_params = 0
    for name, parameter in model.named_parameters():
        if not parameter.requires_grad: continue
        param = parameter.numel()
        table.add_row([name, param])
        total_params+=param
    print(table)
    print(f"Total Trainable Params: {total_params}")
    return total_params

# %%
summary(model, (1,tensor_x.shape[1]))

count_parameters(model)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1               [-1, 1, 100]          20,100
#             Linear-2               [-1, 1, 100]          10,100
#             Linear-3               [-1, 1, 100]          10,100
#             Linear-4               [-1, 1, 100]          10,100
#             Linear-5               [-1, 1, 100]          10,100
#             Linear-6               [-1, 1, 100]          10,100
#             Linear-7               [-1, 1, 100]          10,100
#             Linear-8               [-1, 1, 100]          10,100
#             Linear-9                 [-1, 1, 1]             101
# ================================================================
# Total params: 90,901
# Trainable params: 90,901
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.35
# Estimated Total Size (MB): 0.35
# ----------------------------------------------------------------
# +----------------+------------+
# |    Modules     | Parameters |
# +----------------+------------+
# | linear1.weight |   20000    |
# |  linear1.bias  |    100     |
# | linear2.weight |   10000    |
# |  linear2.bias  |    100     |
# | linear3.weight |   10000    |
# |  linear3.bias  |    100     |
# | linear4.weight |   10000    |
# |  linear4.bias  |    100     |
# | linear5.weight |   10000    |
# |  linear5.bias  |    100     |
# | linear6.weight |   10000    |
# |  linear6.bias  |    100     |
# | linear7.weight |   10000    |
# |  linear7.bias  |    100     |
# | linear8.weight |   10000    |
# |  linear8.bias  |    100     |
# | linear9.weight |    100     |
# |  linear9.bias  |     1      |
# +----------------+------------+
# Total Trainable Params: 90901
# 90901

# %%
def trainable_func(config, checkpoint_dir=None, data_dir=None, epochs=10):

    net = Net(config)

    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda:0"
        if torch.cuda.device_count() > 1:
            net = nn.DataParallel(net)
    net.to(device)

    '''
    Define a loss function
    '''
    ## Classification
    criterion = nn.CrossEntropyLoss()
    #criterion=nn.BCELoss()

    ## Regression
    #criterion = nn.MSELoss(reduction='sum')

    # Define an optimizer 
    #optimizer = torch.optim.SGD(net.parameters(), lr=config.get("lr",0.0003),momentum=0.9)
    optimizer = optim.Adam(net.parameters(), lr=config.get("lr",0.0003))
    if checkpoint_dir:
        model_state, optimizer_state = torch.load(
            os.path.join(checkpoint_dir, "checkpoint"))
        net.load_state_dict(model_state)
        optimizer.load_state_dict(optimizer_state)

    # Load data
    trainset, testset = load_data(data_dir)

    # Split the dataset into training and validation sets
    train_size = int(len(trainset) * 0.825)
    train_subset, val_subset = random_split(trainset, [train_size, len(trainset) - train_size])

    # Define data loaders (which combines a dataset and a sampler, and provides an iterable over the given dataset)
    trainloader = torch.utils.data.DataLoader(
        train_subset,
        batch_size=int(config.get("batch_size",32)),
        shuffle=False,
        num_workers=2)
    valloader = torch.utils.data.DataLoader(
        val_subset,
        batch_size=int(config.get("batch_size",32)),
        shuffle=False,
        num_workers=2)

    for epoch in range(epochs):  # loop over the dataset multiple times
        epoch_train_loss = 0.0
        # epoch_steps = 0
        net.train() # Prepare model for training
        for i, data in enumerate(trainloader):
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            '''
            Compute train loss without scaling to print
            ''' 

        score = compute_score(net, valloader, device="cpu")
        with tune.checkpoint_dir(epoch) as checkpoint_dir:
            path = os.path.join(checkpoint_dir, "checkpoint")
            torch.save((net.state_dict(), optimizer.state_dict()), path)
        tune.report(score=score)
    print("Finished Training")

# %% [markdown]
# **Test** **set** **score**

# %%
def test_score(config, net , device="cpu"):
    trainset, testset = load_data()

    testloader = torch.utils.data.DataLoader(testset, batch_size=int(config.get("batch_size",32)), shuffle=False, num_workers=2)
    best_trained_model=net
    criterion = nn.CrossEntropyLoss()
    # # Test loss
    # test_loss = 0.0
    # net.eval() # Prepare model for evaluation
    # for i, data in enumerate(testloader):
    #     with torch.no_grad():
    #         inputs, labels = data
    #         inputs, labels = inputs.to(device), labels.to(device)

    #         outputs = net(inputs)
    test_score = compute_score(best_trained_model, testloader, device)
    print("Best trial test set score: {}".format(test_score))
            # Inverse transform of the labels' scaler
            #outputs = torch.tensor(scaler_labels.inverse_transform(outputs.detach().cpu())).to(device)    
            #labels = torch.tensor(scaler_labels.inverse_transform(labels.cpu())).to(device)
            
    #         loss = criterion(outputs, labels)
    #         test_loss += loss.cpu().numpy()

    # return test_loss / len(testset)

# %% [markdown]
# Start Ray runtime

# %%
ray.shutdown()
ray.init(num_cpus=2, num_gpus=0) # Here we use ray.init() to evaluate available_resources for Ray
print(ray.available_resources())
  # Restart Ray defensively in case the ray connection is lost. 

# Start Ray runtime with specific resources (not nessesarily all resources)
# You can change this values based on your machine resources)
#ray.init(num_cpus=2, num_gpus=0) 

"""Check Ray Tune is working properly (for trainable class)"""
# from ray.tune.utils import validate_save_restore
# validate_save_restore(Trainable)
# validate_save_restore(Trainable, use_object_store=True)
# print("Success!")
# Out:
# {'memory': 7899232667.0, 'object_store_memory': 3949616332.0, 'node:172.28.0.2': 1.0, 'CPU': 2.0}
# 'Check Ray Tune is working properly (for trainable class)'

# %%
def test_score2(best_trial):
    trainset, testset = load_data()
    testloader = torch.utils.data.DataLoader(testset, batch_size=int(config.get("batch_size",32)), shuffle=False, num_workers=2)
    
    best_trained_model = NeuralNetwork(np.shape(feature_selection[0])[0],best_trial.config["l1"],best_trial.config["l2"],best_trial.config["l3"],best_trial.config)
    device = "cuda:0" if torch.cuda.is_available() else "cpu"
    best_trained_model.to(device)

    checkpoint_path = os.path.join(best_trial.checkpoint.value, "checkpoint")

    model_state, optimizer_state = torch.load(checkpoint_path)
    best_trained_model.load_state_dict(model_state)

    test_score = compute_score(best_trained_model, testloader(best_trial.config), device)
    print("Best trial test set score:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - {} ".format(test_score))
    return best_trial.config, best_trained_model

# %% [markdown]
# Start hyperparameter tuning

# %%
# %%capture
try:
    import optuna
except:
    # %pip install optuna
    import optuna

# %%
def main(num_samples=300, max_num_epochs=100, gpus_per_trial=2):

    # define data directory here if you want to load data from files
    data_dir = os.path.abspath("./data")
    load_data(data_dir)

    # define the search space of hyperparameters
    config = {
        "act1 ": tune.choice(["relu","leaky_relu","silu"]),
        "act2 ": tune.choice(["relu","leaky_relu","silu"]),
        "act3 ": tune.choice(["relu","leaky_relu","silu"]),
        "act4 ": tune.choice(["relu","leaky_relu","silu"]),
        "act5 ": tune.choice(["relu","leaky_relu","silu"]),
        "act6 ": tune.choice(["relu","leaky_relu","silu"]),
        "act7" : tune.choice(["gelu","leaky_relu"]),
        "act8" : tune.choice(["relu", "gelu"]),
        "lr": tune.loguniform(1e-5, 1e-1),
        "batch_size": tune.choice([32,64]),
        "hidden_dim1" : tune.quniform(150, 300, 10),
        "hidden_dim2" : tune.quniform(150, 300, 10),
        "hidden_dim3" : tune.quniform(150, 300, 10),
        "hidden_dim4" : tune.quniform(150, 300, 10),
        "hidden_dim5" : tune.quniform(150, 300, 10),
        "hidden_dim6" : tune.quniform(150, 300, 10),
        "hidden_dim7" : tune.quniform(150, 300, 10),
        "hidden_dim8" : tune.quniform(150, 300, 10),

    }
    

    # Optuna search algorithm
    from ray.tune.suggest.optuna import OptunaSearch 
    from ray.tune.suggest import ConcurrencyLimiter
    search_alg = OptunaSearch(
        metric="score", #or accuracy, etc.
        mode="max", #or max
        seed = 42,
        # points_to_evaluate=[
        # {'lr': 0.0005, 'hidden_size': 150.0, 'readout1_out': 200.0, 'readout2_out': 180.0}
        # ],
        )
    search_alg = ConcurrencyLimiter(search_alg, max_concurrent=30)

    scheduler = ASHAScheduler(
        metric ="score",
        mode="max",
        max_t=max_num_epochs,
        reduction_factor=2, 
        grace_period=4,
        brackets=5
        )
    
    reporter = CLIReporter(
        parameter_columns=["l1", "l2", "lr", "batch_size"],
        metric_columns=["score", "training_iteration"]
        )
    
    # wrap data loading and training for tuning using `partial` 
    # (note that there exist other methods for this purpose)
    result = tune.run(
        partial(trainable_func, data_dir=data_dir, epochs=max_num_epochs),
        scheduler=scheduler,
        search_alg=search_alg,
        num_samples=num_samples,
        config=config,
        verbose=2,
        checkpoint_score_attr="score",
        checkpoint_freq=0,
        keep_checkpoints_num=1,
        # checkpoint_at_end=True,
        # reuse_actors=reuse_actors_status,
        progress_reporter=reporter,
        resources_per_trial={"cpu": 0.5, "gpu": gpus_per_trial},
        stop={"training_iteration": max_num_epochs},                
        )

    best_trial = result.get_best_trial("score", "max", "last")
    print("Best trial config: {}".format(best_trial.config))
    print("Best trial final validation score: {}".format(
        best_trial.last_result["score"]))
# ////////
    best_trained_model = Net(best_trial.config)

    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda:0"
        if gpus_per_trial > 1:
            best_trained_model = nn.DataParallel(best_trained_model)
    best_trained_model.to(device)

    best_checkpoint_dir = best_trial.checkpoint.value
    model_state, optimizer_state = torch.load(os.path.join(
        best_checkpoint_dir, "checkpoint"))
    best_trained_model.load_state_dict(model_state)

    test_score_value = test_score(best_trial.config, best_trained_model, device)
    #print("Best trial test set score: {}".format(test_score_value))
#///////////
    # if ray.util.client.ray.is_connected():
    #     # If using Ray Client, we want to make sure checkpoint access
    #     # happens on the server. So we wrap `test_best_model` in a Ray task.
    #     # We have to make sure it gets executed on the same node that
    #     # ``tune.run`` is called on.
    #     from ray.util.ml_utils.node import force_on_current_node
    #     remote_fn = force_on_current_node(ray.remote(test_score2))
    #     ray.get(remote_fn.remote(best_trial))
    # else:
    #    best_trial.config, best_trained_model=test_score2(best_trial)
    # print("--------------------------------------------------")
    # return best_trial.config, best_trained_model

if __name__ == "__main__":
    # You can change the number of GPUs per trial here:
    main(num_samples=300, max_num_epochs=50, gpus_per_trial=0)
# Out:
# 2022-07-26 20:01:04,639	WARNING callback.py:106 -- The TensorboardX logger cannot be instantiated because either TensorboardX or one of it's dependencies is not installed. Please make sure you have the latest version of TensorboardX installed: `pip install -U tensorboardx`
# Streaming output truncated to the last 5000 lines.
# Memory usage on this node: 2.1/12.7 GiB
# Using AsyncHyperBand: num_stopped=118
# Bracket: Iter 32.000: 0.629245283018868 | Iter 16.000: 0.5879706369879233 | Iter 8.000: 0.5583220114787911 | Iter 4.000: 0.5089885917177984
# Bracket: Iter 32.000: 0.6502970297029703 | Iter 16.000: 0.5891078417810998 | Iter 8.000: 0.4995755003837567
# Bracket: Iter 32.000: 0.5137122903558031 | Iter 16.000: 0.4730839055963375
# Bracket: Iter 32.000: 0.657235182849937
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_20-01-04
# Number of trials: 140/300 (1 PENDING, 4 RUNNING, 135 TERMINATED)
#
#
# Trial trainable_func_b6e9e68a reported score=0.5572267920094007,should_checkpoint=True with parameters={'act1 ': 'leaky_relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'silu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.03850255096532231, 'batch_size': 32, 'hidden_dim1': 160.0, 'hidden_dim2': 260.0, 'hidden_dim3': 230.0, 'hidden_dim4': 270.0, 'hidden_dim5': 240.0, 'hidden_dim6': 230.0, 'hidden_dim7': 210.0, 'hidden_dim8': 180.0}.
# Trial trainable_func_bd6722ac reported score=0.45620638281188736,should_checkpoint=True with parameters={'act1 ': 'leaky_relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'relu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.019358377406771037, 'batch_size': 32, 'hidden_dim1': 250.0, 'hidden_dim2': 260.0, 'hidden_dim3': 230.0, 'hidden_dim4': 300.0, 'hidden_dim5': 240.0, 'hidden_dim6': 230.0, 'hidden_dim7': 210.0, 'hidden_dim8': 190.0}.
# Trial trainable_func_ad197c06 reported score=0.6177656546489563,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'relu', 'act4 ': 'relu', 'act5 ': 'relu', 'act6 ': 'leaky_relu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 1.2550451717485482e-05, 'batch_size': 32, 'hidden_dim1': 150.0, 'hidden_dim2': 250.0, 'hidden_dim3': 180.0, 'hidden_dim4': 250.0, 'hidden_dim5': 180.0, 'hidden_dim6': 210.0, 'hidden_dim7': 190.0, 'hidden_dim8': 170.0}.
# Trial trainable_func_b6e9e68a reported score=0.5572267920094007,should_checkpoint=True with parameters={'act1 ': 'leaky_relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'silu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.03850255096532231, 'batch_size': 32, 'hidden_dim1': 160.0, 'hidden_dim2': 260.0, 'hidden_dim3': 230.0, 'hidden_dim4': 270.0, 'hidden_dim5': 240.0, 'hidden_dim6': 230.0, 'hidden_dim7': 210.0, 'hidden_dim8': 180.0}. This trial completed.
# == Status ==
# Current time: 2022-07-26 20:16:06 (running for 00:15:01.83)
# Memory usage on this node: 2.1/12.7 GiB
# Using AsyncHyperBand: num_stopped=119
# Bracket: Iter 32.000: 0.629245283018868 | Iter 16.000: 0.5879706369879233 | Iter 8.000: 0.5572267920094007 | Iter 4.000: 0.5089885917177984
# Bracket: Iter 32.000: 0.6502970297029703 | Iter 16.000: 0.5891078417810998 | Iter 8.000: 0.4995755003837567
# Bracket: Iter 32.000: 0.5137122903558031 | Iter 16.000: 0.4730839055963375
# Bracket: Iter 32.000: 0.657235182849937
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_20-01-04
# Number of trials: 140/300 (1 PENDING, 4 RUNNING, 135 TERMINATED)
#
#
# Trial trainable_func_b1c8ac86 reported score=0.5823809523809524,should_checkpoint=True with parameters={'act1 ': 'leaky_relu', 'act2 ': 'relu', 'act3 ': 'relu', 'act4 ': 'relu', 'act5 ': 'silu', 'act6 ': 'relu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.0039628968628343565, 'batch_size': 32, 'hidden_dim1': 250.0, 'hidden_dim2': 260.0, 'hidden_dim3': 230.0, 'hidden_dim4': 270.0, 'hidden_dim5': 240.0, 'hidden_dim6': 190.0, 'hidden_dim7': 210.0, 'hidden_dim8': 180.0}.
# Trial trainable_func_c18ef896 reported score=0.43631022326674507,should_checkpoint=True with parameters={'act1 ': 'leaky_relu', 'act2 ': 'relu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'relu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.000809394387124984, 'batch_size': 32, 'hidden_dim1': 270.0, 'hidden_dim2': 190.0, 'hidden_dim3': 210.0, 'hidden_dim4': 270.0, 'hidden_dim5': 230.0, 'hidden_dim6': 190.0, 'hidden_dim7': 200.0, 'hidden_dim8': 190.0}.
# Trial trainable_func_b1c8ac86 reported score=0.5823809523809524,should_checkpoint=True with parameters={'act1 ': 'leaky_relu', 'act2 ': 'relu', 'act3 ': 'relu', 'act4 ': 'relu', 'act5 ': 'silu', 'act6 ': 'relu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.0039628968628343565, 'batch_size': 32, 'hidden_dim1': 250.0, 'hidden_dim2': 260.0, 'hidden_dim3': 230.0, 'hidden_dim4': 270.0, 'hidden_dim5': 240.0, 'hidden_dim6': 190.0, 'hidden_dim7': 210.0, 'hidden_dim8': 180.0}. This trial completed.
# Trial trainable_func_ad197c06 reported score=0.6177656546489563,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'relu', 'act4 ': 'relu', 'act5 ': 'relu', 'act6 ': 'leaky_relu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 1.2550451717485482e-05, 'batch_size': 32, 'hidden_dim1': 150.0, 'hidden_dim2': 250.0, 'hidden_dim3': 180.0, 'hidden_dim4': 250.0, 'hidden_dim5': 180.0, 'hidden_dim6': 210.0, 'hidden_dim7': 190.0, 'hidden_dim8': 170.0}.
# Trial trainable_func_c7c33e5c reported score=0.5375442739079102,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'relu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'relu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.01867104949962085, 'batch_size': 64, 'hidden_dim1': 270.0, 'hidden_dim2': 280.0, 'hidden_dim3': 240.0, 'hidden_dim4': 280.0, 'hidden_dim5': 230.0, 'hidden_dim6': 270.0, 'hidden_dim7': 160.0, 'hidden_dim8': 200.0}.
# Trial trainable_func_bd6722ac reported score=0.45620638281188736,should_checkpoint=True with parameters={'act1 ': 'leaky_relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'relu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.019358377406771037, 'batch_size': 32, 'hidden_dim1': 250.0, 'hidden_dim2': 260.0, 'hidden_dim3': 230.0, 'hidden_dim4': 300.0, 'hidden_dim5': 240.0, 'hidden_dim6': 230.0, 'hidden_dim7': 210.0, 'hidden_dim8': 190.0}.
# == Status ==
# Current time: 2022-07-26 20:16:11 (running for 00:15:07.11)
# Memory usage on this node: 2.1/12.7 GiB
# Using AsyncHyperBand: num_stopped=120
# Bracket: Iter 32.000: 0.629245283018868 | Iter 16.000: 0.587351655127625 | Iter 8.000: 0.5572267920094007 | Iter 4.000: 0.5089885917177984
# Bracket: Iter 32.000: 0.6502970297029703 | Iter 16.000: 0.5891078417810998 | Iter 8.000: 0.4995755003837567
# Bracket: Iter 32.000: 0.5137122903558031 | Iter 16.000: 0.4730839055963375
# Bracket: Iter 32.000: 0.657235182849937
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_20-01-04
# Number of trials: 142/300 (1 PENDING, 4 RUNNING, 137 TERMINATED)
#
#
# Trial trainable_func_bd6722ac reported score=0.45620638281188736,should_checkpoint=True with parameters={'act1 ': 'leaky_relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'relu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.019358377406771037, 'batch_size': 32, 'hidden_dim1': 250.0, 'hidden_dim2': 260.0, 'hidden_dim3': 230.0, 'hidden_dim4': 300.0, 'hidden_dim5': 240.0, 'hidden_dim6': 230.0, 'hidden_dim7': 210.0, 'hidden_dim8': 190.0}. This trial completed.
# Trial trainable_func_c18ef896 reported score=0.43631022326674507,should_checkpoint=True with parameters={'act1 ': 'leaky_relu', 'act2 ': 'relu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'relu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.000809394387124984, 'batch_size': 32, 'hidden_dim1': 270.0, 'hidden_dim2': 190.0, 'hidden_dim3': 210.0, 'hidden_dim4': 270.0, 'hidden_dim5': 230.0, 'hidden_dim6': 190.0, 'hidden_dim7': 200.0, 'hidden_dim8': 190.0}.
# Trial trainable_func_c98bb9b2 reported score=0.5859183834556791,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'leaky_relu', 'act6 ': 'relu', 'act7': 'gelu', 'act8': 'relu', 'lr': 0.009595327635239142, 'batch_size': 64, 'hidden_dim1': 270.0, 'hidden_dim2': 280.0, 'hidden_dim3': 210.0, 'hidden_dim4': 280.0, 'hidden_dim5': 230.0, 'hidden_dim6': 200.0, 'hidden_dim7': 200.0, 'hidden_dim8': 200.0}.
# Trial trainable_func_c7c33e5c reported score=0.5375442739079102,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'relu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'relu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.01867104949962085, 'batch_size': 64, 'hidden_dim1': 270.0, 'hidden_dim2': 280.0, 'hidden_dim3': 240.0, 'hidden_dim4': 280.0, 'hidden_dim5': 230.0, 'hidden_dim6': 270.0, 'hidden_dim7': 160.0, 'hidden_dim8': 200.0}.
# Trial trainable_func_ad197c06 reported score=0.6177656546489563,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'relu', 'act4 ': 'relu', 'act5 ': 'relu', 'act6 ': 'leaky_relu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 1.2550451717485482e-05, 'batch_size': 32, 'hidden_dim1': 150.0, 'hidden_dim2': 250.0, 'hidden_dim3': 180.0, 'hidden_dim4': 250.0, 'hidden_dim5': 180.0, 'hidden_dim6': 210.0, 'hidden_dim7': 190.0, 'hidden_dim8': 170.0}.
# == Status ==
# Current time: 2022-07-26 20:16:17 (running for 00:15:12.57)
# Memory usage on this node: 2.1/12.7 GiB
# Using AsyncHyperBand: num_stopped=121
# Bracket: Iter 32.000: 0.629245283018868 | Iter 16.000: 0.587351655127625 | Iter 8.000: 0.5572267920094007 | Iter 4.000: 0.5089885917177984
# Bracket: Iter 32.000: 0.6502970297029703 | Iter 16.000: 0.5891078417810998 | Iter 8.000: 0.49466318785578745
# Bracket: Iter 32.000: 0.5137122903558031 | Iter 16.000: 0.4730839055963375
# Bracket: Iter 32.000: 0.657235182849937
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_20-01-04
# Number of trials: 143/300 (1 PENDING, 4 RUNNING, 138 TERMINATED)
#
#
# Trial trainable_func_c18ef896 reported score=0.43631022326674507,should_checkpoint=True with parameters={'act1 ': 'leaky_relu', 'act2 ': 'relu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'relu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.000809394387124984, 'batch_size': 32, 'hidden_dim1': 270.0, 'hidden_dim2': 190.0, 'hidden_dim3': 210.0, 'hidden_dim4': 270.0, 'hidden_dim5': 230.0, 'hidden_dim6': 190.0, 'hidden_dim7': 200.0, 'hidden_dim8': 190.0}.
# Trial trainable_func_c98bb9b2 reported score=0.5859183834556791,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'leaky_relu', 'act6 ': 'relu', 'act7': 'gelu', 'act8': 'relu', 'lr': 0.009595327635239142, 'batch_size': 64, 'hidden_dim1': 270.0, 'hidden_dim2': 280.0, 'hidden_dim3': 210.0, 'hidden_dim4': 280.0, 'hidden_dim5': 230.0, 'hidden_dim6': 200.0, 'hidden_dim7': 200.0, 'hidden_dim8': 200.0}.
# Trial trainable_func_c7c33e5c reported score=0.5375442739079102,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'relu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'relu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.01867104949962085, 'batch_size': 64, 'hidden_dim1': 270.0, 'hidden_dim2': 280.0, 'hidden_dim3': 240.0, 'hidden_dim4': 280.0, 'hidden_dim5': 230.0, 'hidden_dim6': 270.0, 'hidden_dim7': 160.0, 'hidden_dim8': 200.0}.
# Trial trainable_func_ad197c06 reported score=0.6177656546489563,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'relu', 'act4 ': 'relu', 'act5 ': 'relu', 'act6 ': 'leaky_relu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 1.2550451717485482e-05, 'batch_size': 32, 'hidden_dim1': 150.0, 'hidden_dim2': 250.0, 'hidden_dim3': 180.0, 'hidden_dim4': 250.0, 'hidden_dim5': 180.0, 'hidden_dim6': 210.0, 'hidden_dim7': 190.0, 'hidden_dim8': 170.0}.
# == Status ==
# Current time: 2022-07-26 20:16:22 (running for 00:15:17.95)
# Memory usage on this node: 2.1/12.7 GiB
# Using AsyncHyperBand: num_stopped=121
# Bracket: Iter 32.000: 0.629245283018868 | Iter 16.000: 0.587351655127625 | Iter 8.000: 0.5572267920094007 | Iter 4.000: 0.5089885917177984
# Bracket: Iter 32.000: 0.6502970297029703 | Iter 16.000: 0.5891078417810998 | Iter 8.000: 0.4995755003837567
# Bracket: Iter 32.000: 0.5137122903558031 | Iter 16.000: 0.4730839055963375
# Bracket: Iter 32.000: 0.657235182849937
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_20-01-04
# Number of trials: 143/300 (1 PENDING, 4 RUNNING, 138 TERMINATED)
#
#
# Trial trainable_func_c18ef896 reported score=0.43631022326674507,should_checkpoint=True with parameters={'act1 ': 'leaky_relu', 'act2 ': 'relu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'relu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.000809394387124984, 'batch_size': 32, 'hidden_dim1': 270.0, 'hidden_dim2': 190.0, 'hidden_dim3': 210.0, 'hidden_dim4': 270.0, 'hidden_dim5': 230.0, 'hidden_dim6': 190.0, 'hidden_dim7': 200.0, 'hidden_dim8': 190.0}. This trial completed.
# Trial trainable_func_cc467886 reported score=0.538126959247649,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'silu', 'act4 ': 'leaky_relu', 'act5 ': 'leaky_relu', 'act6 ': 'silu', 'act7': 'gelu', 'act8': 'gelu', 'lr': 0.009775292861152897, 'batch_size': 64, 'hidden_dim1': 270.0, 'hidden_dim2': 190.0, 'hidden_dim3': 220.0, 'hidden_dim4': 280.0, 'hidden_dim5': 230.0, 'hidden_dim6': 200.0, 'hidden_dim7': 230.0, 'hidden_dim8': 200.0}.
# Trial trainable_func_c98bb9b2 reported score=0.5859183834556791,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'leaky_relu', 'act6 ': 'relu', 'act7': 'gelu', 'act8': 'relu', 'lr': 0.009595327635239142, 'batch_size': 64, 'hidden_dim1': 270.0, 'hidden_dim2': 280.0, 'hidden_dim3': 210.0, 'hidden_dim4': 280.0, 'hidden_dim5': 230.0, 'hidden_dim6': 200.0, 'hidden_dim7': 200.0, 'hidden_dim8': 200.0}.
# Trial trainable_func_ad197c06 reported score=0.6177656546489563,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'relu', 'act4 ': 'relu', 'act5 ': 'relu', 'act6 ': 'leaky_relu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 1.2550451717485482e-05, 'batch_size': 32, 'hidden_dim1': 150.0, 'hidden_dim2': 250.0, 'hidden_dim3': 180.0, 'hidden_dim4': 250.0, 'hidden_dim5': 180.0, 'hidden_dim6': 210.0, 'hidden_dim7': 190.0, 'hidden_dim8': 170.0}.
# == Status ==
# Current time: 2022-07-26 20:16:27 (running for 00:15:23.08)
# Memory usage on this node: 2.1/12.7 GiB
# Using AsyncHyperBand: num_stopped=122
# Bracket: Iter 32.000: 0.629245283018868 | Iter 16.000: 0.587351655127625 | Iter 8.000: 0.5572267920094007 | Iter 4.000: 0.5089885917177984
# Bracket: Iter 32.000: 0.6502970297029703 | Iter 16.000: 0.5891078417810998 | Iter 8.000: 0.49466318785578745
# Bracket: Iter 32.000: 0.5137122903558031 | Iter 16.000: 0.4730839055963375
# Bracket: Iter 32.000: 0.657235182849937
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_20-01-04
# Number of trials: 144/300 (1 PENDING, 4 RUNNING, 139 TERMINATED)
#
#
# Trial trainable_func_c7c33e5c reported score=0.5375442739079102,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'relu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'relu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.01867104949962085, 'batch_size': 64, 'hidden_dim1': 270.0, 'hidden_dim2': 280.0, 'hidden_dim3': 240.0, 'hidden_dim4': 280.0, 'hidden_dim5': 230.0, 'hidden_dim6': 270.0, 'hidden_dim7': 160.0, 'hidden_dim8': 200.0}.
# Trial trainable_func_cc467886 reported score=0.538126959247649,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'silu', 'act4 ': 'leaky_relu', 'act5 ': 'leaky_relu', 'act6 ': 'silu', 'act7': 'gelu', 'act8': 'gelu', 'lr': 0.009775292861152897, 'batch_size': 64, 'hidden_dim1': 270.0, 'hidden_dim2': 190.0, 'hidden_dim3': 220.0, 'hidden_dim4': 280.0, 'hidden_dim5': 230.0, 'hidden_dim6': 200.0, 'hidden_dim7': 230.0, 'hidden_dim8': 200.0}.
# Trial trainable_func_ad197c06 reported score=0.6177656546489563,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'relu', 'act4 ': 'relu', 'act5 ': 'relu', 'act6 ': 'leaky_relu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 1.2550451717485482e-05, 'batch_size': 32, 'hidden_dim1': 150.0, 'hidden_dim2': 250.0, 'hidden_dim3': 180.0, 'hidden_dim4': 250.0, 'hidden_dim5': 180.0, 'hidden_dim6': 210.0, 'hidden_dim7': 190.0, 'hidden_dim8': 170.0}. This trial completed.
# Trial trainable_func_d1847e10 reported score=0.4534665099882491,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'silu', 'act4 ': 'leaky_relu', 'act5 ': 'leaky_relu', 'act6 ': 'silu', 'act7': 'gelu', 'act8': 'gelu', 'lr': 0.00036842457842147723, 'batch_size': 64, 'hidden_dim1': 190.0, 'hidden_dim2': 280.0, 'hidden_dim3': 250.0, 'hidden_dim4': 280.0, 'hidden_dim5': 260.0, 'hidden_dim6': 200.0, 'hidden_dim7': 180.0, 'hidden_dim8': 200.0}.
# Trial trainable_func_c98bb9b2 reported score=0.5859183834556791,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'leaky_relu', 'act6 ': 'relu', 'act7': 'gelu', 'act8': 'relu', 'lr': 0.009595327635239142, 'batch_size': 64, 'hidden_dim1': 270.0, 'hidden_dim2': 280.0, 'hidden_dim3': 210.0, 'hidden_dim4': 280.0, 'hidden_dim5': 230.0, 'hidden_dim6': 200.0, 'hidden_dim7': 200.0, 'hidden_dim8': 200.0}.
# Trial trainable_func_c7c33e5c reported score=0.5375442739079102,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'relu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'relu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.01867104949962085, 'batch_size': 64, 'hidden_dim1': 270.0, 'hidden_dim2': 280.0, 'hidden_dim3': 240.0, 'hidden_dim4': 280.0, 'hidden_dim5': 230.0, 'hidden_dim6': 270.0, 'hidden_dim7': 160.0, 'hidden_dim8': 200.0}. This trial completed.
# == Status ==
# Current time: 2022-07-26 20:16:33 (running for 00:15:28.45)
# Memory usage on this node: 2.1/12.7 GiB
# Using AsyncHyperBand: num_stopped=124
# Bracket: Iter 32.000: 0.628222767801959 | Iter 16.000: 0.587351655127625 | Iter 8.000: 0.5572267920094007 | Iter 4.000: 0.5089885917177984
# Bracket: Iter 32.000: 0.6502970297029703 | Iter 16.000: 0.5866930693069308 | Iter 8.000: 0.49466318785578745
# Bracket: Iter 32.000: 0.5137122903558031 | Iter 16.000: 0.4730839055963375
# Bracket: Iter 32.000: 0.657235182849937
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_20-01-04
# Number of trials: 145/300 (1 PENDING, 4 RUNNING, 140 TERMINATED)
#
#
# Trial trainable_func_d5943f04 reported score=0.5823113207547169,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'silu', 'act4 ': 'leaky_relu', 'act5 ': 'leaky_relu', 'act6 ': 'silu', 'act7': 'gelu', 'act8': 'gelu', 'lr': 1.0019023814374533e-05, 'batch_size': 64, 'hidden_dim1': 290.0, 'hidden_dim2': 200.0, 'hidden_dim3': 300.0, 'hidden_dim4': 280.0, 'hidden_dim5': 260.0, 'hidden_dim6': 200.0, 'hidden_dim7': 220.0, 'hidden_dim8': 200.0}.
# Trial trainable_func_cc467886 reported score=0.538126959247649,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'silu', 'act4 ': 'leaky_relu', 'act5 ': 'leaky_relu', 'act6 ': 'silu', 'act7': 'gelu', 'act8': 'gelu', 'lr': 0.009775292861152897, 'batch_size': 64, 'hidden_dim1': 270.0, 'hidden_dim2': 190.0, 'hidden_dim3': 220.0, 'hidden_dim4': 280.0, 'hidden_dim5': 230.0, 'hidden_dim6': 200.0, 'hidden_dim7': 230.0, 'hidden_dim8': 200.0}.
# Trial trainable_func_d1847e10 reported score=0.4534665099882491,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'silu', 'act4 ': 'leaky_relu', 'act5 ': 'leaky_relu', 'act6 ': 'silu', 'act7': 'gelu', 'act8': 'gelu', 'lr': 0.00036842457842147723, 'batch_size': 64, 'hidden_dim1': 190.0, 'hidden_dim2': 280.0, 'hidden_dim3': 250.0, 'hidden_dim4': 280.0, 'hidden_dim5': 260.0, 'hidden_dim6': 200.0, 'hidden_dim7': 180.0, 'hidden_dim8': 200.0}. This trial completed.
# Trial trainable_func_d7a18d2e reported score=0.41409864345644165,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'silu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.03253778051619917, 'batch_size': 32, 'hidden_dim1': 230.0, 'hidden_dim2': 190.0, 'hidden_dim3': 300.0, 'hidden_dim4': 260.0, 'hidden_dim5': 190.0, 'hidden_dim6': 190.0, 'hidden_dim7': 220.0, 'hidden_dim8': 230.0}.
# Trial trainable_func_c98bb9b2 reported score=0.5859183834556791,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'leaky_relu', 'act6 ': 'relu', 'act7': 'gelu', 'act8': 'relu', 'lr': 0.009595327635239142, 'batch_size': 64, 'hidden_dim1': 270.0, 'hidden_dim2': 280.0, 'hidden_dim3': 210.0, 'hidden_dim4': 280.0, 'hidden_dim5': 230.0, 'hidden_dim6': 200.0, 'hidden_dim7': 200.0, 'hidden_dim8': 200.0}.
# == Status ==
# Current time: 2022-07-26 20:16:38 (running for 00:15:33.47)
# Memory usage on this node: 2.1/12.7 GiB
# Using AsyncHyperBand: num_stopped=125
# Bracket: Iter 32.000: 0.628222767801959 | Iter 16.000: 0.587351655127625 | Iter 8.000: 0.5572267920094007 | Iter 4.000: 0.5080316470870295
# Bracket: Iter 32.000: 0.6502970297029703 | Iter 16.000: 0.5866930693069308 | Iter 8.000: 0.4995755003837567
# Bracket: Iter 32.000: 0.5137122903558031 | Iter 16.000: 0.4730839055963375
# Bracket: Iter 32.000: 0.657235182849937
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_20-01-04
# Number of trials: 147/300 (1 PENDING, 4 RUNNING, 142 TERMINATED)
#
#
# Trial trainable_func_cc467886 reported score=0.538126959247649,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'silu', 'act4 ': 'leaky_relu', 'act5 ': 'leaky_relu', 'act6 ': 'silu', 'act7': 'gelu', 'act8': 'gelu', 'lr': 0.009775292861152897, 'batch_size': 64, 'hidden_dim1': 270.0, 'hidden_dim2': 190.0, 'hidden_dim3': 220.0, 'hidden_dim4': 280.0, 'hidden_dim5': 230.0, 'hidden_dim6': 200.0, 'hidden_dim7': 230.0, 'hidden_dim8': 200.0}.
# Trial trainable_func_d5943f04 reported score=0.5823113207547169,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'silu', 'act4 ': 'leaky_relu', 'act5 ': 'leaky_relu', 'act6 ': 'silu', 'act7': 'gelu', 'act8': 'gelu', 'lr': 1.0019023814374533e-05, 'batch_size': 64, 'hidden_dim1': 290.0, 'hidden_dim2': 200.0, 'hidden_dim3': 300.0, 'hidden_dim4': 280.0, 'hidden_dim5': 260.0, 'hidden_dim6': 200.0, 'hidden_dim7': 220.0, 'hidden_dim8': 200.0}.
# Trial trainable_func_c98bb9b2 reported score=0.5859183834556791,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'leaky_relu', 'act6 ': 'relu', 'act7': 'gelu', 'act8': 'relu', 'lr': 0.009595327635239142, 'batch_size': 64, 'hidden_dim1': 270.0, 'hidden_dim2': 280.0, 'hidden_dim3': 210.0, 'hidden_dim4': 280.0, 'hidden_dim5': 230.0, 'hidden_dim6': 200.0, 'hidden_dim7': 200.0, 'hidden_dim8': 200.0}.
# == Status ==
# Current time: 2022-07-26 20:16:43 (running for 00:15:38.72)
# Memory usage on this node: 2.1/12.7 GiB
# Using AsyncHyperBand: num_stopped=125
# Bracket: Iter 32.000: 0.628222767801959 | Iter 16.000: 0.587351655127625 | Iter 8.000: 0.5572267920094007 | Iter 4.000: 0.5089885917177984
# Bracket: Iter 32.000: 0.6502970297029703 | Iter 16.000: 0.5866930693069308 | Iter 8.000: 0.4995755003837567
# Bracket: Iter 32.000: 0.5137122903558031 | Iter 16.000: 0.4730839055963375
# Bracket: Iter 32.000: 0.657235182849937
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_20-01-04
# Number of trials: 147/300 (1 PENDING, 4 RUNNING, 142 TERMINATED)
#
#
# Trial trainable_func_d7a18d2e reported score=0.41409864345644165,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'silu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.03253778051619917, 'batch_size': 32, 'hidden_dim1': 230.0, 'hidden_dim2': 190.0, 'hidden_dim3': 300.0, 'hidden_dim4': 260.0, 'hidden_dim5': 190.0, 'hidden_dim6': 190.0, 'hidden_dim7': 220.0, 'hidden_dim8': 230.0}. This trial completed.
# Trial trainable_func_cc467886 reported score=0.538126959247649,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'silu', 'act4 ': 'leaky_relu', 'act5 ': 'leaky_relu', 'act6 ': 'silu', 'act7': 'gelu', 'act8': 'gelu', 'lr': 0.009775292861152897, 'batch_size': 64, 'hidden_dim1': 270.0, 'hidden_dim2': 190.0, 'hidden_dim3': 220.0, 'hidden_dim4': 280.0, 'hidden_dim5': 230.0, 'hidden_dim6': 200.0, 'hidden_dim7': 230.0, 'hidden_dim8': 200.0}. This trial completed.
# Trial trainable_func_d9128aaa reported score=0.3973634651600753,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'silu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.02987713871679866, 'batch_size': 32, 'hidden_dim1': 230.0, 'hidden_dim2': 190.0, 'hidden_dim3': 300.0, 'hidden_dim4': 260.0, 'hidden_dim5': 190.0, 'hidden_dim6': 190.0, 'hidden_dim7': 220.0, 'hidden_dim8': 240.0}.
# Trial trainable_func_d5943f04 reported score=0.5823113207547169,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'silu', 'act4 ': 'leaky_relu', 'act5 ': 'leaky_relu', 'act6 ': 'silu', 'act7': 'gelu', 'act8': 'gelu', 'lr': 1.0019023814374533e-05, 'batch_size': 64, 'hidden_dim1': 290.0, 'hidden_dim2': 200.0, 'hidden_dim3': 300.0, 'hidden_dim4': 280.0, 'hidden_dim5': 260.0, 'hidden_dim6': 200.0, 'hidden_dim7': 220.0, 'hidden_dim8': 200.0}.
# Trial trainable_func_de4c7152 reported score=0.6070361635220126,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'silu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.012223522715798857, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 200.0, 'hidden_dim3': 300.0, 'hidden_dim4': 260.0, 'hidden_dim5': 190.0, 'hidden_dim6': 200.0, 'hidden_dim7': 240.0, 'hidden_dim8': 240.0}.
# == Status ==
# Current time: 2022-07-26 20:16:48 (running for 00:15:43.85)
# Memory usage on this node: 2.1/12.7 GiB
# Using AsyncHyperBand: num_stopped=127
# Bracket: Iter 32.000: 0.628222767801959 | Iter 16.000: 0.587351655127625 | Iter 8.000: 0.5591179471660312 | Iter 4.000: 0.5080316470870295
# Bracket: Iter 32.000: 0.6502970297029703 | Iter 16.000: 0.5743415126823417 | Iter 8.000: 0.4995755003837567
# Bracket: Iter 32.000: 0.5137122903558031 | Iter 16.000: 0.4730839055963375
# Bracket: Iter 32.000: 0.657235182849937
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_20-01-04
# Number of trials: 149/300 (1 PENDING, 4 RUNNING, 144 TERMINATED)
#
#
# Trial trainable_func_c98bb9b2 reported score=0.5859183834556791,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'leaky_relu', 'act6 ': 'relu', 'act7': 'gelu', 'act8': 'relu', 'lr': 0.009595327635239142, 'batch_size': 64, 'hidden_dim1': 270.0, 'hidden_dim2': 280.0, 'hidden_dim3': 210.0, 'hidden_dim4': 280.0, 'hidden_dim5': 230.0, 'hidden_dim6': 200.0, 'hidden_dim7': 200.0, 'hidden_dim8': 200.0}.
# Trial trainable_func_d9128aaa reported score=0.3973634651600753,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'silu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.02987713871679866, 'batch_size': 32, 'hidden_dim1': 230.0, 'hidden_dim2': 190.0, 'hidden_dim3': 300.0, 'hidden_dim4': 260.0, 'hidden_dim5': 190.0, 'hidden_dim6': 190.0, 'hidden_dim7': 220.0, 'hidden_dim8': 240.0}. This trial completed.
# Trial trainable_func_d5943f04 reported score=0.5823113207547169,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'silu', 'act4 ': 'leaky_relu', 'act5 ': 'leaky_relu', 'act6 ': 'silu', 'act7': 'gelu', 'act8': 'gelu', 'lr': 1.0019023814374533e-05, 'batch_size': 64, 'hidden_dim1': 290.0, 'hidden_dim2': 200.0, 'hidden_dim3': 300.0, 'hidden_dim4': 280.0, 'hidden_dim5': 260.0, 'hidden_dim6': 200.0, 'hidden_dim7': 220.0, 'hidden_dim8': 200.0}.
# Trial trainable_func_de4c7152 reported score=0.6070361635220126,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'silu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.012223522715798857, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 200.0, 'hidden_dim3': 300.0, 'hidden_dim4': 260.0, 'hidden_dim5': 190.0, 'hidden_dim6': 200.0, 'hidden_dim7': 240.0, 'hidden_dim8': 240.0}.
# == Status ==
# Current time: 2022-07-26 20:16:54 (running for 00:15:49.68)
# Memory usage on this node: 2.1/12.7 GiB
# Using AsyncHyperBand: num_stopped=128
# Bracket: Iter 32.000: 0.628222767801959 | Iter 16.000: 0.587351655127625 | Iter 8.000: 0.5591179471660312 | Iter 4.000: 0.5080316470870295
# Bracket: Iter 32.000: 0.6502970297029703 | Iter 16.000: 0.5743415126823417 | Iter 8.000: 0.4995755003837567
# Bracket: Iter 32.000: 0.5137122903558031 | Iter 16.000: 0.4730839055963375
# Bracket: Iter 32.000: 0.657235182849937
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_20-01-04
# Number of trials: 150/300 (1 PENDING, 4 RUNNING, 145 TERMINATED)
#
#
# Trial trainable_func_c98bb9b2 reported score=0.5859183834556791,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'leaky_relu', 'act6 ': 'relu', 'act7': 'gelu', 'act8': 'relu', 'lr': 0.009595327635239142, 'batch_size': 64, 'hidden_dim1': 270.0, 'hidden_dim2': 280.0, 'hidden_dim3': 210.0, 'hidden_dim4': 280.0, 'hidden_dim5': 230.0, 'hidden_dim6': 200.0, 'hidden_dim7': 200.0, 'hidden_dim8': 200.0}.
# Trial trainable_func_de88cd8c reported score=0.46037735849056605,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'silu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.05499910052202567, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 200.0, 'hidden_dim3': 300.0, 'hidden_dim4': 260.0, 'hidden_dim5': 190.0, 'hidden_dim6': 190.0, 'hidden_dim7': 200.0, 'hidden_dim8': 240.0}.
# Trial trainable_func_d5943f04 reported score=0.5823113207547169,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'silu', 'act4 ': 'leaky_relu', 'act5 ': 'leaky_relu', 'act6 ': 'silu', 'act7': 'gelu', 'act8': 'gelu', 'lr': 1.0019023814374533e-05, 'batch_size': 64, 'hidden_dim1': 290.0, 'hidden_dim2': 200.0, 'hidden_dim3': 300.0, 'hidden_dim4': 280.0, 'hidden_dim5': 260.0, 'hidden_dim6': 200.0, 'hidden_dim7': 220.0, 'hidden_dim8': 200.0}. This trial completed.
# Trial trainable_func_e31cbcdc reported score=0.4430592184128507,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'silu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.05601575312829844, 'batch_size': 32, 'hidden_dim1': 260.0, 'hidden_dim2': 200.0, 'hidden_dim3': 300.0, 'hidden_dim4': 260.0, 'hidden_dim5': 200.0, 'hidden_dim6': 180.0, 'hidden_dim7': 200.0, 'hidden_dim8': 230.0}.
# Trial trainable_func_de4c7152 reported score=0.6070361635220126,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'silu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.012223522715798857, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 200.0, 'hidden_dim3': 300.0, 'hidden_dim4': 260.0, 'hidden_dim5': 190.0, 'hidden_dim6': 200.0, 'hidden_dim7': 240.0, 'hidden_dim8': 240.0}.
# == Status ==
# Current time: 2022-07-26 20:16:59 (running for 00:15:54.93)
# Memory usage on this node: 2.1/12.7 GiB
# Using AsyncHyperBand: num_stopped=129
# Bracket: Iter 32.000: 0.628222767801959 | Iter 16.000: 0.5867326732673267 | Iter 8.000: 0.5591179471660312 | Iter 4.000: 0.5080316470870295
# Bracket: Iter 32.000: 0.6502970297029703 | Iter 16.000: 0.5743415126823417 | Iter 8.000: 0.4995755003837567
# Bracket: Iter 32.000: 0.5137122903558031 | Iter 16.000: 0.4730839055963375
# Bracket: Iter 32.000: 0.657235182849937
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_20-01-04
# Number of trials: 151/300 (1 PENDING, 4 RUNNING, 146 TERMINATED)
#
#
# Trial trainable_func_de88cd8c reported score=0.46037735849056605,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'silu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.05499910052202567, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 200.0, 'hidden_dim3': 300.0, 'hidden_dim4': 260.0, 'hidden_dim5': 190.0, 'hidden_dim6': 190.0, 'hidden_dim7': 200.0, 'hidden_dim8': 240.0}. This trial completed.
# Trial trainable_func_c98bb9b2 reported score=0.5859183834556791,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'leaky_relu', 'act6 ': 'relu', 'act7': 'gelu', 'act8': 'relu', 'lr': 0.009595327635239142, 'batch_size': 64, 'hidden_dim1': 270.0, 'hidden_dim2': 280.0, 'hidden_dim3': 210.0, 'hidden_dim4': 280.0, 'hidden_dim5': 230.0, 'hidden_dim6': 200.0, 'hidden_dim7': 200.0, 'hidden_dim8': 200.0}.
# Trial trainable_func_e5fbff08 reported score=0.46766826923076926,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'silu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.05088234161385608, 'batch_size': 32, 'hidden_dim1': 260.0, 'hidden_dim2': 200.0, 'hidden_dim3': 290.0, 'hidden_dim4': 260.0, 'hidden_dim5': 200.0, 'hidden_dim6': 190.0, 'hidden_dim7': 200.0, 'hidden_dim8': 230.0}.
# == Status ==
# Current time: 2022-07-26 20:17:04 (running for 00:16:00.14)
# Memory usage on this node: 2.1/12.7 GiB
# Using AsyncHyperBand: num_stopped=130
# Bracket: Iter 32.000: 0.628222767801959 | Iter 16.000: 0.5867326732673267 | Iter 8.000: 0.5610091023226617 | Iter 4.000: 0.5077398147162764
# Bracket: Iter 32.000: 0.6502970297029703 | Iter 16.000: 0.5743415126823417 | Iter 8.000: 0.4995755003837567
# Bracket: Iter 32.000: 0.5137122903558031 | Iter 16.000: 0.4730839055963375
# Bracket: Iter 32.000: 0.657235182849937
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_20-01-04
# Number of trials: 152/300 (1 PENDING, 4 RUNNING, 147 TERMINATED)
#
#
# Trial trainable_func_e31cbcdc reported score=0.4430592184128507,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'silu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.05601575312829844, 'batch_size': 32, 'hidden_dim1': 260.0, 'hidden_dim2': 200.0, 'hidden_dim3': 300.0, 'hidden_dim4': 260.0, 'hidden_dim5': 200.0, 'hidden_dim6': 180.0, 'hidden_dim7': 200.0, 'hidden_dim8': 230.0}.
# Trial trainable_func_de4c7152 reported score=0.6070361635220126,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'silu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.012223522715798857, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 200.0, 'hidden_dim3': 300.0, 'hidden_dim4': 260.0, 'hidden_dim5': 190.0, 'hidden_dim6': 200.0, 'hidden_dim7': 240.0, 'hidden_dim8': 240.0}.
# Trial trainable_func_c98bb9b2 reported score=0.5859183834556791,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'leaky_relu', 'act6 ': 'relu', 'act7': 'gelu', 'act8': 'relu', 'lr': 0.009595327635239142, 'batch_size': 64, 'hidden_dim1': 270.0, 'hidden_dim2': 280.0, 'hidden_dim3': 210.0, 'hidden_dim4': 280.0, 'hidden_dim5': 230.0, 'hidden_dim6': 200.0, 'hidden_dim7': 200.0, 'hidden_dim8': 200.0}.
# Trial trainable_func_e5fbff08 reported score=0.46766826923076926,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'silu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.05088234161385608, 'batch_size': 32, 'hidden_dim1': 260.0, 'hidden_dim2': 200.0, 'hidden_dim3': 290.0, 'hidden_dim4': 260.0, 'hidden_dim5': 200.0, 'hidden_dim6': 190.0, 'hidden_dim7': 200.0, 'hidden_dim8': 230.0}.
# == Status ==
# Current time: 2022-07-26 20:17:09 (running for 00:16:05.28)
# Memory usage on this node: 2.1/12.7 GiB
# Using AsyncHyperBand: num_stopped=130
# Bracket: Iter 32.000: 0.628222767801959 | Iter 16.000: 0.5867326732673267 | Iter 8.000: 0.5610091023226617 | Iter 4.000: 0.5077398147162764
# Bracket: Iter 32.000: 0.6502970297029703 | Iter 16.000: 0.5743415126823417 | Iter 8.000: 0.4995755003837567
# Bracket: Iter 32.000: 0.5137122903558031 | Iter 16.000: 0.4730839055963375
# Bracket: Iter 32.000: 0.657235182849937
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_20-01-04
# Number of trials: 152/300 (1 PENDING, 4 RUNNING, 147 TERMINATED)
#
#
# Trial trainable_func_c98bb9b2 reported score=0.5859183834556791,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'leaky_relu', 'act6 ': 'relu', 'act7': 'gelu', 'act8': 'relu', 'lr': 0.009595327635239142, 'batch_size': 64, 'hidden_dim1': 270.0, 'hidden_dim2': 280.0, 'hidden_dim3': 210.0, 'hidden_dim4': 280.0, 'hidden_dim5': 230.0, 'hidden_dim6': 200.0, 'hidden_dim7': 200.0, 'hidden_dim8': 200.0}.
# Trial trainable_func_e31cbcdc reported score=0.4430592184128507,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'silu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.05601575312829844, 'batch_size': 32, 'hidden_dim1': 260.0, 'hidden_dim2': 200.0, 'hidden_dim3': 300.0, 'hidden_dim4': 260.0, 'hidden_dim5': 200.0, 'hidden_dim6': 180.0, 'hidden_dim7': 200.0, 'hidden_dim8': 230.0}.
# Trial trainable_func_de4c7152 reported score=0.6070361635220126,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'silu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.012223522715798857, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 200.0, 'hidden_dim3': 300.0, 'hidden_dim4': 260.0, 'hidden_dim5': 190.0, 'hidden_dim6': 200.0, 'hidden_dim7': 240.0, 'hidden_dim8': 240.0}.
# Trial trainable_func_e31cbcdc reported score=0.4430592184128507,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'silu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.05601575312829844, 'batch_size': 32, 'hidden_dim1': 260.0, 'hidden_dim2': 200.0, 'hidden_dim3': 300.0, 'hidden_dim4': 260.0, 'hidden_dim5': 200.0, 'hidden_dim6': 180.0, 'hidden_dim7': 200.0, 'hidden_dim8': 230.0}. This trial completed.
# Trial trainable_func_e5fbff08 reported score=0.46766826923076926,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'silu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.05088234161385608, 'batch_size': 32, 'hidden_dim1': 260.0, 'hidden_dim2': 200.0, 'hidden_dim3': 290.0, 'hidden_dim4': 260.0, 'hidden_dim5': 200.0, 'hidden_dim6': 190.0, 'hidden_dim7': 200.0, 'hidden_dim8': 230.0}.
# == Status ==
# Current time: 2022-07-26 20:17:15 (running for 00:16:11.08)
# Memory usage on this node: 2.1/12.7 GiB
# Using AsyncHyperBand: num_stopped=131
# Bracket: Iter 32.000: 0.628222767801959 | Iter 16.000: 0.5867326732673267 | Iter 8.000: 0.5610091023226617 | Iter 4.000: 0.5077398147162764
# Bracket: Iter 32.000: 0.6502970297029703 | Iter 16.000: 0.5743415126823417 | Iter 8.000: 0.49466318785578745
# Bracket: Iter 32.000: 0.5137122903558031 | Iter 16.000: 0.4730839055963375
# Bracket: Iter 32.000: 0.657235182849937
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_20-01-04
# Number of trials: 153/300 (1 PENDING, 4 RUNNING, 148 TERMINATED)
#
#
# Trial trainable_func_e7e41b70 reported score=0.44726930320150654,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'silu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 2.2077255549371166e-05, 'batch_size': 32, 'hidden_dim1': 260.0, 'hidden_dim2': 180.0, 'hidden_dim3': 290.0, 'hidden_dim4': 240.0, 'hidden_dim5': 200.0, 'hidden_dim6': 180.0, 'hidden_dim7': 210.0, 'hidden_dim8': 230.0}.
# Trial trainable_func_e5fbff08 reported score=0.46766826923076926,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'silu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.05088234161385608, 'batch_size': 32, 'hidden_dim1': 260.0, 'hidden_dim2': 200.0, 'hidden_dim3': 290.0, 'hidden_dim4': 260.0, 'hidden_dim5': 200.0, 'hidden_dim6': 190.0, 'hidden_dim7': 200.0, 'hidden_dim8': 230.0}. This trial completed.
# Trial trainable_func_c98bb9b2 reported score=0.5859183834556791,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'leaky_relu', 'act6 ': 'relu', 'act7': 'gelu', 'act8': 'relu', 'lr': 0.009595327635239142, 'batch_size': 64, 'hidden_dim1': 270.0, 'hidden_dim2': 280.0, 'hidden_dim3': 210.0, 'hidden_dim4': 280.0, 'hidden_dim5': 230.0, 'hidden_dim6': 200.0, 'hidden_dim7': 200.0, 'hidden_dim8': 200.0}.
# Trial trainable_func_de4c7152 reported score=0.6070361635220126,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'silu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.012223522715798857, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 200.0, 'hidden_dim3': 300.0, 'hidden_dim4': 260.0, 'hidden_dim5': 190.0, 'hidden_dim6': 200.0, 'hidden_dim7': 240.0, 'hidden_dim8': 240.0}.
# Trial trainable_func_efdf592a reported score=0.634812421185372,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'silu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.03992300840657008, 'batch_size': 32, 'hidden_dim1': 200.0, 'hidden_dim2': 180.0, 'hidden_dim3': 290.0, 'hidden_dim4': 240.0, 'hidden_dim5': 160.0, 'hidden_dim6': 200.0, 'hidden_dim7': 210.0, 'hidden_dim8': 220.0}.
# == Status ==
# Current time: 2022-07-26 20:17:20 (running for 00:16:16.17)
# Memory usage on this node: 2.1/12.7 GiB
# Using AsyncHyperBand: num_stopped=132
# Bracket: Iter 32.000: 0.628222767801959 | Iter 16.000: 0.587351655127625 | Iter 8.000: 0.5610091023226617 | Iter 4.000: 0.5077398147162764
# Bracket: Iter 32.000: 0.6502970297029703 | Iter 16.000: 0.5743415126823417 | Iter 8.000: 0.48663406748233584
# Bracket: Iter 32.000: 0.5137122903558031 | Iter 16.000: 0.4730839055963375
# Bracket: Iter 32.000: 0.657235182849937
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.36 GiB heap, 0.0/3.68 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_20-01-04
# Number of trials: 154/300 (1 PENDING, 4 RUNNING, 149 TERMINATED)
#
#
# Trial trainable_func_e7e41b70 reported score=0.44726930320150654,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'silu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 2.2077255549371166e-05, 'batch_size': 32, 'hidden_dim1': 260.0, 'hidden_dim2': 180.0, 'hidden_dim3': 290.0, 'hidden_dim4': 240.0, 'hidden_dim5': 200.0, 'hidden_dim6': 180.0, 'hidden_dim7': 210.0, 'hidden_dim8': 230.0}. This trial completed.
# Trial trainable_func_c98bb9b2 reported score=0.5859183834556791,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'leaky_relu', 'act6 ': 'relu', 'act7': 'gelu', 'act8': 'relu', 'lr': 0.009595327635239142, 'batch_size': 64, 'hidden_dim1': 270.0, 'hidden_dim2': 280.0, 'hidden_dim3': 210.0, 'hidden_dim4': 280.0, 'hidden_dim5': 230.0, 'hidden_dim6': 200.0, 'hidden_dim7': 200.0, 'hidden_dim8': 200.0}.
# Trial trainable_func_f1b09df4 reported score=0.5876047711154094,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'leaky_relu', 'act3 ': 'leaky_relu', 'act4 ': 'silu', 'act5 ': 'leaky_relu', 'act6 ': 'silu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.00015937381673596467, 'batch_size': 32, 'hidden_dim1': 300.0, 'hidden_dim2': 180.0, 'hidden_dim3': 290.0, 'hidden_dim4': 240.0, 'hidden_dim5': 160.0, 'hidden_dim6': 200.0, 'hidden_dim7': 210.0, 'hidden_dim8': 220.0}.
# Trial trainable_func_c98bb9b2 reported score=0.5859183834556791,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'leaky_relu', 'act6 ': 'relu', 'act7': 'gelu', 'act8': 'relu', 'lr': 0.009595327635239142, 'batch_size': 64, 'hidden_dim1': 270.0, 'hidden_dim2': 280.0, 'hidden_dim3': 210.0, 'hidden_dim4': 280.0, 'hidden_dim5': 230.0, 'hidden_dim6': 200.0, 'hidden_dim7': 200.0, 'hidden_dim8': 200.0}. This trial completed.
# Trial trainable_func_efdf592a reported score=0.634812421185372,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'silu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.03992300840657008, 'batch_size': 32, 'hidden_dim1': 200.0, 'hidden_dim2': 180.0, 'hidden_dim3': 290.0, 'hidden_dim4': 240.0, 'hidden_dim5': 160.0, 'hidden_dim6': 200.0, 'hidden_dim7': 210.0, 'hidden_dim8': 220.0}.
# Trial trainable_func_de4c7152 reported score=0.6070361635220126,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'silu', 'act6 ': 'silu', 'act7': 'leaky_relu', 'act8': 'relu', 'lr': 0.012223522715798857, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 200.0, 'hidden_dim3': 300.0, 'hidden_dim4': 260.0, 'hidden_dim5': 190.0, 'hidden_dim6': 200.0, 'hidden_dim7': 240.0, 'hidden_dim8': 240.0}.
# == Status ==
# Current time: 2022-07-26 20:17:26 (running for 00:16:21.59)
# Memory usage on this node: 2.1/12.7 GiB
# ...
# | trainable_func_8919afb4 | TERMINATED | 172.28.0.2:91421 |      |      | 0.00245057  |           32 | 0.586806 |                   32 |
# | trainable_func_8ef01900 | TERMINATED | 172.28.0.2:91369 |      |      | 0.00258275  |           32 | 0.594297 |                   32 |
# | trainable_func_930a04ec | TERMINATED | 172.28.0.2:91432 |      |      | 0.0493641   |           32 | 0.441127 |                    4 |
# | trainable_func_97dc5d76 | TERMINATED | 172.28.0.2:91432 |      |      | 0.000217065 |           64 | 0.393456 |                   32 |
# | trainable_func_9d2d9fa6 | TERMINATED | 172.28.0.2:91370 |      |      | 0.0170144   |           64 | 0.577997 |                   50 |
# | trainable_func_a69959ea | TERMINATED | 172.28.0.2:91432 |      |      | 0.00276551  |           64 | 0.516545 |                    8 |
# | trainable_func_b8260410 | TERMINATED | 172.28.0.2:91421 |      |      | 0.0165258   |           32 | 0.6138   |                   32 |
# | trainable_func_b9e513ae | TERMINATED | 172.28.0.2:91369 |      |      | 0.00712648  |           32 | 0.691038 |                   50 |
# | trainable_func_ba401718 | TERMINATED | 172.28.0.2:91432 |      |      | 0.0128393   |           32 | 0.485053 |                    4 |
# | trainable_func_beeb12fe | TERMINATED | 172.28.0.2:91432 |      |      | 0.01054     |           32 | 0.577773 |                   16 |
# | trainable_func_c4710abc | TERMINATED | 172.28.0.2:91370 |      |      | 0.00746178  |           32 | 0.391893 |                   32 |
# | trainable_func_d04a401a | TERMINATED | 172.28.0.2:91432 |      |      | 0.0104873   |           32 | 0.437147 |                   32 |
# | trainable_func_d84b7bf8 | TERMINATED | 172.28.0.2:91421 |      |      | 0.00748728  |           32 | 0.299366 |                    4 |
# | trainable_func_e192a9f2 | TERMINATED | 172.28.0.2:91421 |      |      | 0.0358173   |           32 | 0.557092 |                   16 |
# | trainable_func_e6781e70 | TERMINATED | 172.28.0.2:91370 |      |      | 0.0332724   |           32 | 0.492785 |                    4 |
# | trainable_func_f71647ac | TERMINATED | 172.28.0.2:91369 |      |      | 0.0360169   |           32 | 0.432775 |                    4 |
# | trainable_func_f790f5d8 | TERMINATED | 172.28.0.2:91421 |      |      | 0.00612472  |           32 | 0.517817 |                    8 |
# | trainable_func_fa611ba8 | TERMINATED | 172.28.0.2:91370 |      |      | 0.00648834  |           32 | 0.416    |                    4 |
# | trainable_func_fbecfa0a | TERMINATED | 172.28.0.2:91369 |      |      | 0.00601739  |           32 | 0.653408 |                   50 |
# | trainable_func_fc17d8ba | TERMINATED | 172.28.0.2:91432 |      |      | 1.17098e-05 |           32 | 0.623777 |                   50 |
# | trainable_func_fe99f4ba | TERMINATED | 172.28.0.2:91370 |      |      | 0.00622267  |           32 | 0.370701 |                    4 |
# | trainable_func_0103dd42 | TERMINATED | 172.28.0.2:91421 |      |      | 0.00856254  |           32 | 0.482926 |                    4 |
# | trainable_func_0502267e | TERMINATED | 172.28.0.2:91370 |      |      | 0.0273982   |           64 | 0.67505  |                   50 |
# | trainable_func_061a4b86 | TERMINATED | 172.28.0.2:91421 |      |      | 0.00875932  |           64 | 0.472827 |                    4 |
# | trainable_func_09d4562c | TERMINATED | 172.28.0.2:91421 |      |      | 2.03969e-05 |           64 | 0.566535 |                   16 |
# | trainable_func_0d12ed6c | TERMINATED | 172.28.0.2:91421 |      |      | 0.00508823  |           64 | 0.426407 |                    4 |
# | trainable_func_1985d3ac | TERMINATED | 172.28.0.2:91421 |      |      | 0.0128391   |           32 | 0.70743  |                   50 |
# | trainable_func_1cd7d366 | TERMINATED | 172.28.0.2:91370 |      |      | 0.0152274   |           32 | 0.680238 |                   50 |
# | trainable_func_2d3a22b8 | TERMINATED | 172.28.0.2:91369 |      |      | 0.0271201   |           64 | 0.372557 |                    4 |
# | trainable_func_37a4a282 | TERMINATED | 172.28.0.2:91369 |      |      | 0.0193854   |           32 | 0.627194 |                   50 |
# | trainable_func_3ac98554 | TERMINATED | 172.28.0.2:91432 |      |      | 0.0451857   |           32 | 0.381997 |                   16 |
# | trainable_func_3f0dd890 | TERMINATED | 172.28.0.2:91432 |      |      | 1.16453e-05 |           32 | 0.372255 |                   32 |
# | trainable_func_50c66552 | TERMINATED | 172.28.0.2:91421 |      |      | 1.17707e-05 |           32 | 0.518994 |                    8 |
# | trainable_func_5a65b522 | TERMINATED | 172.28.0.2:91421 |      |      | 1.15744e-05 |           32 | 0.448524 |                    4 |
# | trainable_func_632cff12 | TERMINATED | 172.28.0.2:91421 |      |      | 1.3441e-05  |           32 | 0.620169 |                   32 |
# | trainable_func_67e538b2 | TERMINATED | 172.28.0.2:91370 |      |      | 1.01472e-05 |           32 | 0.340093 |                    4 |
# | trainable_func_6b69a4aa | TERMINATED | 172.28.0.2:91370 |      |      | 0.014305    |           32 | 0.500613 |                    4 |
# | trainable_func_70510648 | TERMINATED | 172.28.0.2:91369 |      |      | 0.0127304   |           32 | 0.488205 |                    8 |
# | trainable_func_71fff44a | TERMINATED | 172.28.0.2:91432 |      |      | 0.0142376   |           32 | 0.605643 |                   50 |
# | trainable_func_73f4c514 | TERMINATED | 172.28.0.2:91370 |      |      | 0.014132    |           32 | 0.517492 |                    8 |
# | trainable_func_7569bd50 | TERMINATED | 172.28.0.2:91369 |      |      | 0.0192244   |           32 | 0.631451 |                   50 |
# | trainable_func_7b7afa74 | TERMINATED | 172.28.0.2:91370 |      |      | 0.026162    |           32 | 0.666549 |                   50 |
# | trainable_func_7e67af0c | TERMINATED | 172.28.0.2:91421 |      |      | 0.00379565  |           32 | 0.467083 |                    4 |
# | trainable_func_8f89b4ba | TERMINATED | 172.28.0.2:91421 |      |      | 0.0216091   |           32 | 0.447333 |                    4 |
# | trainable_func_94670bf4 | TERMINATED | 172.28.0.2:91421 |      |      | 0.0197091   |           32 | 0.460902 |                    4 |
# | trainable_func_9984ad26 | TERMINATED | 172.28.0.2:91421 |      |      | 0.00477396  |           32 | 0.502358 |                    4 |
# | trainable_func_9e884814 | TERMINATED | 172.28.0.2:91421 |      |      | 0.0239859   |           32 | 0.449087 |                    4 |
# | trainable_func_a34fb3dc | TERMINATED | 172.28.0.2:91421 |      |      | 0.000437039 |           32 | 0.605493 |                   32 |
# | trainable_func_a859f5d6 | TERMINATED | 172.28.0.2:91432 |      |      | 1.40488e-05 |           32 | 0.558376 |                   16 |
# | trainable_func_af8e4b04 | TERMINATED | 172.28.0.2:91369 |      |      | 1.38869e-05 |           32 | 0.624832 |                   32 |
# | trainable_func_b81932e8 | TERMINATED | 172.28.0.2:91370 |      |      | 0.0107577   |           32 | 0.541001 |                   16 |
# | trainable_func_bda9709c | TERMINATED | 172.28.0.2:91432 |      |      | 0.0177393   |           32 | 0.534541 |                    8 |
# | trainable_func_c5076560 | TERMINATED | 172.28.0.2:91432 |      |      | 0.0174617   |           32 | 0.543413 |                   16 |
# | trainable_func_cf380062 | TERMINATED | 172.28.0.2:91421 |      |      | 0.000429355 |           32 | 0.536594 |                    8 |
# | trainable_func_d18ed796 | TERMINATED | 172.28.0.2:91370 |      |      | 0.0196106   |           64 | 0.564503 |                   50 |
# | trainable_func_d1c6f0b8 | TERMINATED | 172.28.0.2:91421 |      |      | 0.0253934   |           64 | 0.309025 |                    4 |
# | trainable_func_db909b9e | TERMINATED | 172.28.0.2:91421 |      |      | 0.0262948   |           32 | 0.435627 |                    8 |
# | trainable_func_df2cf89c | TERMINATED | 172.28.0.2:91369 |      |      | 0.0194032   |           32 | 0.673737 |                   50 |
# | trainable_func_e1d764f6 | TERMINATED | 172.28.0.2:91432 |      |      | 0.0185984   |           32 | 0.36242  |                    8 |
# | trainable_func_e3803378 | TERMINATED | 172.28.0.2:91421 |      |      | 0.000714825 |           32 | 0.517247 |                   16 |
# | trainable_func_e91f3b4e | TERMINATED | 172.28.0.2:91432 |      |      | 0.0194437   |           32 | 0.618103 |                   50 |
# | trainable_func_ee05ad6e | TERMINATED | 172.28.0.2:91370 |      |      | 6.10406e-05 |           32 | 0.348629 |                    4 |
# | trainable_func_fa3de65a | TERMINATED | 172.28.0.2:91421 |      |      | 5.78075e-05 |           32 | 0.623232 |                   32 |
# | trainable_func_fc6d9c0e | TERMINATED | 172.28.0.2:91370 |      |      | 0.000134946 |           32 | 0.442362 |                    4 |
# | trainable_func_ffd53a46 | TERMINATED | 172.28.0.2:91370 |      |      | 1.6439e-05  |           32 | 0.521462 |                    8 |
# | trainable_func_0559403e | TERMINATED | 172.28.0.2:91370 |      |      | 1.67529e-05 |           32 | 0.524484 |                   32 |
# | trainable_func_0ed8b4dc | TERMINATED | 172.28.0.2:91369 |      |      | 0.00921419  |           64 | 0.559378 |                   32 |
# | trainable_func_1ee64c36 | TERMINATED | 172.28.0.2:91421 |      |      | 0.0153545   |           64 | 0.49081  |                    4 |
# | trainable_func_25ab6d9e | TERMINATED | 172.28.0.2:91421 |      |      | 0.0116403   |           64 | 0.583333 |                   50 |
# | trainable_func_292094d6 | TERMINATED | 172.28.0.2:91432 |      |      | 0.00897897  |           64 | 0.314192 |                    8 |
# | trainable_func_2ddba7a4 | TERMINATED | 172.28.0.2:91370 |      |      | 0.0114324   |           64 | 0.344397 |                    4 |
# | trainable_func_313244b2 | TERMINATED | 172.28.0.2:91432 |      |      | 0.023615    |           64 | 0.596114 |                   50 |
# | trainable_func_344fe730 | TERMINATED | 172.28.0.2:91370 |      |      | 0.0111251   |           32 | 0.426292 |                    8 |
# | trainable_func_34a109d0 | TERMINATED | 172.28.0.2:91369 |      |      | 0.0223019   |           32 | 0.459744 |                    4 |
# | trainable_func_3941df64 | TERMINATED | 172.28.0.2:91369 |      |      | 0.0231239   |           32 | 0.407915 |                    8 |
# | trainable_func_3e369dd4 | TERMINATED | 172.28.0.2:91370 |      |      | 0.0284611   |           32 | 0.586297 |                   32 |
# | trainable_func_3e9c48d2 | TERMINATED | 172.28.0.2:91369 |      |      | 0.0295256   |           32 | 0.57014  |                   16 |
# | trainable_func_49155362 | TERMINATED | 172.28.0.2:91421 |      |      | 0.0314885   |           32 | 0.372579 |                    8 |
# | trainable_func_53866214 | TERMINATED | 172.28.0.2:91432 |      |      | 0.000267857 |           32 | 0.584469 |                   16 |
# | trainable_func_5b094240 | TERMINATED | 172.28.0.2:91369 |      |      | 0.00010751  |           32 | 0.503842 |                    4 |
# | trainable_func_5c726d28 | TERMINATED | 172.28.0.2:91421 |      |      | 0.000111508 |           32 | 0.582994 |                   32 |
# | trainable_func_5e23b5e6 | TERMINATED | 172.28.0.2:91369 |      |      | 0.0071323   |           32 | 0.603956 |                   50 |
# | trainable_func_60ee3daa | TERMINATED | 172.28.0.2:91370 |      |      | 0.0428143   |           32 | 0.666429 |                   50 |
# | trainable_func_69bdbf14 | TERMINATED | 172.28.0.2:91432 |      |      | 0.00195397  |           32 | 0.517985 |                    8 |
# | trainable_func_6cd7fe94 | TERMINATED | 172.28.0.2:91432 |      |      | 0.00196071  |           32 | 0.40418  |                    8 |
# | trainable_func_7580918c | TERMINATED | 172.28.0.2:91432 |      |      | 0.00706557  |           32 | 0.568713 |                    8 |
# | trainable_func_7de63c00 | TERMINATED | 172.28.0.2:91421 |      |      | 0.0500415   |           32 | 0.594713 |                   32 |
# | trainable_func_86f625e4 | TERMINATED | 172.28.0.2:91432 |      |      | 0.00716972  |           32 | 0.671727 |                   50 |
# | trainable_func_888cc4a8 | TERMINATED | 172.28.0.2:91369 |      |      | 0.0445412   |           64 | 0.390537 |                    8 |
# | trainable_func_986f348c | TERMINATED | 172.28.0.2:91369 |      |      | 0.0402556   |           64 | 0.609415 |                   32 |
# | trainable_func_9eff7da2 | TERMINATED | 172.28.0.2:91370 |      |      | 0.0148992   |           32 | 0.405652 |                   32 |
# | trainable_func_a6525f2a | TERMINATED | 172.28.0.2:91421 |      |      | 0.000196057 |           32 | 0.332586 |                    4 |
# | trainable_func_ad1b3426 | TERMINATED | 172.28.0.2:91421 |      |      | 0.0153682   |           32 | 0.568651 |                   50 |
# | trainable_func_b1fbbcd6 | TERMINATED | 172.28.0.2:91369 |      |      | 0.0379812   |           64 | 0.352553 |                    4 |
# | trainable_func_b6d3e814 | TERMINATED | 172.28.0.2:91369 |      |      | 0.00113799  |           32 | 0.548085 |                    8 |
# | trainable_func_b9fd076e | TERMINATED | 172.28.0.2:91369 |      |      | 0.0149213   |           32 | 0.380364 |                    4 |
# | trainable_func_c465405e | TERMINATED | 172.28.0.2:91432 |      |      | 0.00562791  |           32 | 0.47044  |                    4 |
# | trainable_func_c5b37570 | TERMINATED | 172.28.0.2:91369 |      |      | 0.00566021  |           32 | 0.535516 |                    8 |
# | trainable_func_c96ee604 | TERMINATED | 172.28.0.2:91432 |      |      | 0.0077816   |           32 | 0.4292   |                   50 |
# | trainable_func_caaa9540 | TERMINATED | 172.28.0.2:91370 |      |      | 0.00874887  |           32 | 0.518536 |                    8 |
# | trainable_func_d07f1c16 | TERMINATED | 172.28.0.2:91369 |      |      | 0.00793022  |           64 | 0.397108 |                    4 |
# | trainable_func_d2b36118 | TERMINATED | 172.28.0.2:91369 |      |      | 0.00358874  |           64 | 0.362534 |                    4 |
# | trainable_func_d6142acc | TERMINATED | 172.28.0.2:91369 |      |      | 0.00945338  |           32 | 0.473629 |                    8 |
# | trainable_func_d9684744 | TERMINATED | 172.28.0.2:91370 |      |      | 0.0043594   |           32 | 0.49137  |                    4 |
# | trainable_func_da4e48de | TERMINATED | 172.28.0.2:91370 |      |      | 0.00457927  |           32 | 0.535403 |                   16 |
# | trainable_func_def6a7be | TERMINATED | 172.28.0.2:91369 |      |      | 0.0651272   |           32 | 0.500355 |                    4 |
# | trainable_func_e3134f28 | TERMINATED | 172.28.0.2:91369 |      |      | 0.059508    |           32 | 0.404699 |                    4 |
# | trainable_func_e8308e94 | TERMINATED | 172.28.0.2:91369 |      |      | 0.00496808  |           32 | 0.495067 |                    4 |
# | trainable_func_eccd3678 | TERMINATED | 172.28.0.2:91421 |      |      | 0.0174012   |           64 | 0.476874 |                    4 |
# | trainable_func_f136140a | TERMINATED | 172.28.0.2:91369 |      |      | 7.83712e-05 |           64 | 0.473556 |                    8 |
# | trainable_func_f1cb9214 | TERMINATED | 172.28.0.2:91370 |      |      | 0.00683485  |           64 | 0.571434 |                   16 |
# +-------------------------+------------+------------------+------+------+-------------+--------------+----------+----------------------+
# 2022-07-26 20:39:05,143	INFO tune.py:748 -- Total run time: 2280.55 seconds (2280.28 seconds for the tuning loop).
# Best trial config: {'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'leaky_relu', 'act6 ': 'silu', 'act7': 'leaky_relu', 'act8': 'gelu', 'lr': 0.0009176891230811991, 'batch_size': 32, 'hidden_dim1': 250.0, 'hidden_dim2': 190.0, 'hidden_dim3': 300.0, 'hidden_dim4': 260.0, 'hidden_dim5': 190.0, 'hidden_dim6': 210.0, 'hidden_dim7': 210.0, 'hidden_dim8': 170.0}
# Best trial final validation score: 0.7075597336466902
# Best trial test set score: 0.7302301910429063

# %% [markdown]
# Best trial config: {'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'leaky_relu', 'act6 ': 'silu', 'act7': 'leaky_relu', 'act8': 'gelu', 'lr': 0.0009176891230811991, 'batch_size': 32, 'hidden_dim1': 250.0, 'hidden_dim2': 190.0, 'hidden_dim3': 300.0, 'hidden_dim4': 260.0, 'hidden_dim5': 190.0, 'hidden_dim6': 210.0, 'hidden_dim7': 210.0, 'hidden_dim8': 170.0}
#
#
# Best trial final **validation score**: 0.7348068563930124
#
# Best trial **test set score**: 0.7028917177432028

# %%
import random
random.seed(1234)
Best_trial_config ={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'leaky_relu', 'act6 ': 'silu', 'act7': 'leaky_relu', 'act8': 'gelu', 'lr': 0.0009176891230811991, 'batch_size': 32, 'hidden_dim1': 250.0, 'hidden_dim2': 190.0, 'hidden_dim3': 300.0, 'hidden_dim4': 260.0, 'hidden_dim5': 190.0, 'hidden_dim6': 210.0, 'hidden_dim7': 210.0, 'hidden_dim8': 170.0}

epochs = 10
config ={'act1 ': 'relu', 'act2 ': 'silu', 'act3 ': 'leaky_relu', 'act4 ': 'leaky_relu', 'act5 ': 'leaky_relu', 'act6 ': 'silu', 'act7': 'leaky_relu', 'act8': 'gelu', 'lr': 0.0009176891230811991, 'batch_size': 32, 'hidden_dim1': 250.0, 'hidden_dim2': 190.0, 'hidden_dim3': 300.0, 'hidden_dim4': 260.0, 'hidden_dim5': 190.0, 'hidden_dim6': 210.0, 'hidden_dim7': 210.0, 'hidden_dim8': 170.0}
net = Net(Best_trial_config)
criterion = nn.CrossEntropyLoss()

    # # Define an optimizer 
optimizer = optim.Adam(net.parameters(), lr=config.get("lr",0.0003))

trainset, testset = load_data()

    # Split the dataset into training and validation sets
train_size = int(len(trainset) * 0.825)
train_subset, val_subset = random_split(trainset, [train_size, len(trainset) - train_size])

    # Define data loaders (which combines a dataset and a sampler, and provides an iterable over the given dataset)
trainloader = torch.utils.data.DataLoader(
    train_subset,
    batch_size=int(config.get("batch_size",32)),
    shuffle=False,
    num_workers=2)
valloader = torch.utils.data.DataLoader(
    val_subset,
    batch_size=int(config.get("batch_size",32)),
    shuffle=False,
    num_workers=2)
for epoch in range(epochs):  # loop over the dataset multiple times
        epoch_train_loss = 0.0
        # epoch_steps = 0
        net.train() # Prepare model for training
        for i, data in enumerate(trainloader):
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            '''
            Compute train loss without scaling to print
            ''' 

        score = compute_score(net, valloader, device="cpu")
        with tune.checkpoint_dir(epoch) as checkpoint_dir:
            path = os.path.join(checkpoint_dir, "checkpoint")
            torch.save((net.state_dict(), optimizer.state_dict()), path)
        tune.report(score=score)
print("Finished Training")
device = "cpu"
test_score_value = test_score(Best_trial_config, net, device)
print(test_score_value)
# Out:
# 2022-07-26 21:05:20,691	WARNING session.py:35 -- Session not detected. You should not be calling `checkpoint_dir` outside `tune.run` or while using the class API.
# 2022-07-26 21:05:20,693	WARNING session.py:38 --   File "/usr/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.7/dist-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelapp.py", line 499, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.7/dist-packages/tornado/platform/asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/usr/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.7/dist-packages/tornado/platform/asyncio.py", line 122, in _handle_events
#     handler_func(fileobj, events)
#   File "/usr/local/lib/python3.7/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 577, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 606, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 556, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-161-cffed99abe1c>", line 53, in <module>
#     with tune.checkpoint_dir(epoch) as checkpoint_dir:
#   File "/usr/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#
# 2022-07-26 21:05:20,744	WARNING session.py:35 -- Session not detected. You should not be calling `report` outside `tune.run` or while using the class API.
# 2022-07-26 21:05:20,746	WARNING session.py:38 --   File "/usr/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.7/dist-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelapp.py", line 499, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.7/dist-packages/tornado/platform/asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/usr/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.7/dist-packages/tornado/platform/asyncio.py", line 122, in _handle_events
#     handler_func(fileobj, events)
#   File "/usr/local/lib/python3.7/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 577, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 606, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 556, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.7/dist-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-161-cffed99abe1c>", line 56, in <module>
#     tune.report(score=score)
# Finished Training
# Best trial test set score: 0.6891246476667711
# None

# %% [markdown]
#  **test** **set** **score** **on** **our** **model**: 0.6891246476667711

# %% [markdown]
# # Other Schedulers and search algorithms of Ray Tune

# %%
# !pip install -U hyperopt
# !pip install hpbandster ConfigSpace
# !pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.7/dist-packages (0.2.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from hyperopt) (4.64.0)
# Requirement already satisfied: py4j in /usr/local/lib/python3.7/dist-packages (from hyperopt) (0.10.9.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from hyperopt) (1.15.0)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.7/dist-packages (from hyperopt) (2.6.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from hyperopt) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from hyperopt) (1.7.3)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from hyperopt) (2.1.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from hyperopt) (0.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: hpbandster in /usr/local/lib/python3.7/dist-packages (0.7.4)
# Requirement already satisfied: ConfigSpace in /usr/local/lib/python3.7/dist-packages (0.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from hpbandster) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from hpbandster) (1.7.3)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.7/dist-packages (from hpbandster) (0.10.2)
# Requirement already satisfied: netifaces in /usr/local/lib/python3.7/dist-packages (from hpbandster) (0.11.0)
# Requirement already satisfied: Pyro4 in /usr/local/lib/python3.7/dist-packages (from hpbandster) (4.82)
# Requirement already satisfied: serpent in /usr/local/lib/python3.7/dist-packages (from hpbandster) (1.41)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from ConfigSpace) (3.0.9)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from ConfigSpace) (0.29.30)
# Requirement already satisfied: patsy>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from statsmodels->hpbandster) (0.5.2)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from statsmodels->hpbandster) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->statsmodels->hpbandster) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->statsmodels->hpbandster) (2022.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.4.0->statsmodels->hpbandster) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: optuna in /usr/local/lib/python3.7/dist-packages (2.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (21.3)
# Requirement already satisfied: cmaes>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from optuna) (0.8.2)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.4.39)
# Requirement already satisfied: scipy!=1.4.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.7.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from optuna) (4.64.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from optuna) (6.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.7/dist-packages (from optuna) (6.6.0)
# Requirement already satisfied: alembic in /usr/local/lib/python3.7/dist-packages (from optuna) (1.8.1)
# Requirement already satisfied: cliff in /usr/local/lib/python3.7/dist-packages (from optuna) (3.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from optuna) (1.21.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->optuna) (3.0.9)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (1.1.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (4.12.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from alembic->optuna) (5.8.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.7/dist-packages (from alembic->optuna) (1.2.1)
# Requirement already satisfied: autopage>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (0.5.1)
# Requirement already satisfied: stevedore>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (3.5.0)
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (3.3.0)
# Requirement already satisfied: cmd2>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (2.4.2)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (5.9.0)
# Requirement already satisfied: attrs>=16.3.0 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (21.4.0)
# Requirement already satisfied: pyperclip>=1.6 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (1.8.2)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (0.2.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy>=1.1.0->optuna) (3.8.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from Mako->alembic->optuna) (2.0.1)

# %%
from ray.tune.suggest.hyperopt import HyperOptSearch
from ray.tune.suggest.optuna import OptunaSearch  
from ray.tune.suggest.dragonfly import DragonflySearch
from ray.tune.suggest.bayesopt import BayesOptSearch
from ray.tune.schedulers.hb_bohb import HyperBandForBOHB
from ray.tune.schedulers import AsyncHyperBandScheduler
from ray.tune.schedulers import MedianStoppingRule
from ray.tune.schedulers import PopulationBasedTraining
from ray.tune.suggest.bohb import TuneBOHB
from ray.tune.suggest.basic_variant import BasicVariantGenerator
from ray.tune.suggest import ConcurrencyLimiter

# %% [markdown]
# **Schedulers**

# %%
training_iteration = 50 #max_num_epochs

## ASHA
scheduler = AsyncHyperBandScheduler(
    time_attr="training_iteration",
    max_t=training_iteration,
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    reduction_factor=2, 
    grace_period=4,
    brackets=5,
    )

## BOHB
scheduler = HyperBandForBOHB(
    time_attr="training_iteration",
    max_t=training_iteration, 
    reduction_factor=8, 
    stop_last_trials=True,
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    )

## Median
scheduler = MedianStoppingRule(
    time_attr="training_iteration",
    grace_period=10,
    min_samples_required=10,
    hard_stop = True,
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    )

## PBT
scheduler = PopulationBasedTraining(
    time_attr="training_iteration",
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    perturbation_interval=10,  # every 10 `time_attr` units
                            # (training_iterations in this case)
    # hyperparam_mutations={
    #     "lr": [8e-3, 7e-3, 6e-3, 5e-3, 4e-3],
    #     "dropout": tune.quniform(0.0, 0.4, 0.05),
    #     "dropout1": tune.quniform(0.0, 0.4, 0.05),
    #     "dropout2": tune.quniform(0.0, 0.4, 0.05),
    #     "max_norm_val":tune.choice([2.5, 3, 3.5, 4]),
    #     }
    )

# %% [markdown]
# # Search algorithms

# %%
pip install dragonfly-opt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: dragonfly-opt in /usr/local/lib/python3.7/dist-packages (0.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from dragonfly-opt) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from dragonfly-opt) (1.7.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from dragonfly-opt) (1.15.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from dragonfly-opt) (0.16.0)

# %%
from ray.tune.suggest.dragonfly import DragonflySearch as DragonflySearch1

# %%
## BOHB
search_alg = TuneBOHB(
    # space=config_space,  # If you want to set the space manually
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    # seed = 42,
    # points_to_evaluate=[
    # ],
    )

## Hyperopt
search_alg = HyperOptSearch(
    # space=config,
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    n_initial_points=60,
    # gamma = 0.1,
    # random_state_seed=42,
    # points_to_evaluate=[{"max_norm_val": 2.5, 'GNN_Layers': 3, 'dropout': 0.25, 'dropout1': 0.35, 'dropout2': 0.15, 'lr': 0.001, 'hidden_size': 80, 'readout1_out': 150, 'readout2_out': 100, 'batch_size': 64}],
    )

## Optuna
search_alg = OptunaSearch(
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    # seed = 42,
    # points_to_evaluate=[
    # {'dropout': 0.2, 'dropout1': 0.1, 'dropout2': 0.25, 'lr': 0.0005, 'hidden_size': 150.0, 'readout1_out': 200.0, 'readout2_out': 180.0, 'max_norm_val': 2.5}
    # ],
    )

## Dragonfly
#search_alg = DragonflySearch1(
#    metric="loss", #or accuracy, etc.
#    mode="min", #or max
#    optimizer="bandit", #[random, bandit, genetic]
    # points_to_evaluate=[
    # {'max_norm_val': 2.5, 'dropout': 0.3, 'dropout1': 0.1, 'dropout2': 0.0, 'lr': 0.0008, 'hidden_size': 90, 'readout1_out': 150, 'readout2_out': 140}
    # ],
    # domain=euclidean, #[cartesian, euclidean]
#    )

## Bayesopt
#search_alg = BayesOptSearch(
#    metric="loss", #or accuracy, etc.
#    mode="min", #or max
#    random_search_steps = 60, 
    # points_to_evaluate=[
    # {'max_norm_val': 2.5, 'dropout': 0.3, 'dropout1': 0.1, 'dropout2': 0.0, 'lr': 0.0008, 'hidden_size': 90, 'readout1_out': 150, 'readout2_out': 140}
    # ],
#    )
