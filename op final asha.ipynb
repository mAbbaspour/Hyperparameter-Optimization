# %% [markdown]
# <a href="https://colab.research.google.com/github/mAbbaspour/Hyperparameter-Optimization/blob/main/op%20final%20asha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as f
import numpy as np
import math;

# %%
from google.colab import files
uploaded = files.upload()
uploaded2 = files.upload()
# Out:
#      <input type="file" id="files-388963db-cdec-4ecf-afe7-577d1aabcc9c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-388963db-cdec-4ecf-afe7-577d1aabcc9c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lipo(Lables).csv to lipo(Lables).csv
#      <input type="file" id="files-0bec4647-d8ef-4f26-835e-131a37740b32" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0bec4647-d8ef-4f26-835e-131a37740b32">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lipo_global_cdf_rdkit.csv to lipo_global_cdf_rdkit.csv

# %%
import random
random.seed(1)
import pandas as pd
import io
from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv(io.BytesIO(uploaded2['lipo_global_cdf_rdkit.csv']))
dataY = pd.read_csv(io.BytesIO(uploaded['lipo(Lables).csv']))
print(data[data.isnull().any(axis=1)])
# Out:
#       ('RDKit2DNormalized_calculated', <class 'bool'>)  \
# 1561                                              True
#
#       ('BalabanJ', <class 'numpy.float64'>)  \
# 1561                                  0.895
#
#       ('BertzCT', <class 'numpy.float64'>)  ('Chi0', <class 'numpy.float64'>)  \
# 1561                              0.230752                           0.031331
#
#       ('Chi0n', <class 'numpy.float64'>)  ('Chi0v', <class 'numpy.float64'>)  \
# 1561                            0.032387                            0.061726
#
#       ('Chi1', <class 'numpy.float64'>)  ('Chi1n', <class 'numpy.float64'>)  \
# 1561                           0.050799                            0.045963
#
#       ('Chi1v', <class 'numpy.float64'>)  ('Chi2n', <class 'numpy.float64'>)  \
# 1561                            0.116251                             0.04344
#
#       ...  ('fr_sulfonamd', <class 'numpy.float64'>)  \
# 1561  ...                               1.593061e-17
#
#       ('fr_sulfone', <class 'numpy.float64'>)  \
# 1561                             5.766101e-14
#
#       ('fr_term_acetylene', <class 'numpy.float64'>)  \
# 1561                                    2.957989e-11
#
#       ('fr_tetrazole', <class 'numpy.float64'>)  \
# 1561                                   0.168378
#
#       ('fr_thiazole', <class 'numpy.float64'>)  \
# 1561                                   0.16738
#
#       ('fr_thiocyan', <class 'numpy.float64'>)  \
# 1561                              1.481515e-18
#
#       ('fr_thiophene', <class 'numpy.float64'>)  \
# 1561                               2.324150e-16
#
#       ('fr_unbrch_alkane', <class 'numpy.float64'>)  \
# 1561                                   4.703598e-08
#
#       ('fr_urea', <class 'numpy.float64'>)  ('qed', <class 'numpy.float64'>)
# 1561                              0.166633                          0.542261
#
# [1 rows x 201 columns]

# %%
data = data.drop(1561)
dataY = dataY.drop(1561)

# %%
arrayY = dataY.values
Y = arrayY[0: ,1 ]
array = data.values
X = array[0:,1:]

# %%
X_train, X_test ,Y_train , Y_test  = train_test_split(X, Y ,test_size=0.2)
scaler_data  = preprocessing.MinMaxScaler()
X_train = scaler_data.fit_transform(X_train)
X_test =  scaler_data.transform(X_test)
scaler_labels = preprocessing.MinMaxScaler()
Y_train = scaler_labels.fit_transform(Y_train.reshape(-1, 1))
Y_test = scaler_labels.transform(Y_test.reshape(-1, 1))

# %%
print(X_test.shape)
print(Y_test.shape)
print(X_train.shape)
print(Y_train.shape)
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
# Out:
# (840, 200)
# (840, 1)
# (3359, 200)
# (3359, 1)

# %%
Y_train_new =  Y_train.astype(np.float)
Y_test_new = Y_test.astype(np.float)
print(Y_train_new.shape)
print(Y_test_new.shape)
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
tensor_x_train = torch.tensor(X_train, dtype=torch.float).to(device) 
tensor_x_test = torch.tensor(X_test, dtype=torch.float).to(device) 

tensor_y_train = torch.tensor(Y_train_new , dtype=torch.float).to(device)
tensor_y_test= torch.tensor(Y_test_new, dtype=torch.float).to(device)
# Out:
# (3359, 1)
# (840, 1)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
from torch.utils.data import TensorDataset
trainset = TensorDataset(tensor_x_train, tensor_y_train) 
testset = TensorDataset(tensor_x_test,tensor_y_test)

# %%
# %%capture
try:
    import ray
except:
    # !pip install -U ray
    import ray

# %%
from functools import partial
import numpy as np
import os
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import random_split
from torchsummary import summary

from ray import tune
# a = {"a":tune.quniform(50, 200, 10) , "b": 5}
# print(type(a.get("a")))
from ray.tune import CLIReporter
from ray.tune.schedulers import ASHAScheduler

# %%
def load_data(data_dir=None):
    return trainset, testset

# %%
# # Net().__init__(self , confing) 
#     config = {
#         "act1 ": tune.choice(["relu","tanh","selu"]),
#         "act2" : tune.choice(["relu","tanh","selu"]),
#         "act3" : tune.choice(["relu","tanh","selu"]),
#         "lr": tune.quniform(0.0005, 0.001, 0.0001),
#         "batch_size": tune.choice([8, 16, 32]),
#         "hidden_dim1" : tune.quniform(50, 200, 10),
#         "hidden_dim2" : tune.quniform(50, 200, 10),
#         "hidden_dim3" : tune.quniform(50, 200, 10),
#     }
#   self = { "confing": confing , "hd":}
class Net(nn.Module):
    def __init__(self, config):
        super().__init__()

        self.config = config
        self.hidden_dim1 = int(self.config.get("hidden_dim1", 100))
        self.hidden_dim2 = int(self.config.get("hidden_dim2", 100))
        self.hidden_dim3 = int(self.config.get("hidden_dim3", 100))

        self.act1 = self.config.get("act1", "relu") 
        self.act2 = self.config.get("act2", "relu") 
        self.act3 = self.config.get("act3", "relu")

        self.linear1 = nn.Linear(200, self.hidden_dim1)
        self.linear2 = nn.Linear(self.hidden_dim1, self.hidden_dim2)
        self.linear3 = nn.Linear(self.hidden_dim2, self.hidden_dim3)
        self.linear4 = nn.Linear(self.hidden_dim3, 1)
    
    @staticmethod
    def activation_func(act_str):
        if act_str=="tanh":
            return eval("torch."+act_str)
        elif act_str=="selu" or act_str=="relu":   
            return eval("torch.nn.functional."+act_str)

    def forward(self, x):
        output = self.linear1(x)
        output = self.activation_func(self.act1)(output)
        output = self.linear2(output)
        output = self.activation_func(self.act2)(output)
        output = self.linear3(output)
        output = self.activation_func(self.act3)(output)
        output = self.linear4(output)        
        return output

# %%
model = Net({})

# %%
from prettytable import PrettyTable

def count_parameters(model):
    table = PrettyTable(["Modules", "Parameters"])
    total_params = 0
    for name, parameter in model.named_parameters():
        if not parameter.requires_grad: continue
        param = parameter.numel()
        table.add_row([name, param])
        total_params+=param
    print(table)
    print(f"Total Trainable Params: {total_params}")
    return total_params

# %%
summary(model, (1,tensor_x_train.shape[1]))

count_parameters(model)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1               [-1, 1, 100]          20,100
#             Linear-2               [-1, 1, 100]          10,100
#             Linear-3               [-1, 1, 100]          10,100
#             Linear-4                 [-1, 1, 1]             101
# ================================================================
# Total params: 40,401
# Trainable params: 40,401
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.15
# Estimated Total Size (MB): 0.16
# ----------------------------------------------------------------
# +----------------+------------+
# |    Modules     | Parameters |
# +----------------+------------+
# | linear1.weight |   20000    |
# |  linear1.bias  |    100     |
# | linear2.weight |   10000    |
# |  linear2.bias  |    100     |
# | linear3.weight |   10000    |
# |  linear3.bias  |    100     |
# | linear4.weight |    100     |
# |  linear4.bias  |     1      |
# +----------------+------------+
# Total Trainable Params: 40401
# 40401

# %%
def trainable_func(config, checkpoint_dir=None, data_dir=None, epochs=10):

    net = Net(config)

    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda:0"
        if torch.cuda.device_count() > 1:
            net = nn.DataParallel(net)
    net.to(device)

    '''
    Define a loss function
    '''
    ## Classification
    # criterion = nn.CrossEntropyLoss()

    ## Regression
    criterion = nn.MSELoss(reduction='sum')

    # Define an optimizer 
    optimizer = optim.Adam(net.parameters(), lr=config.get("lr",0.0003))

    if checkpoint_dir:
        model_state, optimizer_state = torch.load(
            os.path.join(checkpoint_dir, "checkpoint"))
        net.load_state_dict(model_state)
        optimizer.load_state_dict(optimizer_state)

    # Load data
    trainset, testset = load_data(data_dir)

    # Split the dataset into training and validation sets
    train_size = int(len(trainset) * 0.8)
    train_subset, val_subset = random_split(trainset, [train_size, len(trainset) - train_size])

    # Define data loaders (which combines a dataset and a sampler, and provides an iterable over the given dataset)
    trainloader = torch.utils.data.DataLoader(
        train_subset,
        batch_size=int(config.get("batch_size",32)),
        shuffle=True,
        num_workers=2)
    valloader = torch.utils.data.DataLoader(
        val_subset,
        batch_size=int(config.get("batch_size",32)),
        shuffle=True,
        num_workers=2)

    for epoch in range(epochs):  # loop over the dataset multiple times
        epoch_train_loss = 0.0
        # epoch_steps = 0
        net.train() # Prepare model for training
        for i, data in enumerate(trainloader):
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            '''
            Compute train loss without scaling to print
            ''' 
            # outputs = torch.tensor(scaler_labels.inverse_transform(outputs.detach().cpu())).to(device)    
            # labels = torch.tensor(scaler_labels.inverse_transform(labels.cpu())).to(device)  
            # loss_train = criterion(outputs, labels) 
            # epoch_train_loss += loss_train.detach().item()
        # print("[%d] loss: %.3f" % (epoch + 1, epoch_train_loss / len(train_subset)))

        # Validation loss
        val_loss = 0.0
        net.eval() # Prepare model for evaluation
        for i, data in enumerate(valloader):
            with torch.no_grad():
                inputs, labels = data
                inputs, labels = inputs.to(device), labels.to(device)

                outputs = net(inputs)

                # Inverse transform of the labels' scaler
                outputs = torch.tensor(scaler_labels.inverse_transform(outputs.detach().cpu())).to(device)    
                labels = torch.tensor(scaler_labels.inverse_transform(labels.cpu())).to(device) 

                loss = criterion(outputs, labels)
                val_loss += loss.cpu().numpy()

        with tune.checkpoint_dir(epoch) as checkpoint_dir:
            path = os.path.join(checkpoint_dir, "checkpoint")
            torch.save((net.state_dict(), optimizer.state_dict()), path)

        tune.report(epoch = epoch, loss=(val_loss / len(val_subset)))
    print("Finished Training")

# %%
def test_score(config, net, device="cpu"):
    trainset, testset = load_data()

    testloader = torch.utils.data.DataLoader(
        testset, batch_size=int(config.get("batch_size",32)), shuffle=False, num_workers=2)
    
    ## Regression
    criterion = nn.MSELoss(reduction='sum')

    # Test loss
    test_loss = 0.0
    net.eval() # Prepare model for evaluation
    for i, data in enumerate(testloader):
        with torch.no_grad():
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = net(inputs)

            # Inverse transform of the labels' scaler
            outputs = torch.tensor(scaler_labels.inverse_transform(outputs.detach().cpu())).to(device)    
            labels = torch.tensor(scaler_labels.inverse_transform(labels.cpu())).to(device) 

            loss = criterion(outputs, labels)
            test_loss += loss.cpu().numpy()

    return test_loss / len(testset)

# %%
ray.shutdown()
ray.init() # Here we use ray.init() to evaluate available_resources for Ray
print(ray.available_resources())
ray.shutdown()  # Restart Ray defensively in case the ray connection is lost. 

# Start Ray runtime with specific resources (not nessesarily all resources)
# You can change this values based on your machine resources)
ray.init(num_cpus=2, num_gpus=0) 

"""Check Ray Tune is working properly (for trainable class)"""
# from ray.tune.utils import validate_save_restore
# validate_save_restore(Trainable)
# validate_save_restore(Trainable, use_object_store=True)
# print("Success!")
""""""
# Out:
# {'object_store_memory': 4004802969.0, 'CPU': 2.0, 'node:172.28.0.2': 1.0, 'memory': 8009605940.0}
# ''

# %%
# %%capture
try:
    import optuna
except:
    # %pip install optuna
    import optuna

# %%
ray.shutdown()
def main(num_samples=10, max_num_epochs=10, gpus_per_trial=2):

    # define data directory here if you want to load data from files
    data_dir = os.path.abspath("./data")
    load_data(data_dir)

    # define the search space of hyperparameters
    config = {
        "act1 ": tune.choice(["relu","tanh","selu"]),
        "act2" : tune.choice(["relu","tanh","selu"]),
        "act3" : tune.choice(["relu","tanh","selu"]),
        "lr": tune.quniform(0.0005, 0.001, 0.0001),
        "batch_size": tune.choice([ 8,16, 32 , 64]),
        "hidden_dim1" : tune.quniform(120, 330, 15),
        "hidden_dim2" : tune.quniform(120, 330, 15),
        "hidden_dim3" : tune.quniform(120, 330, 15),
    }

    # Optuna search algorithm
    from ray.tune.suggest.optuna import OptunaSearch 
    from ray.tune.suggest import ConcurrencyLimiter
    search_alg = OptunaSearch(
        metric="loss", #or accuracy, etc.
        mode="min", #or max
        # seed = 42,
        # points_to_evaluate=[
        # {'lr': 0.0005, 'hidden_size': 150.0, 'readout1_out': 200.0, 'readout2_out': 180.0}
        # ],
        )
    search_alg = ConcurrencyLimiter(search_alg, max_concurrent=10)

    scheduler = ASHAScheduler(
        metric ="loss",
        mode="min",
        max_t=max_num_epochs,
        reduction_factor=2, 
        grace_period=4,
        brackets=5
        )
    
    reporter = CLIReporter(
        # parameter_columns=["l1", "l2", "lr", "batch_size"],
        metric_columns=["loss", "training_iteration"]
        )
    
    # wrap data loading and training for tuning using `partial` 
    # (note that there exist other methods for this purpose)
    result = tune.run(
        partial(trainable_func, data_dir=data_dir, epochs=max_num_epochs),
        scheduler=scheduler,
        search_alg=search_alg,
        num_samples=num_samples,
        config=config,
        verbose=2,
        checkpoint_score_attr="loss",
        checkpoint_freq=0,
        keep_checkpoints_num=1,
        # checkpoint_at_end=True,
        # reuse_actors=reuse_actors_status,
        progress_reporter=reporter,
        resources_per_trial={"cpu": 0.5, "gpu": gpus_per_trial},
        stop={"training_iteration": max_num_epochs},                
        )

    best_trial = result.get_best_trial("loss", "min", "last")
    print("Best trial config: {}".format(best_trial.config))
    print("Best trial final validation score: {}".format(
        best_trial.last_result["loss"]))

    best_trained_model = Net(best_trial.config)
    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda:0"
        if gpus_per_trial > 1:
            best_trained_model = nn.DataParallel(best_trained_model)
    best_trained_model.to(device)

    best_checkpoint_dir = best_trial.checkpoint.value
    model_state, optimizer_state = torch.load(os.path.join(
        best_checkpoint_dir, "checkpoint"))
    best_trained_model.load_state_dict(model_state)

    test_score_value = test_score(best_trial.config, best_trained_model, device)
    print("Best trial test set score: {}".format(test_score_value))


if __name__ == "__main__":
    # You can change the number of GPUs per trial here:
    main(num_samples=50, max_num_epochs=50, gpus_per_trial=0)
# Out:
# 2022-07-26 10:58:39,640	INFO tune.py:874 -- Initializing Ray automatically.For cluster usage or custom Ray initialization, call `ray.init(...)` before `tune.run`.
# 2022-07-26 10:58:44,157	WARNING callback.py:106 -- The TensorboardX logger cannot be instantiated because either TensorboardX or one of it's dependencies is not installed. Please make sure you have the latest version of TensorboardX installed: `pip install -U tensorboardx`
# == Status ==
# Current time: 2022-07-26 10:58:44 (running for 00:00:00.30)
# Memory usage on this node: 2.0/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 0.5/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 1/50 (1 RUNNING)
#
#
# == Status ==
# Current time: 2022-07-26 10:58:49 (running for 00:00:05.70)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
#
#
# Trial trainable_func_eac17688 reported epoch=0,loss=0.8982038683141318,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 32, 'hidden_dim1': 285.0, 'hidden_dim2': 180.0, 'hidden_dim3': 165.0}.
# Trial trainable_func_ea93bf5e reported epoch=0,loss=0.7508906705876045,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 300.0, 'hidden_dim2': 195.0, 'hidden_dim3': 120.0}.
# == Status ==
# Current time: 2022-07-26 10:58:55 (running for 00:00:10.91)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
#
#
# Trial trainable_func_eadc9080 reported epoch=0,loss=1.2749407883593158,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0005, 'batch_size': 64, 'hidden_dim1': 270.0, 'hidden_dim2': 210.0, 'hidden_dim3': 195.0}.
# Trial trainable_func_eacca92c reported epoch=0,loss=0.7993382026307436,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0009, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 150.0, 'hidden_dim3': 300.0}.
# == Status ==
# Current time: 2022-07-26 10:59:00 (running for 00:00:16.40)
# Memory usage on this node: 2.7/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
#
#
# Trial trainable_func_eac17688 reported epoch=3,loss=0.5462228171686663,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 32, 'hidden_dim1': 285.0, 'hidden_dim2': 180.0, 'hidden_dim3': 165.0}.
# Trial trainable_func_eadc9080 reported epoch=3,loss=0.6408678696328785,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0005, 'batch_size': 64, 'hidden_dim1': 270.0, 'hidden_dim2': 210.0, 'hidden_dim3': 195.0}. This trial completed.
# Trial trainable_func_ea93bf5e reported epoch=2,loss=0.7464761953187297,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 300.0, 'hidden_dim2': 195.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_eacca92c reported epoch=3,loss=0.5222172874535671,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0009, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 150.0, 'hidden_dim3': 300.0}.
# Trial trainable_func_eaf30b26 reported epoch=0,loss=0.7666833802399191,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 270.0, 'hidden_dim2': 240.0, 'hidden_dim3': 315.0}.
# Trial trainable_func_eac17688 reported epoch=5,loss=0.5045046818015498,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 32, 'hidden_dim1': 285.0, 'hidden_dim2': 180.0, 'hidden_dim3': 165.0}.
# == Status ==
# Current time: 2022-07-26 10:59:05 (running for 00:00:21.54)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=1
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: -0.5462228171686663
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 6/50 (1 PENDING, 4 RUNNING, 1 TERMINATED)
#
#
# Trial trainable_func_eaf30b26 reported epoch=2,loss=0.7461770325965624,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 270.0, 'hidden_dim2': 240.0, 'hidden_dim3': 315.0}.
# Trial trainable_func_eacca92c reported epoch=6,loss=0.5018791780906481,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0009, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 150.0, 'hidden_dim3': 300.0}.
# == Status ==
# Current time: 2022-07-26 10:59:10 (running for 00:00:26.57)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=1
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: -0.4835875246227635 | Iter 4.000: -0.5462228171686663
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 6/50 (1 PENDING, 4 RUNNING, 1 TERMINATED)
#
#
# Trial trainable_func_ea93bf5e reported epoch=4,loss=0.6132085210302457,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 300.0, 'hidden_dim2': 195.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_eac17688 reported epoch=8,loss=0.4961820780090688,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 32, 'hidden_dim1': 285.0, 'hidden_dim2': 180.0, 'hidden_dim3': 165.0}.
# Trial trainable_func_eaf30b26 reported epoch=3,loss=0.5936921402185023,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0008, 'batch_size': 32, 'hidden_dim1': 270.0, 'hidden_dim2': 240.0, 'hidden_dim3': 315.0}. This trial completed.
# Trial trainable_func_eacca92c reported epoch=7,loss=0.49633268797188373,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0009, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 150.0, 'hidden_dim3': 300.0}. This trial completed.
# Trial trainable_func_f5302d9e reported epoch=0,loss=0.7892491409055081,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 165.0, 'hidden_dim3': 270.0}.
# == Status ==
# Current time: 2022-07-26 10:59:16 (running for 00:00:32.02)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=3
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: -0.4899601062973236 | Iter 4.000: -0.5699574786935843
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 8/50 (1 PENDING, 4 RUNNING, 3 TERMINATED)
#
#
# Trial trainable_func_fb9ab38e reported epoch=0,loss=0.7056466996012782,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 165.0, 'hidden_dim2': 300.0, 'hidden_dim3': 225.0}.
# Trial trainable_func_eac17688 reported epoch=10,loss=0.47854194821569473,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 32, 'hidden_dim1': 285.0, 'hidden_dim2': 180.0, 'hidden_dim3': 165.0}.
# Trial trainable_func_ea93bf5e reported epoch=6,loss=0.57870705097556,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 300.0, 'hidden_dim2': 195.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_f5302d9e reported epoch=3,loss=0.5879285489465271,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 165.0, 'hidden_dim3': 270.0}. This trial completed.
# == Status ==
# Current time: 2022-07-26 10:59:22 (running for 00:00:37.94)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=4
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: -0.4899601062973236 | Iter 4.000: -0.5879285489465271
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 9/50 (1 PENDING, 4 RUNNING, 4 TERMINATED)
#
#
# Trial trainable_func_fbc67e10 reported epoch=0,loss=0.9923686345271572,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.001, 'batch_size': 64, 'hidden_dim1': 270.0, 'hidden_dim2': 165.0, 'hidden_dim3': 300.0}.
# Trial trainable_func_eac17688 reported epoch=13,loss=0.45195114396567054,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 32, 'hidden_dim1': 285.0, 'hidden_dim2': 180.0, 'hidden_dim3': 165.0}.
# Trial trainable_func_fb9ab38e reported epoch=2,loss=0.6705150029587732,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 165.0, 'hidden_dim2': 300.0, 'hidden_dim3': 225.0}.
# Trial trainable_func_fbc67e10 reported epoch=3,loss=0.6696106683733211,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.001, 'batch_size': 64, 'hidden_dim1': 270.0, 'hidden_dim2': 165.0, 'hidden_dim3': 300.0}. This trial completed.
# == Status ==
# Current time: 2022-07-26 10:59:28 (running for 00:00:44.29)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=5
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: -0.4899601062973236 | Iter 4.000: -0.5908103445825147
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: -0.6503634300236775
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 10/50 (1 PENDING, 4 RUNNING, 5 TERMINATED)
#
#
# Trial trainable_func_ea93bf5e reported epoch=8,loss=0.6203613142332695,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 300.0, 'hidden_dim2': 195.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_eac17688 reported epoch=16,loss=0.45598095877869355,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 32, 'hidden_dim1': 285.0, 'hidden_dim2': 180.0, 'hidden_dim3': 165.0}.
# Trial trainable_func_0097c3b8 reported epoch=0,loss=0.8217997873286009,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 8, 'hidden_dim1': 180.0, 'hidden_dim2': 150.0, 'hidden_dim3': 135.0}.
# Trial trainable_func_fb9ab38e reported epoch=4,loss=0.6794205301366323,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 165.0, 'hidden_dim2': 300.0, 'hidden_dim3': 225.0}.
# == Status ==
# Current time: 2022-07-26 10:59:33 (running for 00:00:49.71)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=5
# Bracket: Iter 32.000: None | Iter 16.000: -0.47236528974715597 | Iter 8.000: -0.4899601062973236 | Iter 4.000: -0.5908103445825147
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: -0.6503634300236775
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 10/50 (1 PENDING, 4 RUNNING, 5 TERMINATED)
#
#
# Trial trainable_func_eac17688 reported epoch=18,loss=0.4926991529634032,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 32, 'hidden_dim1': 285.0, 'hidden_dim2': 180.0, 'hidden_dim3': 165.0}.
# Trial trainable_func_ea93bf5e reported epoch=10,loss=0.6060928476284019,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 300.0, 'hidden_dim2': 195.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_0097c3b8 reported epoch=1,loss=0.7405027414640356,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 8, 'hidden_dim1': 180.0, 'hidden_dim2': 150.0, 'hidden_dim3': 135.0}.
# Trial trainable_func_fb9ab38e reported epoch=6,loss=0.6094401364590004,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 165.0, 'hidden_dim2': 300.0, 'hidden_dim3': 225.0}.
# == Status ==
# Current time: 2022-07-26 10:59:40 (running for 00:00:56.71)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=5
# Bracket: Iter 32.000: None | Iter 16.000: -0.47236528974715597 | Iter 8.000: -0.4899601062973236 | Iter 4.000: -0.5908103445825147
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: -0.6503634300236775
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 10/50 (1 PENDING, 4 RUNNING, 5 TERMINATED)
#
#
# Trial trainable_func_eac17688 reported epoch=21,loss=0.44486867458902823,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 32, 'hidden_dim1': 285.0, 'hidden_dim2': 180.0, 'hidden_dim3': 165.0}.
# Trial trainable_func_0097c3b8 reported epoch=2,loss=0.62539812237264,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 8, 'hidden_dim1': 180.0, 'hidden_dim2': 150.0, 'hidden_dim3': 135.0}.
# Trial trainable_func_fb9ab38e reported epoch=7,loss=0.7062718288608238,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 165.0, 'hidden_dim2': 300.0, 'hidden_dim3': 225.0}. This trial completed.
# Trial trainable_func_ea93bf5e reported epoch=12,loss=0.6208499946371321,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 300.0, 'hidden_dim2': 195.0, 'hidden_dim3': 120.0}.
# == Status ==
# Current time: 2022-07-26 10:59:46 (running for 00:01:02.16)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=6
# Bracket: Iter 32.000: None | Iter 16.000: -0.47236528974715597 | Iter 8.000: -0.4899601062973236 | Iter 4.000: -0.5908103445825147
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: -0.6783176294422506
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 11/50 (1 PENDING, 4 RUNNING, 6 TERMINATED)
#
#
# Trial trainable_func_03cba18a reported epoch=0,loss=0.7518204883119297,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 32, 'hidden_dim1': 180.0, 'hidden_dim2': 135.0, 'hidden_dim3': 180.0}.
# Trial trainable_func_eac17688 reported epoch=23,loss=0.475709436238032,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 32, 'hidden_dim1': 285.0, 'hidden_dim2': 180.0, 'hidden_dim3': 165.0}.
# == Status ==
# Current time: 2022-07-26 10:59:51 (running for 00:01:07.61)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=6
# Bracket: Iter 32.000: None | Iter 16.000: -0.47236528974715597 | Iter 8.000: -0.4899601062973236 | Iter 4.000: -0.5908103445825147
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: -0.6783176294422506
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 11/50 (1 PENDING, 4 RUNNING, 6 TERMINATED)
#
#
# Trial trainable_func_ea93bf5e reported epoch=13,loss=0.5650605102325654,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 300.0, 'hidden_dim2': 195.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_0097c3b8 reported epoch=3,loss=0.603726282582449,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 8, 'hidden_dim1': 180.0, 'hidden_dim2': 150.0, 'hidden_dim3': 135.0}. This trial completed.
# Trial trainable_func_03cba18a reported epoch=3,loss=0.619623285077016,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 32, 'hidden_dim1': 180.0, 'hidden_dim2': 135.0, 'hidden_dim3': 180.0}.
# Trial trainable_func_0ed652dc reported epoch=0,loss=0.9041359572537011,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0008, 'batch_size': 64, 'hidden_dim1': 240.0, 'hidden_dim2': 255.0, 'hidden_dim3': 240.0}.
# Trial trainable_func_eac17688 reported epoch=25,loss=0.4827081838515311,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 32, 'hidden_dim1': 285.0, 'hidden_dim2': 180.0, 'hidden_dim3': 165.0}.
# == Status ==
# Current time: 2022-07-26 10:59:56 (running for 00:01:12.75)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=7
# Bracket: Iter 32.000: None | Iter 16.000: -0.47236528974715597 | Iter 8.000: -0.4899601062973236 | Iter 4.000: -0.5936921402185023
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: -0.6783176294422506
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 12/50 (1 PENDING, 4 RUNNING, 7 TERMINATED)
#
#
# Trial trainable_func_03cba18a reported epoch=6,loss=0.6041436591390331,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 32, 'hidden_dim1': 180.0, 'hidden_dim2': 135.0, 'hidden_dim3': 180.0}.
# Trial trainable_func_0ed652dc reported epoch=4,loss=0.5988359784749301,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0008, 'batch_size': 64, 'hidden_dim1': 240.0, 'hidden_dim2': 255.0, 'hidden_dim3': 240.0}.
# Trial trainable_func_ea93bf5e reported epoch=15,loss=0.5853336132528688,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 300.0, 'hidden_dim2': 195.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_eac17688 reported epoch=28,loss=0.4575358942436172,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 32, 'hidden_dim1': 285.0, 'hidden_dim2': 180.0, 'hidden_dim3': 165.0}.
# == Status ==
# Current time: 2022-07-26 11:00:02 (running for 00:01:18.05)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=7
# Bracket: Iter 32.000: None | Iter 16.000: -0.47236528974715597 | Iter 8.000: -0.4899601062973236 | Iter 4.000: -0.5936921402185023
# Bracket: Iter 32.000: None | Iter 16.000: -0.5853336132528688 | Iter 8.000: -0.6503634300236775
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 12/50 (1 PENDING, 4 RUNNING, 7 TERMINATED)
#
#
# Trial trainable_func_03cba18a reported epoch=9,loss=0.5868350431398897,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 32, 'hidden_dim1': 180.0, 'hidden_dim2': 135.0, 'hidden_dim3': 180.0}.
# Trial trainable_func_0ed652dc reported epoch=8,loss=0.5857003724789812,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0008, 'batch_size': 64, 'hidden_dim1': 240.0, 'hidden_dim2': 255.0, 'hidden_dim3': 240.0}.
# Trial trainable_func_eac17688 reported epoch=30,loss=0.4577381091086333,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 32, 'hidden_dim1': 285.0, 'hidden_dim2': 180.0, 'hidden_dim3': 165.0}.
# == Status ==
# Current time: 2022-07-26 11:00:07 (running for 00:01:23.23)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=7
# Bracket: Iter 32.000: None | Iter 16.000: -0.47236528974715597 | Iter 8.000: -0.4899601062973236 | Iter 4.000: -0.5936921402185023
# Bracket: Iter 32.000: None | Iter 16.000: -0.5853336132528688 | Iter 8.000: -0.6503634300236775
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 12/50 (1 PENDING, 4 RUNNING, 7 TERMINATED)
#
#
# Trial trainable_func_ea93bf5e reported epoch=17,loss=0.5544717506256317,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 300.0, 'hidden_dim2': 195.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_0ed652dc reported epoch=12,loss=0.5654775290068546,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0008, 'batch_size': 64, 'hidden_dim1': 240.0, 'hidden_dim2': 255.0, 'hidden_dim3': 240.0}.
# Trial trainable_func_03cba18a reported epoch=12,loss=0.5376128792679219,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 32, 'hidden_dim1': 180.0, 'hidden_dim2': 135.0, 'hidden_dim3': 180.0}.
# Trial trainable_func_eac17688 reported epoch=32,loss=0.43749876750684213,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 32, 'hidden_dim1': 285.0, 'hidden_dim2': 180.0, 'hidden_dim3': 165.0}.
# == Status ==
# Current time: 2022-07-26 11:00:12 (running for 00:01:28.25)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=7
# Bracket: Iter 32.000: -0.4644072995332212 | Iter 16.000: -0.47236528974715597 | Iter 8.000: -0.4899601062973236 | Iter 4.000: -0.5936921402185023
# Bracket: Iter 32.000: None | Iter 16.000: -0.5853336132528688 | Iter 8.000: -0.6503634300236775
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 12/50 (1 PENDING, 4 RUNNING, 7 TERMINATED)
#
#
# Trial trainable_func_0ed652dc reported epoch=16,loss=0.562721758751358,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0008, 'batch_size': 64, 'hidden_dim1': 240.0, 'hidden_dim2': 255.0, 'hidden_dim3': 240.0}.
# Trial trainable_func_eac17688 reported epoch=34,loss=0.47447076687340795,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 32, 'hidden_dim1': 285.0, 'hidden_dim2': 180.0, 'hidden_dim3': 165.0}.
# == Status ==
# Current time: 2022-07-26 11:00:17 (running for 00:01:33.59)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=7
# Bracket: Iter 32.000: -0.4644072995332212 | Iter 16.000: -0.47236528974715597 | Iter 8.000: -0.4899601062973236 | Iter 4.000: -0.5936921402185023
# Bracket: Iter 32.000: None | Iter 16.000: -0.5853336132528688 | Iter 8.000: -0.6503634300236775
# Bracket: Iter 32.000: None | Iter 16.000: -0.5399081709225221
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 12/50 (1 PENDING, 4 RUNNING, 7 TERMINATED)
#
#
# Trial trainable_func_03cba18a reported epoch=15,loss=0.5787559008706172,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 32, 'hidden_dim1': 180.0, 'hidden_dim2': 135.0, 'hidden_dim3': 180.0}.
# Trial trainable_func_ea93bf5e reported epoch=19,loss=0.5514831354242253,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 300.0, 'hidden_dim2': 195.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_eac17688 reported epoch=36,loss=0.4508588101349526,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 32, 'hidden_dim1': 285.0, 'hidden_dim2': 180.0, 'hidden_dim3': 165.0}.
# == Status ==
# Current time: 2022-07-26 11:00:22 (running for 00:01:38.83)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=7
# Bracket: Iter 32.000: -0.4644072995332212 | Iter 16.000: -0.47236528974715597 | Iter 8.000: -0.4899601062973236 | Iter 4.000: -0.5936921402185023
# Bracket: Iter 32.000: None | Iter 16.000: -0.5820447570617431 | Iter 8.000: -0.6503634300236775
# Bracket: Iter 32.000: None | Iter 16.000: -0.5399081709225221
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 12/50 (1 PENDING, 4 RUNNING, 7 TERMINATED)
#
#
# Trial trainable_func_0ed652dc reported epoch=20,loss=0.5296348871486893,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0008, 'batch_size': 64, 'hidden_dim1': 240.0, 'hidden_dim2': 255.0, 'hidden_dim3': 240.0}.
# Trial trainable_func_03cba18a reported epoch=18,loss=0.5477518778020798,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 32, 'hidden_dim1': 180.0, 'hidden_dim2': 135.0, 'hidden_dim3': 180.0}.
# == Status ==
# Current time: 2022-07-26 11:00:28 (running for 00:01:43.85)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=7
# Bracket: Iter 32.000: -0.4644072995332212 | Iter 16.000: -0.47236528974715597 | Iter 8.000: -0.4899601062973236 | Iter 4.000: -0.5936921402185023
# Bracket: Iter 32.000: None | Iter 16.000: -0.5820447570617431 | Iter 8.000: -0.6503634300236775
# Bracket: Iter 32.000: None | Iter 16.000: -0.5399081709225221
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 12/50 (1 PENDING, 4 RUNNING, 7 TERMINATED)
#
#
# Trial trainable_func_eac17688 reported epoch=38,loss=0.4415666347556884,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 32, 'hidden_dim1': 285.0, 'hidden_dim2': 180.0, 'hidden_dim3': 165.0}.
# Trial trainable_func_ea93bf5e reported epoch=21,loss=0.6509917482872806,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 300.0, 'hidden_dim2': 195.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_0ed652dc reported epoch=24,loss=0.5567976647879294,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0008, 'batch_size': 64, 'hidden_dim1': 240.0, 'hidden_dim2': 255.0, 'hidden_dim3': 240.0}.
# Trial trainable_func_03cba18a reported epoch=21,loss=0.5450976850655526,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 32, 'hidden_dim1': 180.0, 'hidden_dim2': 135.0, 'hidden_dim3': 180.0}.
# == Status ==
# Current time: 2022-07-26 11:00:33 (running for 00:01:48.96)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=7
# Bracket: Iter 32.000: -0.4644072995332212 | Iter 16.000: -0.47236528974715597 | Iter 8.000: -0.4899601062973236 | Iter 4.000: -0.5936921402185023
# Bracket: Iter 32.000: None | Iter 16.000: -0.5820447570617431 | Iter 8.000: -0.6503634300236775
# Bracket: Iter 32.000: None | Iter 16.000: -0.5399081709225221
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 12/50 (1 PENDING, 4 RUNNING, 7 TERMINATED)
#
#
# Trial trainable_func_eac17688 reported epoch=40,loss=0.4463539001901897,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 32, 'hidden_dim1': 285.0, 'hidden_dim2': 180.0, 'hidden_dim3': 165.0}.
# Trial trainable_func_03cba18a reported epoch=24,loss=0.5493713771234803,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 32, 'hidden_dim1': 180.0, 'hidden_dim2': 135.0, 'hidden_dim3': 180.0}.
# Trial trainable_func_0ed652dc reported epoch=28,loss=0.5247303563869938,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0008, 'batch_size': 64, 'hidden_dim1': 240.0, 'hidden_dim2': 255.0, 'hidden_dim3': 240.0}.
# == Status ==
# Current time: 2022-07-26 11:00:38 (running for 00:01:54.16)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=7
# Bracket: Iter 32.000: -0.4644072995332212 | Iter 16.000: -0.47236528974715597 | Iter 8.000: -0.4899601062973236 | Iter 4.000: -0.5936921402185023
# Bracket: Iter 32.000: None | Iter 16.000: -0.5820447570617431 | Iter 8.000: -0.6503634300236775
# Bracket: Iter 32.000: None | Iter 16.000: -0.5399081709225221
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 12/50 (1 PENDING, 4 RUNNING, 7 TERMINATED)
#
#
# Trial trainable_func_ea93bf5e reported epoch=23,loss=0.5512527044146195,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 300.0, 'hidden_dim2': 195.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_eac17688 reported epoch=43,loss=0.4470007579165299,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 32, 'hidden_dim1': 285.0, 'hidden_dim2': 180.0, 'hidden_dim3': 165.0}.
# Trial trainable_func_0ed652dc reported epoch=32,loss=0.518491759450493,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0008, 'batch_size': 64, 'hidden_dim1': 240.0, 'hidden_dim2': 255.0, 'hidden_dim3': 240.0}.
# Trial trainable_func_03cba18a reported epoch=27,loss=0.5375791615266357,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 32, 'hidden_dim1': 180.0, 'hidden_dim2': 135.0, 'hidden_dim3': 180.0}.
# == Status ==
# Current time: 2022-07-26 11:00:43 (running for 00:01:59.37)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=7
# Bracket: Iter 32.000: -0.4644072995332212 | Iter 16.000: -0.47236528974715597 | Iter 8.000: -0.4899601062973236 | Iter 4.000: -0.5936921402185023
# Bracket: Iter 32.000: None | Iter 16.000: -0.5820447570617431 | Iter 8.000: -0.6503634300236775
# Bracket: Iter 32.000: -0.5053333658225291 | Iter 16.000: -0.5399081709225221
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 12/50 (1 PENDING, 4 RUNNING, 7 TERMINATED)
#
#
# Trial trainable_func_eac17688 reported epoch=46,loss=0.4429606444051182,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 32, 'hidden_dim1': 285.0, 'hidden_dim2': 180.0, 'hidden_dim3': 165.0}.
# == Status ==
# Current time: 2022-07-26 11:00:48 (running for 00:02:04.40)
# Memory usage on this node: 2.5/12.7 GiB
# Using AsyncHyperBand: num_stopped=7
# Bracket: Iter 32.000: -0.4644072995332212 | Iter 16.000: -0.47236528974715597 | Iter 8.000: -0.4899601062973236 | Iter 4.000: -0.5936921402185023
# Bracket: Iter 32.000: None | Iter 16.000: -0.5820447570617431 | Iter 8.000: -0.6503634300236775
# Bracket: Iter 32.000: -0.5053333658225291 | Iter 16.000: -0.5399081709225221
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 12/50 (1 PENDING, 4 RUNNING, 7 TERMINATED)
#
#
# Trial trainable_func_ea93bf5e reported epoch=25,loss=0.5444162092056077,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 300.0, 'hidden_dim2': 195.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_0ed652dc reported epoch=36,loss=0.5232544422745506,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0008, 'batch_size': 64, 'hidden_dim1': 240.0, 'hidden_dim2': 255.0, 'hidden_dim3': 240.0}.
# Trial trainable_func_03cba18a reported epoch=30,loss=0.5665885265198041,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 32, 'hidden_dim1': 180.0, 'hidden_dim2': 135.0, 'hidden_dim3': 180.0}.
# Trial trainable_func_03cba18a reported epoch=32,loss=0.5387435803413831,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 32, 'hidden_dim1': 180.0, 'hidden_dim2': 135.0, 'hidden_dim3': 180.0}.
# == Status ==
# Current time: 2022-07-26 11:00:53 (running for 00:02:09.82)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=7
# Bracket: Iter 32.000: -0.4644072995332212 | Iter 16.000: -0.47236528974715597 | Iter 8.000: -0.4899601062973236 | Iter 4.000: -0.5936921402185023
# Bracket: Iter 32.000: -0.5503603751656576 | Iter 16.000: -0.5820447570617431 | Iter 8.000: -0.6503634300236775
# Bracket: Iter 32.000: -0.5053333658225291 | Iter 16.000: -0.5399081709225221
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 12/50 (1 PENDING, 4 RUNNING, 7 TERMINATED)
#
#
# Trial trainable_func_ea93bf5e reported epoch=26,loss=0.5492702972880713,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 300.0, 'hidden_dim2': 195.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_0ed652dc reported epoch=39,loss=0.5734584653903779,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0008, 'batch_size': 64, 'hidden_dim1': 240.0, 'hidden_dim2': 255.0, 'hidden_dim3': 240.0}.
# Trial trainable_func_eac17688 reported epoch=48,loss=0.4967694166996563,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 32, 'hidden_dim1': 285.0, 'hidden_dim2': 180.0, 'hidden_dim3': 165.0}.
# Trial trainable_func_eac17688 reported epoch=49,loss=0.45543732196590253,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 32, 'hidden_dim1': 285.0, 'hidden_dim2': 180.0, 'hidden_dim3': 165.0}. This trial completed.
# == Status ==
# Current time: 2022-07-26 11:00:59 (running for 00:02:15.15)
# Memory usage on this node: 2.5/12.7 GiB
# Using AsyncHyperBand: num_stopped=7
# Bracket: Iter 32.000: -0.4644072995332212 | Iter 16.000: -0.47236528974715597 | Iter 8.000: -0.4899601062973236 | Iter 4.000: -0.5936921402185023
# Bracket: Iter 32.000: -0.5503603751656576 | Iter 16.000: -0.5820447570617431 | Iter 8.000: -0.6503634300236775
# Bracket: Iter 32.000: -0.5053333658225291 | Iter 16.000: -0.5399081709225221
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 13/50 (1 PENDING, 4 RUNNING, 8 TERMINATED)
#
#
# Trial trainable_func_03cba18a reported epoch=35,loss=0.5294949756968534,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 32, 'hidden_dim1': 180.0, 'hidden_dim2': 135.0, 'hidden_dim3': 180.0}.
# Trial trainable_func_0ed652dc reported epoch=43,loss=0.5191065649857575,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0008, 'batch_size': 64, 'hidden_dim1': 240.0, 'hidden_dim2': 255.0, 'hidden_dim3': 240.0}.
# Trial trainable_func_ea93bf5e reported epoch=28,loss=0.5736303265001664,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 300.0, 'hidden_dim2': 195.0, 'hidden_dim3': 120.0}.
# == Status ==
# Current time: 2022-07-26 11:01:04 (running for 00:02:20.47)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=7
# Bracket: Iter 32.000: -0.4644072995332212 | Iter 16.000: -0.47236528974715597 | Iter 8.000: -0.4899601062973236 | Iter 4.000: -0.5936921402185023
# Bracket: Iter 32.000: -0.5503603751656576 | Iter 16.000: -0.5820447570617431 | Iter 8.000: -0.6503634300236775
# Bracket: Iter 32.000: -0.5053333658225291 | Iter 16.000: -0.5399081709225221
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 13/50 (1 PENDING, 4 RUNNING, 8 TERMINATED)
#
#
# Trial trainable_func_136fd764 reported epoch=0,loss=0.6546351887614621,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0005, 'batch_size': 8, 'hidden_dim1': 315.0, 'hidden_dim2': 165.0, 'hidden_dim3': 150.0}.
# Trial trainable_func_03cba18a reported epoch=38,loss=0.5354895872786438,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 32, 'hidden_dim1': 180.0, 'hidden_dim2': 135.0, 'hidden_dim3': 180.0}.
# Trial trainable_func_0ed652dc reported epoch=47,loss=0.5217349278518238,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0008, 'batch_size': 64, 'hidden_dim1': 240.0, 'hidden_dim2': 255.0, 'hidden_dim3': 240.0}.
# Trial trainable_func_0ed652dc reported epoch=49,loss=0.5168206586474597,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0008, 'batch_size': 64, 'hidden_dim1': 240.0, 'hidden_dim2': 255.0, 'hidden_dim3': 240.0}. This trial completed.
# == Status ==
# Current time: 2022-07-26 11:01:10 (running for 00:02:26.52)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=7
# Bracket: Iter 32.000: -0.4644072995332212 | Iter 16.000: -0.47236528974715597 | Iter 8.000: -0.4899601062973236 | Iter 4.000: -0.5936921402185023
# Bracket: Iter 32.000: -0.5503603751656576 | Iter 16.000: -0.5820447570617431 | Iter 8.000: -0.6503634300236775
# Bracket: Iter 32.000: -0.5053333658225291 | Iter 16.000: -0.5399081709225221
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 13/50 (1 PENDING, 4 RUNNING, 8 TERMINATED)
#
#
# Trial trainable_func_136fd764 reported epoch=1,loss=0.7292458376649448,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0005, 'batch_size': 8, 'hidden_dim1': 315.0, 'hidden_dim2': 165.0, 'hidden_dim3': 150.0}.
# Trial trainable_func_03cba18a reported epoch=41,loss=0.5564847651355704,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 32, 'hidden_dim1': 180.0, 'hidden_dim2': 135.0, 'hidden_dim3': 180.0}.
# Trial trainable_func_ea93bf5e reported epoch=30,loss=0.5543796774516577,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 300.0, 'hidden_dim2': 195.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_39df825a reported epoch=0,loss=0.9810641719462095,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 240.0, 'hidden_dim2': 150.0, 'hidden_dim3': 120.0}.
# == Status ==
# Current time: 2022-07-26 11:01:17 (running for 00:02:33.09)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=7
# Bracket: Iter 32.000: -0.4644072995332212 | Iter 16.000: -0.47236528974715597 | Iter 8.000: -0.4899601062973236 | Iter 4.000: -0.5936921402185023
# Bracket: Iter 32.000: -0.5503603751656576 | Iter 16.000: -0.5820447570617431 | Iter 8.000: -0.6503634300236775
# Bracket: Iter 32.000: -0.5053333658225291 | Iter 16.000: -0.5399081709225221
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 14/50 (1 PENDING, 4 RUNNING, 9 TERMINATED)
#
#
# Trial trainable_func_ea93bf5e reported epoch=31,loss=0.5964350560488217,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 300.0, 'hidden_dim2': 195.0, 'hidden_dim3': 120.0}. This trial completed.
# Trial trainable_func_03cba18a reported epoch=44,loss=0.5346612889506561,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 32, 'hidden_dim1': 180.0, 'hidden_dim2': 135.0, 'hidden_dim3': 180.0}.
# Trial trainable_func_41ecf28e reported epoch=0,loss=1.0113305001281443,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.001, 'batch_size': 64, 'hidden_dim1': 255.0, 'hidden_dim2': 195.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_136fd764 reported epoch=2,loss=0.5959129326494793,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0005, 'batch_size': 8, 'hidden_dim1': 315.0, 'hidden_dim2': 165.0, 'hidden_dim3': 150.0}.
# Trial trainable_func_39df825a reported epoch=2,loss=0.6442935572380196,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 240.0, 'hidden_dim2': 150.0, 'hidden_dim3': 120.0}.
# == Status ==
# Current time: 2022-07-26 11:01:22 (running for 00:02:38.32)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=8
# Bracket: Iter 32.000: -0.4644072995332212 | Iter 16.000: -0.47236528974715597 | Iter 8.000: -0.4899601062973236 | Iter 4.000: -0.5936921402185023
# Bracket: Iter 32.000: -0.5733977156072396 | Iter 16.000: -0.5820447570617431 | Iter 8.000: -0.6503634300236775
# Bracket: Iter 32.000: -0.5053333658225291 | Iter 16.000: -0.5399081709225221
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 15/50 (1 PENDING, 4 RUNNING, 10 TERMINATED)
#
#
# Trial trainable_func_41ecf28e reported epoch=3,loss=0.5939166605058058,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.001, 'batch_size': 64, 'hidden_dim1': 255.0, 'hidden_dim2': 195.0, 'hidden_dim3': 120.0}. This trial completed.
# Trial trainable_func_03cba18a reported epoch=47,loss=0.5538513597847686,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 32, 'hidden_dim1': 180.0, 'hidden_dim2': 135.0, 'hidden_dim3': 180.0}.
# == Status ==
# Current time: 2022-07-26 11:01:27 (running for 00:02:43.79)
# Memory usage on this node: 2.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=9
# Bracket: Iter 32.000: -0.4644072995332212 | Iter 16.000: -0.47236528974715597 | Iter 8.000: -0.4899601062973236 | Iter 4.000: -0.5938044003621541
# Bracket: Iter 32.000: -0.5733977156072396 | Iter 16.000: -0.5820447570617431 | Iter 8.000: -0.6503634300236775
# Bracket: Iter 32.000: -0.5053333658225291 | Iter 16.000: -0.5399081709225221
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 16/50 (1 PENDING, 4 RUNNING, 11 TERMINATED)
#
#
# ...
# Number of trials: 50/50 (1 RUNNING, 49 TERMINATED)
#
#
# Trial trainable_func_431ab6f4 reported epoch=24,loss=0.5295360568438723,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0009, 'batch_size': 8, 'hidden_dim1': 300.0, 'hidden_dim2': 225.0, 'hidden_dim3': 255.0}.
# == Status ==
# Current time: 2022-07-26 11:12:15 (running for 00:13:30.95)
# Memory usage on this node: 2.0/12.7 GiB
# Using AsyncHyperBand: num_stopped=39
# Bracket: Iter 32.000: -0.49294308163882083 | Iter 16.000: -0.5107622536523352 | Iter 8.000: -0.5320029757114717 | Iter 4.000: -0.608949002933616
# Bracket: Iter 32.000: -0.5503603751656576 | Iter 16.000: -0.5481012899191842 | Iter 8.000: -0.5634351385158018
# Bracket: Iter 32.000: -0.47283398488549644 | Iter 16.000: -0.5061107633067372
# Bracket: Iter 32.000: -0.5155669296495613
# Bracket:
# Resources requested: 0.5/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 50/50 (1 RUNNING, 49 TERMINATED)
#
#
# Trial trainable_func_431ab6f4 reported epoch=26,loss=0.5246299817285093,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0009, 'batch_size': 8, 'hidden_dim1': 300.0, 'hidden_dim2': 225.0, 'hidden_dim3': 255.0}.
# == Status ==
# Current time: 2022-07-26 11:12:20 (running for 00:13:36.05)
# Memory usage on this node: 2.0/12.7 GiB
# Using AsyncHyperBand: num_stopped=39
# Bracket: Iter 32.000: -0.49294308163882083 | Iter 16.000: -0.5107622536523352 | Iter 8.000: -0.5320029757114717 | Iter 4.000: -0.608949002933616
# Bracket: Iter 32.000: -0.5503603751656576 | Iter 16.000: -0.5481012899191842 | Iter 8.000: -0.5634351385158018
# Bracket: Iter 32.000: -0.47283398488549644 | Iter 16.000: -0.5061107633067372
# Bracket: Iter 32.000: -0.5155669296495613
# Bracket:
# Resources requested: 0.5/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 50/50 (1 RUNNING, 49 TERMINATED)
#
#
# Trial trainable_func_431ab6f4 reported epoch=28,loss=0.5196769771833006,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0009, 'batch_size': 8, 'hidden_dim1': 300.0, 'hidden_dim2': 225.0, 'hidden_dim3': 255.0}.
# == Status ==
# Current time: 2022-07-26 11:12:25 (running for 00:13:41.16)
# Memory usage on this node: 2.0/12.7 GiB
# Using AsyncHyperBand: num_stopped=39
# Bracket: Iter 32.000: -0.49294308163882083 | Iter 16.000: -0.5107622536523352 | Iter 8.000: -0.5320029757114717 | Iter 4.000: -0.608949002933616
# Bracket: Iter 32.000: -0.5503603751656576 | Iter 16.000: -0.5481012899191842 | Iter 8.000: -0.5634351385158018
# Bracket: Iter 32.000: -0.47283398488549644 | Iter 16.000: -0.5061107633067372
# Bracket: Iter 32.000: -0.5155669296495613
# Bracket:
# Resources requested: 0.5/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 50/50 (1 RUNNING, 49 TERMINATED)
#
#
# Trial trainable_func_431ab6f4 reported epoch=30,loss=0.619293067852868,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0009, 'batch_size': 8, 'hidden_dim1': 300.0, 'hidden_dim2': 225.0, 'hidden_dim3': 255.0}.
# 2022-07-26 11:12:30,544	INFO tune.py:748 -- Total run time: 826.46 seconds (826.23 seconds for the tuning loop).
# Trial trainable_func_431ab6f4 reported epoch=31,loss=0.5546953662427774,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0009, 'batch_size': 8, 'hidden_dim1': 300.0, 'hidden_dim2': 225.0, 'hidden_dim3': 255.0}. This trial completed.
# == Status ==
# Current time: 2022-07-26 11:12:30 (running for 00:13:46.22)
# Memory usage on this node: 2.0/12.7 GiB
# Using AsyncHyperBand: num_stopped=40
# Bracket: Iter 32.000: -0.49294308163882083 | Iter 16.000: -0.5107622536523352 | Iter 8.000: -0.5320029757114717 | Iter 4.000: -0.608949002933616
# Bracket: Iter 32.000: -0.5525278707042175 | Iter 16.000: -0.5481012899191842 | Iter 8.000: -0.5634351385158018
# Bracket: Iter 32.000: -0.47283398488549644 | Iter 16.000: -0.5061107633067372
# Bracket: Iter 32.000: -0.5155669296495613
# Bracket:
# Resources requested: 0.5/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 50/50 (1 RUNNING, 49 TERMINATED)
#
#
# == Status ==
# Current time: 2022-07-26 11:12:30 (running for 00:13:46.25)
# Memory usage on this node: 1.9/12.7 GiB
# Using AsyncHyperBand: num_stopped=40
# Bracket: Iter 32.000: -0.49294308163882083 | Iter 16.000: -0.5107622536523352 | Iter 8.000: -0.5320029757114717 | Iter 4.000: -0.608949002933616
# Bracket: Iter 32.000: -0.5525278707042175 | Iter 16.000: -0.5481012899191842 | Iter 8.000: -0.5634351385158018
# Bracket: Iter 32.000: -0.47283398488549644 | Iter 16.000: -0.5061107633067372
# Bracket: Iter 32.000: -0.5155669296495613
# Bracket:
# Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.46 GiB heap, 0.0/3.73 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_10-58-44
# Number of trials: 50/50 (50 TERMINATED)
# +-------------------------+------------+-------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# | Trial name              | status     | loc               | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |     loss |   training_iteration |
# |-------------------------+------------+-------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------|
# | trainable_func_ea93bf5e | TERMINATED | 172.28.0.2:106352 | relu    | relu   | tanh   |           16 |           300 |           195 |           120 | 0.0006 | 0.596435 |                   32 |
# | trainable_func_eac17688 | TERMINATED | 172.28.0.2:106353 | relu    | selu   | selu   |           32 |           285 |           180 |           165 | 0.001  | 0.455437 |                   50 |
# | trainable_func_eacca92c | TERMINATED | 172.28.0.2:106404 | relu    | selu   | relu   |           32 |           240 |           150 |           300 | 0.0009 | 0.496333 |                    8 |
# | trainable_func_eadc9080 | TERMINATED | 172.28.0.2:106416 | relu    | selu   | relu   |           64 |           270 |           210 |           195 | 0.0005 | 0.640868 |                    4 |
# | trainable_func_eaf30b26 | TERMINATED | 172.28.0.2:106416 | selu    | relu   | selu   |           32 |           270 |           240 |           315 | 0.0008 | 0.593692 |                    4 |
# | trainable_func_f5302d9e | TERMINATED | 172.28.0.2:106416 | selu    | tanh   | tanh   |           32 |           255 |           165 |           270 | 0.001  | 0.587929 |                    4 |
# | trainable_func_fb9ab38e | TERMINATED | 172.28.0.2:106404 | relu    | selu   | tanh   |           16 |           165 |           300 |           225 | 0.0007 | 0.706272 |                    8 |
# | trainable_func_fbc67e10 | TERMINATED | 172.28.0.2:106416 | selu    | tanh   | relu   |           64 |           270 |           165 |           300 | 0.001  | 0.669611 |                    4 |
# | trainable_func_0097c3b8 | TERMINATED | 172.28.0.2:106416 | relu    | relu   | tanh   |            8 |           180 |           150 |           135 | 0.0009 | 0.603726 |                    4 |
# | trainable_func_03cba18a | TERMINATED | 172.28.0.2:106404 | tanh    | tanh   | tanh   |           32 |           180 |           135 |           180 | 0.0007 | 0.551019 |                   50 |
# | trainable_func_0ed652dc | TERMINATED | 172.28.0.2:106416 | selu    | tanh   | selu   |           64 |           240 |           255 |           240 | 0.0008 | 0.516821 |                   50 |
# | trainable_func_136fd764 | TERMINATED | 172.28.0.2:106353 | relu    | tanh   | tanh   |            8 |           315 |           165 |           150 | 0.0005 | 0.530769 |                   32 |
# | trainable_func_39df825a | TERMINATED | 172.28.0.2:106416 | relu    | selu   | tanh   |           16 |           240 |           150 |           120 | 0.0009 | 0.516788 |                   50 |
# | trainable_func_41ecf28e | TERMINATED | 172.28.0.2:106352 | selu    | selu   | relu   |           64 |           255 |           195 |           120 | 0.001  | 0.593917 |                    4 |
# | trainable_func_46662cfe | TERMINATED | 172.28.0.2:106352 | tanh    | selu   | selu   |            8 |           330 |           120 |           165 | 0.0007 | 0.622099 |                    8 |
# | trainable_func_49d55f22 | TERMINATED | 172.28.0.2:106404 | tanh    | selu   | selu   |           32 |           330 |           120 |           180 | 0.0009 | 0.617848 |                    4 |
# | trainable_func_4d573a4e | TERMINATED | 172.28.0.2:106404 | relu    | selu   | selu   |           32 |           330 |           120 |           165 | 0.0009 | 0.614373 |                    4 |
# | trainable_func_526e9234 | TERMINATED | 172.28.0.2:106404 | relu    | selu   | selu   |           32 |           210 |           330 |           270 | 0.0009 | 0.488311 |                   50 |
# | trainable_func_57ef95dc | TERMINATED | 172.28.0.2:106352 | relu    | selu   | relu   |            8 |           225 |           180 |           330 | 0.0009 | 0.498375 |                   50 |
# | trainable_func_71991eb8 | TERMINATED | 172.28.0.2:106404 | relu    | selu   | relu   |           32 |           210 |           270 |           270 | 0.0009 | 0.65044  |                    4 |
# | trainable_func_aa1eda5c | TERMINATED | 172.28.0.2:106404 | relu    | selu   | selu   |           32 |           210 |           330 |           255 | 0.001  | 0.508692 |                   50 |
# | trainable_func_af9d4f90 | TERMINATED | 172.28.0.2:106416 | relu    | selu   | selu   |           32 |           210 |           330 |           240 | 0.001  | 0.473264 |                   50 |
# | trainable_func_b79f23da | TERMINATED | 172.28.0.2:106353 | relu    | selu   | selu   |           32 |           135 |           330 |           225 | 0.001  | 0.560167 |                   16 |
# | trainable_func_d437e770 | TERMINATED | 172.28.0.2:106353 | relu    | selu   | selu   |           32 |           135 |           315 |           225 | 0.001  | 0.753254 |                    4 |
# | trainable_func_ea8d4c18 | TERMINATED | 172.28.0.2:106353 | tanh    | relu   | selu   |           32 |           210 |           330 |           255 | 0.0008 | 0.52641  |                    8 |
# | trainable_func_efdf73c6 | TERMINATED | 172.28.0.2:106353 | relu    | selu   | relu   |           32 |           210 |           195 |           285 | 0.0008 | 0.643928 |                   32 |
# | trainable_func_fc050d32 | TERMINATED | 172.28.0.2:106404 | relu    | selu   | relu   |           32 |           300 |           195 |           330 | 0.0009 | 0.464753 |                   50 |
# | trainable_func_00ea943e | TERMINATED | 172.28.0.2:106416 | relu    | selu   | relu   |           32 |           300 |           195 |           330 | 0.0009 | 0.53021  |                   50 |
# | trainable_func_07977752 | TERMINATED | 172.28.0.2:106353 | relu    | selu   | selu   |           32 |           195 |           285 |           210 | 0.001  | 0.582107 |                   16 |
# | trainable_func_2802062e | TERMINATED | 172.28.0.2:106353 | relu    | selu   | selu   |           32 |           180 |           285 |           195 | 0.001  | 0.595152 |                    4 |
# | trainable_func_3dbcb306 | TERMINATED | 172.28.0.2:106353 | relu    | selu   | selu   |           32 |           165 |           300 |           330 | 0.0009 | 0.551696 |                   16 |
# | trainable_func_431ab6f4 | TERMINATED | 172.28.0.2:106404 | relu    | selu   | selu   |            8 |           300 |           225 |           255 | 0.0009 | 0.554695 |                   32 |
# | trainable_func_4bed7ab4 | TERMINATED | 172.28.0.2:106416 | relu    | selu   | relu   |            8 |           300 |           225 |           330 | 0.0009 | 0.955265 |                    4 |
# | trainable_func_526b67b6 | TERMINATED | 172.28.0.2:106353 | tanh    | relu   | relu   |           16 |           300 |           225 |           330 | 0.0006 | 0.629505 |                    4 |
# | trainable_func_5a7e2e52 | TERMINATED | 172.28.0.2:106353 | tanh    | relu   | relu   |           16 |           300 |           225 |           210 | 0.0006 | 0.58748  |                   32 |
# | trainable_func_64be0f72 | TERMINATED | 172.28.0.2:106416 | relu    | selu   | selu   |           32 |           300 |           180 |           255 | 0.001  | 0.577194 |                    8 |
# | trainable_func_667cf79c | TERMINATED | 172.28.0.2:106352 | relu    | selu   | selu   |           32 |           285 |           180 |           300 | 0.001  | 0.663737 |                    4 |
# | trainable_func_6faaade6 | TERMINATED | 172.28.0.2:106416 | relu    | selu   | selu   |           32 |           285 |           210 |           300 | 0.001  | 0.652981 |                    8 |
# | trainable_func_70a1c59a | TERMINATED | 172.28.0.2:106352 | relu    | selu   | selu   |           32 |           225 |           210 |           300 | 0.0008 | 0.608949 |                    4 |
# | trainable_func_74bdf7fc | TERMINATED | 172.28.0.2:106352 | relu    | relu   | selu   |           16 |           225 |           210 |           240 | 0.0008 | 0.63911  |                    4 |
# | trainable_func_79fba2be | TERMINATED | 172.28.0.2:106416 | relu    | relu   | selu   |           16 |           255 |           240 |           270 | 0.0009 | 0.57607  |                   16 |
# | trainable_func_7b39375e | TERMINATED | 172.28.0.2:106352 | selu    | relu   | selu   |           16 |           255 |           255 |           270 | 0.0009 | 0.650751 |                    4 |
# | trainable_func_827c8fb6 | TERMINATED | 172.28.0.2:106352 | selu    | tanh   | relu   |           64 |           255 |           315 |           285 | 0.001  | 0.658926 |                    4 |
# | trainable_func_8c5ce8b4 | TERMINATED | 172.28.0.2:106352 | relu    | tanh   | relu   |           64 |           270 |           315 |           285 | 0.001  | 0.554983 |                    8 |
# | trainable_func_9022374c | TERMINATED | 172.28.0.2:106352 | relu    | selu   | tanh   |           32 |           270 |           240 |           210 | 0.0008 | 0.537596 |                    8 |
# | trainable_func_97ab8540 | TERMINATED | 172.28.0.2:106352 | relu    | selu   | relu   |           32 |           240 |           150 |           315 | 0.0009 | 0.521479 |                   32 |
# | trainable_func_a1d1d362 | TERMINATED | 172.28.0.2:106416 | relu    | selu   | relu   |           32 |           240 |           150 |           315 | 0.0009 | 0.841232 |                    8 |
# | trainable_func_a4a5ad5c | TERMINATED | 172.28.0.2:106416 | relu    | selu   | relu   |           32 |           195 |           150 |           240 | 0.0009 | 0.574517 |                   16 |
# | trainable_func_aea5ff46 | TERMINATED | 172.28.0.2:106353 | relu    | selu   | relu   |           32 |           285 |           165 |           315 | 0.0007 | 0.631699 |                    4 |
# | trainable_func_c01e9094 | TERMINATED | 172.28.0.2:106416 | relu    | selu   | relu   |           32 |           195 |           165 |           315 | 0.0009 | 0.592412 |                    8 |
# +-------------------------+------------+-------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
#
#
# Best trial config: {'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 32, 'hidden_dim1': 285.0, 'hidden_dim2': 180.0, 'hidden_dim3': 165.0}
# Best trial final validation score: 0.45543732196590253
# Best trial test set score: 0.4547823913411027
