# %% [markdown]
# <a href="https://colab.research.google.com/github/mAbbaspour/Hyperparameter-Optimization/blob/main/asha%20%26%20hyperopt%20without%20pca%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as f
import numpy as np
import math;

# %%
from google.colab import files
uploaded = files.upload()
uploaded2 = files.upload()
# Out:
#      <input type="file" id="files-161c01fc-0786-40b6-9783-1964c01e0d68" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-161c01fc-0786-40b6-9783-1964c01e0d68">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lipo(Lables).csv to lipo(Lables) (1).csv
#      <input type="file" id="files-6c51ad64-e1ce-468a-b2e7-9d3546a3eaf6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6c51ad64-e1ce-468a-b2e7-9d3546a3eaf6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lipo_global_cdf_rdkit.csv to lipo_global_cdf_rdkit (1).csv

# %%
import random
random.seed(1)
import pandas as pd
import io
from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv(io.BytesIO(uploaded2['lipo_global_cdf_rdkit.csv']))
dataY = pd.read_csv(io.BytesIO(uploaded['lipo(Lables).csv']))
print(data[data.isnull().any(axis=1)])
# Out:
#       ('RDKit2DNormalized_calculated', <class 'bool'>)  \
# 1561                                              True
#
#       ('BalabanJ', <class 'numpy.float64'>)  \
# 1561                                  0.895
#
#       ('BertzCT', <class 'numpy.float64'>)  ('Chi0', <class 'numpy.float64'>)  \
# 1561                              0.230752                           0.031331
#
#       ('Chi0n', <class 'numpy.float64'>)  ('Chi0v', <class 'numpy.float64'>)  \
# 1561                            0.032387                            0.061726
#
#       ('Chi1', <class 'numpy.float64'>)  ('Chi1n', <class 'numpy.float64'>)  \
# 1561                           0.050799                            0.045963
#
#       ('Chi1v', <class 'numpy.float64'>)  ('Chi2n', <class 'numpy.float64'>)  \
# 1561                            0.116251                             0.04344
#
#       ...  ('fr_sulfonamd', <class 'numpy.float64'>)  \
# 1561  ...                               1.593061e-17
#
#       ('fr_sulfone', <class 'numpy.float64'>)  \
# 1561                             5.766101e-14
#
#       ('fr_term_acetylene', <class 'numpy.float64'>)  \
# 1561                                    2.957989e-11
#
#       ('fr_tetrazole', <class 'numpy.float64'>)  \
# 1561                                   0.168378
#
#       ('fr_thiazole', <class 'numpy.float64'>)  \
# 1561                                   0.16738
#
#       ('fr_thiocyan', <class 'numpy.float64'>)  \
# 1561                              1.481515e-18
#
#       ('fr_thiophene', <class 'numpy.float64'>)  \
# 1561                               2.324150e-16
#
#       ('fr_unbrch_alkane', <class 'numpy.float64'>)  \
# 1561                                   4.703598e-08
#
#       ('fr_urea', <class 'numpy.float64'>)  ('qed', <class 'numpy.float64'>)
# 1561                              0.166633                          0.542261
#
# [1 rows x 201 columns]

# %%
data = data.drop(1561)
dataY = dataY.drop(1561)

# %%
arrayY = dataY.values
Y = arrayY[0: ,1 ]
array = data.values
X = array[0:,1:]

# %%
X_train, X_test ,Y_train , Y_test  = train_test_split(X, Y ,test_size=0.2)
scaler_data  = preprocessing.MinMaxScaler()
X_train = scaler_data.fit_transform(X_train)
X_test =  scaler_data.transform(X_test)
scaler_labels = preprocessing.MinMaxScaler()
Y_train = scaler_labels.fit_transform(Y_train.reshape(-1, 1))
Y_test = scaler_labels.transform(Y_test.reshape(-1, 1))

# %%
print(X_test.shape)
print(Y_test.shape)
print(X_train.shape)
print(Y_train.shape)
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
# Out:
# (840, 200)
# (840, 1)
# (3359, 200)
# (3359, 1)

# %%
Y_train_new =  Y_train.astype(np.float)
Y_test_new = Y_test.astype(np.float)
print(Y_train_new.shape)
print(Y_test_new.shape)
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
tensor_x_train = torch.tensor(X_train, dtype=torch.float).to(device) 
tensor_x_test = torch.tensor(X_test, dtype=torch.float).to(device) 

tensor_y_train = torch.tensor(Y_train_new , dtype=torch.float).to(device)
tensor_y_test= torch.tensor(Y_test_new, dtype=torch.float).to(device)
# Out:
# (3359, 1)
# (840, 1)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
from torch.utils.data import TensorDataset
trainset = TensorDataset(tensor_x_train, tensor_y_train) 
testset = TensorDataset(tensor_x_test,tensor_y_test)

# %%
# %%capture
try:
    import ray
except:
    # !pip install -U ray
    import ray

# %%
from functools import partial
import numpy as np
import os
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import random_split
from torchsummary import summary

from ray import tune
# a = {"a":tune.quniform(50, 200, 10) , "b": 5}
# print(type(a.get("a")))
from ray.tune import CLIReporter
from ray.tune.schedulers import ASHAScheduler

# %%
def load_data(data_dir=None):
    return trainset, testset

# %%
# # Net().__init__(self , confing) 
#     config = {
#         "act1 ": tune.choice(["relu","tanh","selu"]),
#         "act2" : tune.choice(["relu","tanh","selu"]),
#         "act3" : tune.choice(["relu","tanh","selu"]),
#         "lr": tune.quniform(0.0005, 0.001, 0.0001),
#         "batch_size": tune.choice([8, 16, 32]),
#         "hidden_dim1" : tune.quniform(50, 200, 10),
#         "hidden_dim2" : tune.quniform(50, 200, 10),
#         "hidden_dim3" : tune.quniform(50, 200, 10),
#     }
#   self = { "confing": confing , "hd":}
class Net(nn.Module):
    def __init__(self, config):
        super().__init__()

        self.config = config
        self.hidden_dim1 = int(self.config.get("hidden_dim1", 100))
        self.hidden_dim2 = int(self.config.get("hidden_dim2", 100))
        self.hidden_dim3 = int(self.config.get("hidden_dim3", 100))

        self.act1 = self.config.get("act1", "relu") 
        self.act2 = self.config.get("act2", "relu") 
        self.act3 = self.config.get("act3", "relu")

        self.linear1 = nn.Linear(200, self.hidden_dim1)
        self.linear2 = nn.Linear(self.hidden_dim1, self.hidden_dim2)
        self.linear3 = nn.Linear(self.hidden_dim2, self.hidden_dim3)
        self.linear4 = nn.Linear(self.hidden_dim3, 1)
    
    @staticmethod
    def activation_func(act_str):
        if act_str=="tanh":
            return eval("torch."+act_str)
        elif act_str=="selu" or act_str=="relu":   
            return eval("torch.nn.functional."+act_str)

    def forward(self, x):
        output = self.linear1(x)
        output = self.activation_func(self.act1)(output)
        output = self.linear2(output)
        output = self.activation_func(self.act2)(output)
        output = self.linear3(output)
        output = self.activation_func(self.act3)(output)
        output = self.linear4(output)        
        return output

# %%
model = Net({})

# %%
from prettytable import PrettyTable

def count_parameters(model):
    table = PrettyTable(["Modules", "Parameters"])
    total_params = 0
    for name, parameter in model.named_parameters():
        if not parameter.requires_grad: continue
        param = parameter.numel()
        table.add_row([name, param])
        total_params+=param
    print(table)
    print(f"Total Trainable Params: {total_params}")
    return total_params

# %%
summary(model, (1,tensor_x_train.shape[1]))

count_parameters(model)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1               [-1, 1, 100]          20,100
#             Linear-2               [-1, 1, 100]          10,100
#             Linear-3               [-1, 1, 100]          10,100
#             Linear-4                 [-1, 1, 1]             101
# ================================================================
# Total params: 40,401
# Trainable params: 40,401
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.15
# Estimated Total Size (MB): 0.16
# ----------------------------------------------------------------
# +----------------+------------+
# |    Modules     | Parameters |
# +----------------+------------+
# | linear1.weight |   20000    |
# |  linear1.bias  |    100     |
# | linear2.weight |   10000    |
# |  linear2.bias  |    100     |
# | linear3.weight |   10000    |
# |  linear3.bias  |    100     |
# | linear4.weight |    100     |
# |  linear4.bias  |     1      |
# +----------------+------------+
# Total Trainable Params: 40401
# 40401

# %%
def trainable_func(config, checkpoint_dir=None, data_dir=None, epochs=10):

    net = Net(config)

    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda:0"
        if torch.cuda.device_count() > 1:
            net = nn.DataParallel(net)
    net.to(device)

    '''
    Define a loss function
    '''
    ## Classification
    # criterion = nn.CrossEntropyLoss()

    ## Regression
    criterion = nn.MSELoss(reduction='sum')

    # Define an optimizer 
    optimizer = optim.Adam(net.parameters(), lr=config.get("lr",0.0003))

    if checkpoint_dir:
        model_state, optimizer_state = torch.load(
            os.path.join(checkpoint_dir, "checkpoint"))
        net.load_state_dict(model_state)
        optimizer.load_state_dict(optimizer_state)

    # Load data
    trainset, testset = load_data(data_dir)

    # Split the dataset into training and validation sets
    train_size = int(len(trainset) * 0.8)
    train_subset, val_subset = random_split(trainset, [train_size, len(trainset) - train_size])

    # Define data loaders (which combines a dataset and a sampler, and provides an iterable over the given dataset)
    trainloader = torch.utils.data.DataLoader(
        train_subset,
        batch_size=int(config.get("batch_size",32)),
        shuffle=True,
        num_workers=2)
    valloader = torch.utils.data.DataLoader(
        val_subset,
        batch_size=int(config.get("batch_size",32)),
        shuffle=True,
        num_workers=2)

    for epoch in range(epochs):  # loop over the dataset multiple times
        epoch_train_loss = 0.0
        # epoch_steps = 0
        net.train() # Prepare model for training
        for i, data in enumerate(trainloader):
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            '''
            Compute train loss without scaling to print
            ''' 
            # outputs = torch.tensor(scaler_labels.inverse_transform(outputs.detach().cpu())).to(device)    
            # labels = torch.tensor(scaler_labels.inverse_transform(labels.cpu())).to(device)  
            # loss_train = criterion(outputs, labels) 
            # epoch_train_loss += loss_train.detach().item()
        # print("[%d] loss: %.3f" % (epoch + 1, epoch_train_loss / len(train_subset)))

        # Validation loss
        val_loss = 0.0
        net.eval() # Prepare model for evaluation
        for i, data in enumerate(valloader):
            with torch.no_grad():
                inputs, labels = data
                inputs, labels = inputs.to(device), labels.to(device)

                outputs = net(inputs)

                # Inverse transform of the labels' scaler
                outputs = torch.tensor(scaler_labels.inverse_transform(outputs.detach().cpu())).to(device)    
                labels = torch.tensor(scaler_labels.inverse_transform(labels.cpu())).to(device) 

                loss = criterion(outputs, labels)
                val_loss += loss.cpu().numpy()

        with tune.checkpoint_dir(epoch) as checkpoint_dir:
            path = os.path.join(checkpoint_dir, "checkpoint")
            torch.save((net.state_dict(), optimizer.state_dict()), path)

        tune.report(epoch = epoch, loss=(val_loss / len(val_subset)))
    print("Finished Training")

# %%
def test_score(config, net, device="cpu"):
    trainset, testset = load_data()

    testloader = torch.utils.data.DataLoader(
        testset, batch_size=int(config.get("batch_size",32)), shuffle=False, num_workers=2)
    
    ## Regression
    criterion = nn.MSELoss(reduction='sum')

    # Test loss
    test_loss = 0.0
    net.eval() # Prepare model for evaluation
    for i, data in enumerate(testloader):
        with torch.no_grad():
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = net(inputs)

            # Inverse transform of the labels' scaler
            outputs = torch.tensor(scaler_labels.inverse_transform(outputs.detach().cpu())).to(device)    
            labels = torch.tensor(scaler_labels.inverse_transform(labels.cpu())).to(device) 

            loss = criterion(outputs, labels)
            test_loss += loss.cpu().numpy()

    return test_loss / len(testset)

# %%
ray.shutdown()
ray.init() # Here we use ray.init() to evaluate available_resources for Ray
print(ray.available_resources())
ray.shutdown()  # Restart Ray defensively in case the ray connection is lost. 

# Start Ray runtime with specific resources (not nessesarily all resources)
# You can change this values based on your machine resources)
ray.init(num_cpus=2, num_gpus=0) 

"""Check Ray Tune is working properly (for trainable class)"""
# from ray.tune.utils import validate_save_restore
# validate_save_restore(Trainable)
# validate_save_restore(Trainable, use_object_store=True)
# print("Success!")
""""""
# Out:
# {'CPU': 2.0, 'object_store_memory': 4009374105.0, 'memory': 8018748212.0, 'node:172.28.0.2': 1.0}
# ''

# %%
# %%capture

# %pip install hpbandster ConfigSpace
# !pip install hpbandster ConfigSpace
# !pip install bayesian-optimization

# %%
ray.shutdown()
from ray.tune.schedulers import AsyncHyperBandScheduler
from ray.tune.suggest.hyperopt import HyperOptSearch
from ray.tune.suggest.bayesopt import BayesOptSearch
from ray.tune.suggest.hyperopt import HyperOptSearch
from ray.tune.schedulers import PopulationBasedTraining
def main(num_samples=10, max_num_epochs=10, gpus_per_trial=2):

    # define data directory here if you want to load data from files
    data_dir = os.path.abspath("./data")
    load_data(data_dir)

    # define the search space of hyperparameters
    config = {
        "act1 ": tune.choice(["relu","tanh","selu"]),
        "act2" : tune.choice(["relu","tanh","selu"]),
        "act3" : tune.choice(["relu","tanh","selu"]),
        "lr": tune.quniform(0.0005, 0.001, 0.0001),
        "batch_size": tune.choice([ 8,16, 32 , 64]),
        "hidden_dim1" : tune.quniform(120, 330, 15),
        "hidden_dim2" : tune.quniform(120, 330, 15),
        "hidden_dim3" : tune.quniform(120, 330, 15),
    }

    # Optuna search algorithm
    from ray.tune.suggest.optuna import OptunaSearch 
    from ray.tune.suggest import ConcurrencyLimiter
    search_alg = HyperOptSearch(
    # space=config,
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    n_initial_points=60,
    # gamma = 0.1,
    # random_state_seed=42,
    # points_to_evaluate=[{"max_norm_val": 2.5, 'GNN_Layers': 3, 'dropout': 0.25, 'dropout1': 0.35, 'dropout2': 0.15, 'lr': 0.001, 'hidden_size': 80, 'readout1_out': 150, 'readout2_out': 100, 'batch_size': 64}],
    )
    search_alg = ConcurrencyLimiter(search_alg, max_concurrent=10)

    scheduler = ASHAScheduler(
        metric ="loss",
        mode="min",
        max_t=max_num_epochs,
        reduction_factor=2, 
        grace_period=4,
        brackets=5
        )
    
    reporter = CLIReporter(
        # parameter_columns=["l1", "l2", "lr", "batch_size"],
        metric_columns=["loss", "training_iteration"]
        )
    
    # wrap data loading and training for tuning using `partial` 
    # (note that there exist other methods for this purpose)
    result = tune.run(
        partial(trainable_func, data_dir=data_dir, epochs=max_num_epochs),
        scheduler=scheduler,
        search_alg=search_alg,
        num_samples=num_samples,
        config=config,
        verbose=2,
        checkpoint_score_attr="loss",
        checkpoint_freq=0,
        keep_checkpoints_num=1,
        # checkpoint_at_end=True,
        # reuse_actors=reuse_actors_status,
        progress_reporter=reporter,
        resources_per_trial={"cpu": 0.5, "gpu": gpus_per_trial},
        stop={"training_iteration": max_num_epochs},                
        )

    best_trial = result.get_best_trial("loss", "min", "last")
    print("Best trial config: {}".format(best_trial.config))
    print("Best trial final validation score: {}".format(
        best_trial.last_result["loss"]))

    best_trained_model = Net(best_trial.config)
    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda:0"
        if gpus_per_trial > 1:
            best_trained_model = nn.DataParallel(best_trained_model)
    best_trained_model.to(device)

    best_checkpoint_dir = best_trial.checkpoint.value
    model_state, optimizer_state = torch.load(os.path.join(
        best_checkpoint_dir, "checkpoint"))
    best_trained_model.load_state_dict(model_state)

    test_score_value = test_score(best_trial.config, best_trained_model, device)
    print("Best trial test set score: {}".format(test_score_value))


if __name__ == "__main__":
    # You can change the number of GPUs per trial here:
    main(num_samples=50, max_num_epochs=50, gpus_per_trial=0)
# Out:
# 2022-07-26 12:33:36,857	INFO tune.py:874 -- Initializing Ray automatically.For cluster usage or custom Ray initialization, call `ray.init(...)` before `tune.run`.
# 2022-07-26 12:33:42,039	WARNING callback.py:106 -- The TensorboardX logger cannot be instantiated because either TensorboardX or one of it's dependencies is not installed. Please make sure you have the latest version of TensorboardX installed: `pip install -U tensorboardx`
# == Status ==
# Current time: 2022-07-26 12:33:42 (running for 00:00:00.61)
# Memory usage on this node: 1.4/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 0.5/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 1/50 (1 RUNNING)
#
#
# == Status ==
# Current time: 2022-07-26 12:33:48 (running for 00:00:06.15)
# Memory usage on this node: 1.6/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
#
#
# == Status ==
# Current time: 2022-07-26 12:33:53 (running for 00:00:11.17)
# Memory usage on this node: 1.9/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
#
#
# Trial trainable_func_2ec80538 reported epoch=0,loss=0.7831342837293859,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 315.0, 'hidden_dim3': 270.0}.
# == Status ==
# Current time: 2022-07-26 12:34:00 (running for 00:00:18.60)
# Memory usage on this node: 2.2/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
#
#
# Trial trainable_func_2f261eca reported epoch=0,loss=0.9437307746741455,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 8, 'hidden_dim1': 135.0, 'hidden_dim2': 165.0, 'hidden_dim3': 240.0}.
# Trial trainable_func_2ec80538 reported epoch=2,loss=0.5711917787959628,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 315.0, 'hidden_dim3': 270.0}.
# == Status ==
# Current time: 2022-07-26 12:34:07 (running for 00:00:25.79)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: -0.6353134286737778
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
#
#
# Trial trainable_func_2f5294c8 reported epoch=0,loss=0.7376367840692757,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 285.0, 'hidden_dim2': 255.0, 'hidden_dim3': 270.0}.
# Trial trainable_func_2f261eca reported epoch=1,loss=0.6483188670943127,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 8, 'hidden_dim1': 135.0, 'hidden_dim2': 165.0, 'hidden_dim3': 240.0}.
# Trial trainable_func_2f3ca08c reported epoch=0,loss=0.7838714838420628,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0008, 'batch_size': 8, 'hidden_dim1': 210.0, 'hidden_dim2': 180.0, 'hidden_dim3': 315.0}.
# Trial trainable_func_2ec80538 reported epoch=4,loss=0.5109178507824054,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 315.0, 'hidden_dim3': 270.0}.
# Trial trainable_func_2f5294c8 reported epoch=1,loss=0.6559445952068097,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 285.0, 'hidden_dim2': 255.0, 'hidden_dim3': 270.0}.
# == Status ==
# Current time: 2022-07-26 12:34:14 (running for 00:00:32.11)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: -0.6353134286737778
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
#
#
# Trial trainable_func_2ec80538 reported epoch=6,loss=0.4724138122518336,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 315.0, 'hidden_dim3': 270.0}.
# Trial trainable_func_2f261eca reported epoch=2,loss=0.6456748094587214,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 8, 'hidden_dim1': 135.0, 'hidden_dim2': 165.0, 'hidden_dim3': 240.0}.
# == Status ==
# Current time: 2022-07-26 12:34:19 (running for 00:00:37.17)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: -0.6353134286737778
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
#
#
# Trial trainable_func_2f5294c8 reported epoch=2,loss=0.7001054143738719,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 285.0, 'hidden_dim2': 255.0, 'hidden_dim3': 270.0}.
# Trial trainable_func_2f3ca08c reported epoch=1,loss=0.9214285908452085,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0008, 'batch_size': 8, 'hidden_dim1': 210.0, 'hidden_dim2': 180.0, 'hidden_dim3': 315.0}.
# Trial trainable_func_2ec80538 reported epoch=8,loss=0.46551912239929993,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 315.0, 'hidden_dim3': 270.0}.
# == Status ==
# Current time: 2022-07-26 12:34:25 (running for 00:00:43.35)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: -0.4873034693809778 | Iter 4.000: -0.6353134286737778
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
#
#
# Trial trainable_func_2f5294c8 reported epoch=3,loss=0.6108099185308776,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 285.0, 'hidden_dim2': 255.0, 'hidden_dim3': 270.0}.
# Trial trainable_func_2f261eca reported epoch=3,loss=0.5772416905774187,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 8, 'hidden_dim1': 135.0, 'hidden_dim2': 165.0, 'hidden_dim3': 240.0}.
# Trial trainable_func_2f3ca08c reported epoch=2,loss=0.6590025731863589,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0008, 'batch_size': 8, 'hidden_dim1': 210.0, 'hidden_dim2': 180.0, 'hidden_dim3': 315.0}.
# == Status ==
# Current time: 2022-07-26 12:34:30 (running for 00:00:48.83)
# Memory usage on this node: 2.4/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: -0.4873034693809778 | Iter 4.000: -0.6108099185308776
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
#
#
# Trial trainable_func_2f5294c8 reported epoch=4,loss=0.7505946731395274,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 285.0, 'hidden_dim2': 255.0, 'hidden_dim3': 270.0}.
# Trial trainable_func_2ec80538 reported epoch=10,loss=0.4810173565445523,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 315.0, 'hidden_dim3': 270.0}.
# == Status ==
# Current time: 2022-07-26 12:34:36 (running for 00:00:54.21)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: -0.4873034693809778 | Iter 4.000: -0.6108099185308776
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
#
#
# Trial trainable_func_2f261eca reported epoch=4,loss=0.5628628373240383,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 8, 'hidden_dim1': 135.0, 'hidden_dim2': 165.0, 'hidden_dim3': 240.0}.
# Trial trainable_func_2f5294c8 reported epoch=5,loss=0.5475883223589656,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 285.0, 'hidden_dim2': 255.0, 'hidden_dim3': 270.0}.
# Trial trainable_func_2ec80538 reported epoch=12,loss=0.4848872767853334,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 315.0, 'hidden_dim3': 270.0}.
# Trial trainable_func_2f3ca08c reported epoch=3,loss=0.6447289871545604,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0008, 'batch_size': 8, 'hidden_dim1': 210.0, 'hidden_dim2': 180.0, 'hidden_dim3': 315.0}. This trial completed.
# Trial trainable_func_2f6b0814 reported epoch=0,loss=0.9265195296010147,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 300.0, 'hidden_dim3': 120.0}.
# == Status ==
# Current time: 2022-07-26 12:34:41 (running for 00:00:59.30)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=1
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: -0.4873034693809778 | Iter 4.000: -0.6230616736023278
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 6/50 (1 PENDING, 4 RUNNING, 1 TERMINATED)
#
#
# Trial trainable_func_2f261eca reported epoch=5,loss=0.5760403350165559,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 8, 'hidden_dim1': 135.0, 'hidden_dim2': 165.0, 'hidden_dim3': 240.0}.
# Trial trainable_func_2ec80538 reported epoch=14,loss=0.5537095513597509,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 315.0, 'hidden_dim3': 270.0}.
# == Status ==
# Current time: 2022-07-26 12:34:47 (running for 00:01:05.02)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=1
# Bracket: Iter 32.000: None | Iter 16.000: -0.5332483226829887 | Iter 8.000: -0.4873034693809778 | Iter 4.000: -0.6230616736023278
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 6/50 (1 PENDING, 4 RUNNING, 1 TERMINATED)
#
#
# Trial trainable_func_2f5294c8 reported epoch=7,loss=0.565263931788083,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 285.0, 'hidden_dim2': 255.0, 'hidden_dim3': 270.0}. This trial completed.
# Trial trainable_func_2f6b0814 reported epoch=3,loss=0.6305400896224171,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 300.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_50dae0d2 reported epoch=0,loss=1.2515641693722621,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0008, 'batch_size': 64, 'hidden_dim1': 210.0, 'hidden_dim2': 120.0, 'hidden_dim3': 210.0}.
# Trial trainable_func_2f261eca reported epoch=6,loss=0.5683674159947765,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 8, 'hidden_dim1': 135.0, 'hidden_dim2': 165.0, 'hidden_dim3': 240.0}.
# Trial trainable_func_2ec80538 reported epoch=16,loss=0.47580465143927175,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 315.0, 'hidden_dim3': 270.0}.
# Trial trainable_func_50dae0d2 reported epoch=3,loss=0.6433181601394811,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0008, 'batch_size': 64, 'hidden_dim1': 210.0, 'hidden_dim2': 120.0, 'hidden_dim3': 210.0}. This trial completed.
# == Status ==
# Current time: 2022-07-26 12:34:52 (running for 00:01:10.54)
# Memory usage on this node: 2.4/12.7 GiB
# Using AsyncHyperBand: num_stopped=3
# Bracket: Iter 32.000: None | Iter 16.000: -0.5332483226829887 | Iter 8.000: -0.5262837005845304 | Iter 4.000: -0.6353134286737778
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 8/50 (1 PENDING, 4 RUNNING, 3 TERMINATED)
#
#
# Trial trainable_func_2f6b0814 reported epoch=6,loss=0.596292725594891,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 300.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_2ec80538 reported epoch=18,loss=0.5292484065852003,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 315.0, 'hidden_dim3': 270.0}.
# Trial trainable_func_2f261eca reported epoch=7,loss=0.5321875375990697,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 8, 'hidden_dim1': 135.0, 'hidden_dim2': 165.0, 'hidden_dim3': 240.0}. This trial completed.
# Trial trainable_func_585edaf2 reported epoch=0,loss=1.2464863972900548,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0006000000000000001, 'batch_size': 64, 'hidden_dim1': 180.0, 'hidden_dim2': 225.0, 'hidden_dim3': 165.0}.
# Trial trainable_func_55906868 reported epoch=0,loss=0.8174828204543506,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 8, 'hidden_dim1': 180.0, 'hidden_dim2': 225.0, 'hidden_dim3': 165.0}.
# == Status ==
# Current time: 2022-07-26 12:34:58 (running for 00:01:16.15)
# Memory usage on this node: 2.4/12.7 GiB
# Using AsyncHyperBand: num_stopped=4
# Bracket: Iter 32.000: None | Iter 16.000: -0.5332483226829887 | Iter 8.000: -0.5321875375990697 | Iter 4.000: -0.6353134286737778
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: -0.5548704758277297
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 9/50 (1 PENDING, 4 RUNNING, 4 TERMINATED)
#
#
# Trial trainable_func_2ec80538 reported epoch=20,loss=0.5099513994331831,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 315.0, 'hidden_dim3': 270.0}.
# Trial trainable_func_2f6b0814 reported epoch=9,loss=0.716367535724529,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 300.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_585edaf2 reported epoch=4,loss=0.6301881629927758,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0006000000000000001, 'batch_size': 64, 'hidden_dim1': 180.0, 'hidden_dim2': 225.0, 'hidden_dim3': 165.0}.
# == Status ==
# Current time: 2022-07-26 12:35:03 (running for 00:01:21.48)
# Memory usage on this node: 2.4/12.7 GiB
# Using AsyncHyperBand: num_stopped=4
# Bracket: Iter 32.000: None | Iter 16.000: -0.5332483226829887 | Iter 8.000: -0.5321875375990697 | Iter 4.000: -0.6353134286737778
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: -0.5548704758277297
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 9/50 (1 PENDING, 4 RUNNING, 4 TERMINATED)
#
#
# Trial trainable_func_55906868 reported epoch=1,loss=0.7171054883981357,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 8, 'hidden_dim1': 180.0, 'hidden_dim2': 225.0, 'hidden_dim3': 165.0}.
# Trial trainable_func_585edaf2 reported epoch=7,loss=0.5670552129052421,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0006000000000000001, 'batch_size': 64, 'hidden_dim1': 180.0, 'hidden_dim2': 225.0, 'hidden_dim3': 165.0}. This trial completed.
# Trial trainable_func_2ec80538 reported epoch=22,loss=0.5182538005340419,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 315.0, 'hidden_dim3': 270.0}.
# Trial trainable_func_2f6b0814 reported epoch=11,loss=0.5888802985044589,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 300.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_5abe9224 reported epoch=0,loss=0.9568676755276373,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 150.0, 'hidden_dim3': 135.0}.
# == Status ==
# Current time: 2022-07-26 12:35:09 (running for 00:01:27.19)
# Memory usage on this node: 2.4/12.7 GiB
# Using AsyncHyperBand: num_stopped=5
# Bracket: Iter 32.000: None | Iter 16.000: -0.5332483226829887 | Iter 8.000: -0.5321875375990697 | Iter 4.000: -0.6353134286737778
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: -0.5609628443664859
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 10/50 (1 PENDING, 4 RUNNING, 5 TERMINATED)
#
#
# Trial trainable_func_55906868 reported epoch=2,loss=0.6933574297870448,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 8, 'hidden_dim1': 180.0, 'hidden_dim2': 225.0, 'hidden_dim3': 165.0}.
# Trial trainable_func_2ec80538 reported epoch=24,loss=0.49043492604866373,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 315.0, 'hidden_dim3': 270.0}.
# Trial trainable_func_2f6b0814 reported epoch=13,loss=0.5446264899128967,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 300.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_5abe9224 reported epoch=3,loss=0.662921325452517,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 150.0, 'hidden_dim3': 135.0}.
# == Status ==
# Current time: 2022-07-26 12:35:14 (running for 00:01:32.41)
# Memory usage on this node: 2.4/12.7 GiB
# Using AsyncHyperBand: num_stopped=5
# Bracket: Iter 32.000: None | Iter 16.000: -0.5332483226829887 | Iter 8.000: -0.5321875375990697 | Iter 4.000: -0.6353134286737778
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: -0.5609628443664859
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 10/50 (1 PENDING, 4 RUNNING, 5 TERMINATED)
#
#
# Trial trainable_func_2ec80538 reported epoch=26,loss=0.4755364126538348,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 315.0, 'hidden_dim3': 270.0}.
# Trial trainable_func_2f6b0814 reported epoch=16,loss=0.5471810944502686,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 300.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_5abe9224 reported epoch=6,loss=0.5704111165627014,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 150.0, 'hidden_dim3': 135.0}.
# == Status ==
# Current time: 2022-07-26 12:35:19 (running for 00:01:37.58)
# Memory usage on this node: 2.4/12.7 GiB
# Using AsyncHyperBand: num_stopped=5
# Bracket: Iter 32.000: None | Iter 16.000: -0.5332483226829887 | Iter 8.000: -0.5321875375990697 | Iter 4.000: -0.6353134286737778
# Bracket: Iter 32.000: None | Iter 16.000: -0.587868111255189 | Iter 8.000: -0.5609628443664859
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 10/50 (1 PENDING, 4 RUNNING, 5 TERMINATED)
#
#
# Trial trainable_func_55906868 reported epoch=3,loss=0.6591029770815909,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.001, 'batch_size': 8, 'hidden_dim1': 180.0, 'hidden_dim2': 225.0, 'hidden_dim3': 165.0}. This trial completed.
# Trial trainable_func_5abe9224 reported epoch=7,loss=0.5989193772919159,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 150.0, 'hidden_dim3': 135.0}. This trial completed.
# Trial trainable_func_61077560 reported epoch=0,loss=0.8397439176395005,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 315.0, 'hidden_dim2': 210.0, 'hidden_dim3': 150.0}.
# Trial trainable_func_2ec80538 reported epoch=28,loss=0.47549669603081446,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 315.0, 'hidden_dim3': 270.0}.
# Trial trainable_func_68f66eb6 reported epoch=0,loss=0.832550848937968,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0009000000000000001, 'batch_size': 32, 'hidden_dim1': 315.0, 'hidden_dim2': 195.0, 'hidden_dim3': 210.0}.
# Trial trainable_func_2f6b0814 reported epoch=18,loss=0.5941046581374916,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 300.0, 'hidden_dim3': 120.0}.
# == Status ==
# Current time: 2022-07-26 12:35:26 (running for 00:01:44.18)
# Memory usage on this node: 2.4/12.7 GiB
# Using AsyncHyperBand: num_stopped=7
# Bracket: Iter 32.000: None | Iter 16.000: -0.5332483226829887 | Iter 8.000: -0.5321875375990697 | Iter 4.000: -0.6393157944066294
# Bracket: Iter 32.000: None | Iter 16.000: -0.587868111255189 | Iter 8.000: -0.5670552129052421
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 12/50 (1 PENDING, 4 RUNNING, 7 TERMINATED)
#
#
# Trial trainable_func_2ec80538 reported epoch=30,loss=0.4660002782283066,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 315.0, 'hidden_dim3': 270.0}.
# Trial trainable_func_68f66eb6 reported epoch=3,loss=0.5887603256069621,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0009000000000000001, 'batch_size': 32, 'hidden_dim1': 315.0, 'hidden_dim2': 195.0, 'hidden_dim3': 210.0}.
# Trial trainable_func_2f6b0814 reported epoch=21,loss=0.5602166366867579,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 300.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_61077560 reported epoch=2,loss=0.8770309449067304,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 315.0, 'hidden_dim2': 210.0, 'hidden_dim3': 150.0}.
# == Status ==
# Current time: 2022-07-26 12:35:31 (running for 00:01:49.44)
# Memory usage on this node: 2.4/12.7 GiB
# Using AsyncHyperBand: num_stopped=7
# Bracket: Iter 32.000: None | Iter 16.000: -0.5332483226829887 | Iter 8.000: -0.5321875375990697 | Iter 4.000: -0.6393157944066294
# Bracket: Iter 32.000: None | Iter 16.000: -0.587868111255189 | Iter 8.000: -0.5670552129052421
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 12/50 (1 PENDING, 4 RUNNING, 7 TERMINATED)
#
#
# Trial trainable_func_2ec80538 reported epoch=32,loss=0.4724762876857623,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 315.0, 'hidden_dim3': 270.0}.
# Trial trainable_func_68f66eb6 reported epoch=6,loss=0.6165410495553191,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0009000000000000001, 'batch_size': 32, 'hidden_dim1': 315.0, 'hidden_dim2': 195.0, 'hidden_dim3': 210.0}.
# == Status ==
# Current time: 2022-07-26 12:35:37 (running for 00:01:55.87)
# Memory usage on this node: 2.4/12.7 GiB
# Using AsyncHyperBand: num_stopped=7
# Bracket: Iter 32.000: -0.5068083390109733 | Iter 16.000: -0.5332483226829887 | Iter 8.000: -0.5321875375990697 | Iter 4.000: -0.6353134286737778
# Bracket: Iter 32.000: None | Iter 16.000: -0.587868111255189 | Iter 8.000: -0.5670552129052421
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 12/50 (1 PENDING, 4 RUNNING, 7 TERMINATED)
#
#
# Trial trainable_func_2f6b0814 reported epoch=24,loss=0.5695416478615082,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 300.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_61077560 reported epoch=4,loss=0.6279460831155107,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 315.0, 'hidden_dim2': 210.0, 'hidden_dim3': 150.0}.
# Trial trainable_func_2ec80538 reported epoch=34,loss=0.4567501288789626,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 315.0, 'hidden_dim3': 270.0}.
# == Status ==
# Current time: 2022-07-26 12:35:43 (running for 00:02:01.06)
# Memory usage on this node: 2.4/12.7 GiB
# Using AsyncHyperBand: num_stopped=7
# Bracket: Iter 32.000: -0.5068083390109733 | Iter 16.000: -0.5332483226829887 | Iter 8.000: -0.5321875375990697 | Iter 4.000: -0.6353134286737778
# Bracket: Iter 32.000: None | Iter 16.000: -0.587868111255189 | Iter 8.000: -0.5609628443664859
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 12/50 (1 PENDING, 4 RUNNING, 7 TERMINATED)
#
#
# Trial trainable_func_68f66eb6 reported epoch=9,loss=0.6347165661973092,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0009000000000000001, 'batch_size': 32, 'hidden_dim1': 315.0, 'hidden_dim2': 195.0, 'hidden_dim3': 210.0}.
# Trial trainable_func_2f6b0814 reported epoch=27,loss=0.569888325346219,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 300.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_2ec80538 reported epoch=36,loss=0.45565686277160705,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 315.0, 'hidden_dim3': 270.0}.
# Trial trainable_func_61077560 reported epoch=6,loss=0.6141396714589453,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 315.0, 'hidden_dim2': 210.0, 'hidden_dim3': 150.0}.
# == Status ==
# Current time: 2022-07-26 12:35:48 (running for 00:02:06.64)
# Memory usage on this node: 2.4/12.7 GiB
# Using AsyncHyperBand: num_stopped=7
# Bracket: Iter 32.000: -0.5068083390109733 | Iter 16.000: -0.5332483226829887 | Iter 8.000: -0.5321875375990697 | Iter 4.000: -0.6353134286737778
# Bracket: Iter 32.000: None | Iter 16.000: -0.587868111255189 | Iter 8.000: -0.5609628443664859
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 12/50 (1 PENDING, 4 RUNNING, 7 TERMINATED)
#
#
# Trial trainable_func_68f66eb6 reported epoch=11,loss=0.5461987301804988,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0009000000000000001, 'batch_size': 32, 'hidden_dim1': 315.0, 'hidden_dim2': 195.0, 'hidden_dim3': 210.0}.
# Trial trainable_func_2f6b0814 reported epoch=30,loss=0.5624717414786371,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 300.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_2ec80538 reported epoch=38,loss=0.5058724372871906,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 315.0, 'hidden_dim3': 270.0}.
# Trial trainable_func_61077560 reported epoch=7,loss=0.5907988907781695,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 315.0, 'hidden_dim2': 210.0, 'hidden_dim3': 150.0}. This trial completed.
# == Status ==
# Current time: 2022-07-26 12:35:54 (running for 00:02:12.27)
# Memory usage on this node: 2.4/12.7 GiB
# Using AsyncHyperBand: num_stopped=8
# Bracket: Iter 32.000: -0.5068083390109733 | Iter 16.000: -0.5332483226829887 | Iter 8.000: -0.5487257346935763 | Iter 4.000: -0.6353134286737778
# Bracket: Iter 32.000: -0.5554640525361011 | Iter 16.000: -0.587868111255189 | Iter 8.000: -0.5609628443664859
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 13/50 (1 PENDING, 4 RUNNING, 8 TERMINATED)
#
#
# Trial trainable_func_6a27d13a reported epoch=0,loss=0.7564750440712578,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 225.0, 'hidden_dim3': 285.0}.
# Trial trainable_func_68f66eb6 reported epoch=13,loss=0.7302218449197009,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0009000000000000001, 'batch_size': 32, 'hidden_dim1': 315.0, 'hidden_dim2': 195.0, 'hidden_dim3': 210.0}.
# Trial trainable_func_2f6b0814 reported epoch=33,loss=0.5582652472422596,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 300.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_2ec80538 reported epoch=40,loss=0.4583503116935925,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 315.0, 'hidden_dim3': 270.0}.
# == Status ==
# Current time: 2022-07-26 12:36:00 (running for 00:02:17.99)
# Memory usage on this node: 2.4/12.7 GiB
# Using AsyncHyperBand: num_stopped=8
# Bracket: Iter 32.000: -0.5068083390109733 | Iter 16.000: -0.5332483226829887 | Iter 8.000: -0.5487257346935763 | Iter 4.000: -0.6353134286737778
# Bracket: Iter 32.000: -0.5554640525361011 | Iter 16.000: -0.587868111255189 | Iter 8.000: -0.5609628443664859
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 13/50 (1 PENDING, 4 RUNNING, 8 TERMINATED)
#
#
# Trial trainable_func_68f66eb6 reported epoch=15,loss=0.551787018841112,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0009000000000000001, 'batch_size': 32, 'hidden_dim1': 315.0, 'hidden_dim2': 195.0, 'hidden_dim3': 210.0}.
# Trial trainable_func_6a27d13a reported epoch=3,loss=0.6487350440930398,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 225.0, 'hidden_dim3': 285.0}.
# Trial trainable_func_2ec80538 reported epoch=42,loss=0.4772557613247581,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 315.0, 'hidden_dim3': 270.0}.
# Trial trainable_func_2f6b0814 reported epoch=36,loss=0.5498993766298909,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 300.0, 'hidden_dim3': 120.0}.
# == Status ==
# Current time: 2022-07-26 12:36:05 (running for 00:02:23.90)
# Memory usage on this node: 2.4/12.7 GiB
# Using AsyncHyperBand: num_stopped=8
# Bracket: Iter 32.000: -0.5068083390109733 | Iter 16.000: -0.5332483226829887 | Iter 8.000: -0.5487257346935763 | Iter 4.000: -0.6353134286737778
# Bracket: Iter 32.000: -0.5554640525361011 | Iter 16.000: -0.5698275650481506 | Iter 8.000: -0.5609628443664859
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 13/50 (1 PENDING, 4 RUNNING, 8 TERMINATED)
#
#
# Trial trainable_func_68f66eb6 reported epoch=17,loss=0.5571120869945725,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0009000000000000001, 'batch_size': 32, 'hidden_dim1': 315.0, 'hidden_dim2': 195.0, 'hidden_dim3': 210.0}.
# Trial trainable_func_6a27d13a reported epoch=6,loss=0.5540793629290502,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 225.0, 'hidden_dim3': 285.0}.
# Trial trainable_func_2ec80538 reported epoch=44,loss=0.449029530431349,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 315.0, 'hidden_dim3': 270.0}.
# == Status ==
# Current time: 2022-07-26 12:36:11 (running for 00:02:29.35)
# Memory usage on this node: 2.4/12.7 GiB
# Using AsyncHyperBand: num_stopped=8
# Bracket: Iter 32.000: -0.5068083390109733 | Iter 16.000: -0.5332483226829887 | Iter 8.000: -0.5487257346935763 | Iter 4.000: -0.6353134286737778
# Bracket: Iter 32.000: -0.5554640525361011 | Iter 16.000: -0.5698275650481506 | Iter 8.000: -0.5580800583479697
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 13/50 (1 PENDING, 4 RUNNING, 8 TERMINATED)
#
#
# Trial trainable_func_68f66eb6 reported epoch=19,loss=0.5214568166244068,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0009000000000000001, 'batch_size': 32, 'hidden_dim1': 315.0, 'hidden_dim2': 195.0, 'hidden_dim3': 210.0}.
# Trial trainable_func_2f6b0814 reported epoch=39,loss=0.5718707989221796,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 300.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_2ec80538 reported epoch=46,loss=0.4827991501225965,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 315.0, 'hidden_dim3': 270.0}.
# Trial trainable_func_6a27d13a reported epoch=9,loss=0.5861884893243549,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 225.0, 'hidden_dim3': 285.0}.
# Trial trainable_func_68f66eb6 reported epoch=21,loss=0.5288160714083822,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0009000000000000001, 'batch_size': 32, 'hidden_dim1': 315.0, 'hidden_dim2': 195.0, 'hidden_dim3': 210.0}.
# == Status ==
# Current time: 2022-07-26 12:36:16 (running for 00:02:34.73)
# Memory usage on this node: 2.4/12.7 GiB
# Using AsyncHyperBand: num_stopped=8
# Bracket: Iter 32.000: -0.5068083390109733 | Iter 16.000: -0.5332483226829887 | Iter 8.000: -0.5487257346935763 | Iter 4.000: -0.6353134286737778
# Bracket: Iter 32.000: -0.5554640525361011 | Iter 16.000: -0.5698275650481506 | Iter 8.000: -0.5580800583479697
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 13/50 (1 PENDING, 4 RUNNING, 8 TERMINATED)
#
#
# Trial trainable_func_2f6b0814 reported epoch=42,loss=0.5964752341302684,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 300.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_6a27d13a reported epoch=11,loss=0.5849369926717668,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 225.0, 'hidden_dim3': 285.0}.
# Trial trainable_func_2ec80538 reported epoch=48,loss=0.4826694092957438,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 315.0, 'hidden_dim3': 270.0}.
# == Status ==
# Current time: 2022-07-26 12:36:22 (running for 00:02:40.70)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=8
# Bracket: Iter 32.000: -0.5068083390109733 | Iter 16.000: -0.5332483226829887 | Iter 8.000: -0.5487257346935763 | Iter 4.000: -0.6353134286737778
# Bracket: Iter 32.000: -0.5554640525361011 | Iter 16.000: -0.5698275650481506 | Iter 8.000: -0.5580800583479697
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 13/50 (1 PENDING, 4 RUNNING, 8 TERMINATED)
#
#
# Trial trainable_func_68f66eb6 reported epoch=23,loss=0.5356851620572407,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0009000000000000001, 'batch_size': 32, 'hidden_dim1': 315.0, 'hidden_dim2': 195.0, 'hidden_dim3': 210.0}.
# Trial trainable_func_2ec80538 reported epoch=49,loss=0.47691555793344215,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 315.0, 'hidden_dim3': 270.0}. This trial completed.
# Trial trainable_func_6a27d13a reported epoch=13,loss=0.5540239111706299,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 225.0, 'hidden_dim3': 285.0}.
# Trial trainable_func_2f6b0814 reported epoch=44,loss=0.5791566203199269,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 240.0, 'hidden_dim2': 300.0, 'hidden_dim3': 120.0}.
# Trial trainable_func_68f66eb6 reported epoch=25,loss=0.556480250267209,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0009000000000000001, 'batch_size': 32, 'hidden_dim1': 315.0, 'hidden_dim2': 195.0, 'hidden_dim3': 210.0}.
# == Status ==
# Current time: 2022-07-26 12:36:29 (running for 00:02:47.01)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=8
# Bracket: Iter 32.000: -0.5068083390109733 | Iter 16.000: -0.5332483226829887 | Iter 8.000: -0.5487257346935763 | Iter 4.000: -0.6353134286737778
# Bracket: Iter 32.000: -0.5554640525361011 | Iter 16.000: -0.5698275650481506 | Iter 8.000: -0.5580800583479697
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 14/50 (1 PENDING, 4 RUNNING, 9 TERMINATED)
#
#
# Trial trainable_func_7cd3d748 reported epoch=0,loss=0.7301391332837709,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0009000000000000001, 'batch_size': 16, 'hidden_dim1': 210.0, 'hidden_dim2': 285.0, 'hidden_dim3': 285.0}.
# Trial trainable_func_6a27d13a reported epoch=15,loss=0.5715144367470514,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 32, 'hidden_dim1': 255.0, 'hidden_dim2': 225.0, 'hidden_dim3': 285.0}. This trial completed.
# Trial trainable_func_90931866 reported epoch=0,loss=0.8699842254811316,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0007, 'batch_size': 32, 'hidden_dim1': 210.0, 'hidden_dim2': 180.0, 'hidden_dim3': 225.0}.
# == Status ==
# Current time: 2022-07-26 12:36:34 (running for 00:02:52.18)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=9
# Bracket: Iter 32.000: -0.5068083390109733 | Iter 16.000: -0.5332483226829887 | Iter 8.000: -0.5487257346935763 | Iter 4.000: -0.6353134286737778
# Bracket: Iter 32.000: -0.5554640525361011 | Iter 16.000: -0.5715144367470514 | Iter 8.000: -0.5580800583479697
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# ...
#
#
# Trial trainable_func_78881806 reported epoch=36,loss=0.5060022542973434,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 240.0, 'hidden_dim2': 180.0, 'hidden_dim3': 300.0}.
# Trial trainable_func_5cf4ce4a reported epoch=45,loss=0.5098823750900613,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'relu', 'act3': 'relu', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 180.0, 'hidden_dim2': 240.0, 'hidden_dim3': 270.0}.
# == Status ==
# Current time: 2022-07-26 12:44:34 (running for 00:10:52.95)
# Memory usage on this node: 1.9/12.7 GiB
# Using AsyncHyperBand: num_stopped=42
# Bracket: Iter 32.000: -0.5448108445658093 | Iter 16.000: -0.5332483226829887 | Iter 8.000: -0.5528896388546165 | Iter 4.000: -0.6353134286737778
# Bracket: Iter 32.000: -0.5327476432790468 | Iter 16.000: -0.5715144367470514 | Iter 8.000: -0.5800515541315532
# Bracket: Iter 32.000: -0.5225415472953849 | Iter 16.000: -0.5046486592113745
# Bracket: Iter 32.000: -0.546802613506002
# Bracket:
# Resources requested: 1.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 50/50 (2 RUNNING, 48 TERMINATED)
#
#
# Trial trainable_func_78881806 reported epoch=39,loss=0.5007147667711629,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 240.0, 'hidden_dim2': 180.0, 'hidden_dim3': 300.0}.
# == Status ==
# Current time: 2022-07-26 12:44:40 (running for 00:10:58.54)
# Memory usage on this node: 1.9/12.7 GiB
# Using AsyncHyperBand: num_stopped=42
# Bracket: Iter 32.000: -0.5448108445658093 | Iter 16.000: -0.5332483226829887 | Iter 8.000: -0.5528896388546165 | Iter 4.000: -0.6353134286737778
# Bracket: Iter 32.000: -0.5327476432790468 | Iter 16.000: -0.5715144367470514 | Iter 8.000: -0.5800515541315532
# Bracket: Iter 32.000: -0.5225415472953849 | Iter 16.000: -0.5046486592113745
# Bracket: Iter 32.000: -0.546802613506002
# Bracket:
# Resources requested: 1.0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 50/50 (2 RUNNING, 48 TERMINATED)
#
#
# Trial trainable_func_5cf4ce4a reported epoch=48,loss=0.47951140493653355,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'relu', 'act3': 'relu', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 180.0, 'hidden_dim2': 240.0, 'hidden_dim3': 270.0}.
# Trial trainable_func_78881806 reported epoch=42,loss=0.5067254178325469,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 240.0, 'hidden_dim2': 180.0, 'hidden_dim3': 300.0}.
# Trial trainable_func_5cf4ce4a reported epoch=49,loss=0.4683026211987932,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'relu', 'act3': 'relu', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 180.0, 'hidden_dim2': 240.0, 'hidden_dim3': 270.0}. This trial completed.
# == Status ==
# Current time: 2022-07-26 12:44:45 (running for 00:11:03.84)
# Memory usage on this node: 1.7/12.7 GiB
# Using AsyncHyperBand: num_stopped=42
# Bracket: Iter 32.000: -0.5448108445658093 | Iter 16.000: -0.5332483226829887 | Iter 8.000: -0.5528896388546165 | Iter 4.000: -0.6353134286737778
# Bracket: Iter 32.000: -0.5327476432790468 | Iter 16.000: -0.5715144367470514 | Iter 8.000: -0.5800515541315532
# Bracket: Iter 32.000: -0.5225415472953849 | Iter 16.000: -0.5046486592113745
# Bracket: Iter 32.000: -0.546802613506002
# Bracket:
# Resources requested: 0.5/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 50/50 (1 RUNNING, 49 TERMINATED)
#
#
# Trial trainable_func_78881806 reported epoch=47,loss=0.5134936052607865,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 240.0, 'hidden_dim2': 180.0, 'hidden_dim3': 300.0}.
# 2022-07-26 12:44:50,398	INFO tune.py:748 -- Total run time: 668.50 seconds (668.21 seconds for the tuning loop).
# Trial trainable_func_78881806 reported epoch=49,loss=0.4965463768512528,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 240.0, 'hidden_dim2': 180.0, 'hidden_dim3': 300.0}. This trial completed.
# == Status ==
# Current time: 2022-07-26 12:44:50 (running for 00:11:08.23)
# Memory usage on this node: 1.7/12.7 GiB
# Using AsyncHyperBand: num_stopped=42
# Bracket: Iter 32.000: -0.5448108445658093 | Iter 16.000: -0.5332483226829887 | Iter 8.000: -0.5528896388546165 | Iter 4.000: -0.6353134286737778
# Bracket: Iter 32.000: -0.5327476432790468 | Iter 16.000: -0.5715144367470514 | Iter 8.000: -0.5800515541315532
# Bracket: Iter 32.000: -0.5225415472953849 | Iter 16.000: -0.5046486592113745
# Bracket: Iter 32.000: -0.546802613506002
# Bracket:
# Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.47 GiB heap, 0.0/3.74 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-26_12-33-42
# Number of trials: 50/50 (50 TERMINATED)
# +-------------------------+------------+-------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# | Trial name              | status     | loc               | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |     loss |   training_iteration |
# |-------------------------+------------+-------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------|
# | trainable_func_2ec80538 | TERMINATED | 172.28.0.2:177786 | relu    | selu   | tanh   |           32 |           255 |           315 |           270 | 0.0006 | 0.476916 |                   50 |
# | trainable_func_2f261eca | TERMINATED | 172.28.0.2:177787 | relu    | tanh   | tanh   |            8 |           135 |           165 |           240 | 0.0006 | 0.532188 |                    8 |
# | trainable_func_2f3ca08c | TERMINATED | 172.28.0.2:177840 | tanh    | selu   | relu   |            8 |           210 |           180 |           315 | 0.0008 | 0.644729 |                    4 |
# | trainable_func_2f5294c8 | TERMINATED | 172.28.0.2:177851 | tanh    | selu   | selu   |           16 |           285 |           255 |           270 | 0.0007 | 0.565264 |                    8 |
# | trainable_func_2f6b0814 | TERMINATED | 172.28.0.2:177840 | relu    | tanh   | relu   |           32 |           240 |           300 |           120 | 0.0006 | 0.568353 |                   50 |
# | trainable_func_50dae0d2 | TERMINATED | 172.28.0.2:177851 | selu    | tanh   | relu   |           64 |           210 |           120 |           210 | 0.0008 | 0.643318 |                    4 |
# | trainable_func_55906868 | TERMINATED | 172.28.0.2:177851 | relu    | selu   | selu   |            8 |           180 |           225 |           165 | 0.001  | 0.659103 |                    4 |
# | trainable_func_585edaf2 | TERMINATED | 172.28.0.2:177787 | relu    | tanh   | relu   |           64 |           180 |           225 |           165 | 0.0006 | 0.567055 |                    8 |
# | trainable_func_5abe9224 | TERMINATED | 172.28.0.2:177787 | tanh    | selu   | tanh   |           32 |           240 |           150 |           135 | 0.0007 | 0.598919 |                    8 |
# | trainable_func_61077560 | TERMINATED | 172.28.0.2:177851 | tanh    | tanh   | tanh   |           16 |           315 |           210 |           150 | 0.0007 | 0.590799 |                    8 |
# | trainable_func_68f66eb6 | TERMINATED | 172.28.0.2:177787 | relu    | selu   | relu   |           32 |           315 |           195 |           210 | 0.0009 | 0.541514 |                   50 |
# | trainable_func_6a27d13a | TERMINATED | 172.28.0.2:177851 | relu    | selu   | tanh   |           32 |           255 |           225 |           285 | 0.0006 | 0.571514 |                   16 |
# | trainable_func_7cd3d748 | TERMINATED | 172.28.0.2:177786 | tanh    | tanh   | relu   |           16 |           210 |           285 |           285 | 0.0009 | 0.642945 |                    4 |
# | trainable_func_90931866 | TERMINATED | 172.28.0.2:177851 | selu    | tanh   | relu   |           32 |           210 |           180 |           225 | 0.0007 | 0.492189 |                   50 |
# | trainable_func_940517e2 | TERMINATED | 172.28.0.2:177840 | selu    | selu   | tanh   |           64 |           300 |           195 |           285 | 0.0009 | 0.582813 |                   32 |
# | trainable_func_98bbc24a | TERMINATED | 172.28.0.2:177786 | relu    | relu   | relu   |           64 |           135 |           195 |           240 | 0.0005 | 0.624287 |                    8 |
# | trainable_func_9a678eb2 | TERMINATED | 172.28.0.2:177786 | tanh    | tanh   | selu   |           16 |           240 |           165 |           135 | 0.0006 | 0.680371 |                    4 |
# | trainable_func_a07200c6 | TERMINATED | 172.28.0.2:177786 | relu    | relu   | tanh   |            8 |           315 |           180 |           240 | 0.001  | 0.679123 |                    4 |
# | trainable_func_a8ce7114 | TERMINATED | 172.28.0.2:177840 | tanh    | relu   | tanh   |           32 |           240 |           255 |           135 | 0.001  | 0.535179 |                    8 |
# | trainable_func_b51bd39e | TERMINATED | 172.28.0.2:177787 | relu    | relu   | selu   |           64 |           150 |           195 |           315 | 0.0005 | 0.617807 |                    8 |
# | trainable_func_b7dc6f80 | TERMINATED | 172.28.0.2:177786 | selu    | tanh   | selu   |           16 |           195 |           225 |           225 | 0.0007 | 0.61559  |                   32 |
# | trainable_func_bbfbf5cc | TERMINATED | 172.28.0.2:177787 | relu    | tanh   | tanh   |            8 |           285 |           180 |           195 | 0.0009 | 0.902557 |                    4 |
# | trainable_func_be5984a6 | TERMINATED | 172.28.0.2:177840 | selu    | tanh   | selu   |            8 |           195 |           285 |           195 | 0.001  | 0.943603 |                    4 |
# | trainable_func_bf45daae | TERMINATED | 172.28.0.2:177787 | selu    | selu   | tanh   |           16 |           135 |           330 |           180 | 0.0006 | 0.877304 |                    4 |
# | trainable_func_cf6fe29e | TERMINATED | 172.28.0.2:177840 | tanh    | relu   | tanh   |           16 |           150 |           180 |           135 | 0.0008 | 0.459073 |                   50 |
# | trainable_func_d0c04634 | TERMINATED | 172.28.0.2:177851 | selu    | selu   | tanh   |            8 |           210 |           270 |           315 | 0.0009 | 0.580052 |                    8 |
# | trainable_func_d45fa582 | TERMINATED | 172.28.0.2:177787 | selu    | selu   | relu   |           32 |           135 |           225 |           225 | 0.0006 | 0.651796 |                    4 |
# | trainable_func_d856226a | TERMINATED | 172.28.0.2:177787 | relu    | tanh   | relu   |           64 |           225 |           195 |           180 | 0.0006 | 0.536615 |                   32 |
# | trainable_func_dd5cbe36 | TERMINATED | 172.28.0.2:177787 | selu    | relu   | tanh   |           16 |           165 |           195 |           315 | 0.0005 | 0.535269 |                    8 |
# | trainable_func_f6957870 | TERMINATED | 172.28.0.2:177851 | relu    | selu   | relu   |           32 |           315 |           285 |           165 | 0.0006 | 0.589605 |                   50 |
# | trainable_func_fca1c1c4 | TERMINATED | 172.28.0.2:177786 | selu    | relu   | selu   |            8 |           315 |           240 |           135 | 0.0008 | 0.597278 |                    8 |
# | trainable_func_074d20a0 | TERMINATED | 172.28.0.2:177787 | tanh    | tanh   | relu   |            8 |           270 |           225 |           150 | 0.0006 | 0.540782 |                    8 |
# | trainable_func_0777346c | TERMINATED | 172.28.0.2:177787 | selu    | tanh   | selu   |            8 |           300 |           285 |           285 | 0.001  | 0.611353 |                    8 |
# | trainable_func_2acfd7ac | TERMINATED | 172.28.0.2:177786 | tanh    | relu   | tanh   |           32 |           120 |           135 |           150 | 0.001  | 0.688579 |                    4 |
# | trainable_func_3251e2fe | TERMINATED | 172.28.0.2:177786 | tanh    | tanh   | relu   |           16 |           255 |           180 |           270 | 0.0009 | 0.563701 |                    8 |
# | trainable_func_36a877d2 | TERMINATED | 172.28.0.2:177840 | selu    | tanh   | relu   |           16 |           255 |           285 |           180 | 0.0005 | 0.549615 |                    8 |
# | trainable_func_39b1e74c | TERMINATED | 172.28.0.2:177851 | relu    | tanh   | tanh   |           16 |           285 |           300 |           330 | 0.0006 | 0.619242 |                    8 |
# | trainable_func_470c1d5e | TERMINATED | 172.28.0.2:177786 | relu    | selu   | selu   |           32 |           135 |           300 |           210 | 0.0009 | 0.623914 |                    8 |
# | trainable_func_48be6e2c | TERMINATED | 172.28.0.2:177840 | selu    | tanh   | selu   |            8 |           315 |           240 |           195 | 0.0007 | 0.80105  |                    4 |
# | trainable_func_4d33281c | TERMINATED | 172.28.0.2:177786 | relu    | selu   | selu   |            8 |           180 |           240 |           315 | 0.0009 | 0.673691 |                    4 |
# | trainable_func_5278fb4e | TERMINATED | 172.28.0.2:177787 | tanh    | tanh   | selu   |           16 |           135 |           225 |           225 | 0.001  | 0.604345 |                   16 |
# | trainable_func_59bc8984 | TERMINATED | 172.28.0.2:177851 | relu    | tanh   | tanh   |           32 |           135 |           195 |           240 | 0.001  | 0.780017 |                    8 |
# | trainable_func_5cf4ce4a | TERMINATED | 172.28.0.2:177840 | selu    | relu   | relu   |           16 |           180 |           240 |           270 | 0.0007 | 0.468303 |                   50 |
# | trainable_func_607d1ec8 | TERMINATED | 172.28.0.2:177786 | selu    | relu   | relu   |           16 |           135 |           315 |           150 | 0.0009 | 0.556164 |                    8 |
# | trainable_func_642675a6 | TERMINATED | 172.28.0.2:177851 | relu    | relu   | relu   |            8 |           300 |           165 |           195 | 0.0007 | 0.662232 |                    4 |
# | trainable_func_66678a1c | TERMINATED | 172.28.0.2:177786 | selu    | selu   | selu   |           64 |           300 |           120 |           285 | 0.0008 | 0.533281 |                   16 |
# | trainable_func_76ef6800 | TERMINATED | 172.28.0.2:177851 | relu    | relu   | relu   |           16 |           150 |           195 |           300 | 0.0009 | 0.563691 |                    8 |
# | trainable_func_78881806 | TERMINATED | 172.28.0.2:177787 | selu    | selu   | tanh   |           16 |           240 |           180 |           300 | 0.0007 | 0.496546 |                   50 |
# | trainable_func_7ca7ff1e | TERMINATED | 172.28.0.2:177786 | tanh    | tanh   | selu   |           16 |           255 |           270 |           315 | 0.0007 | 0.715987 |                    4 |
# | trainable_func_83e1a69a | TERMINATED | 172.28.0.2:177851 | relu    | tanh   | tanh   |           32 |           165 |           195 |           150 | 0.0009 | 0.60163  |                    8 |
# +-------------------------+------------+-------------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
#
#
# Best trial config: {'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0008, 'batch_size': 16, 'hidden_dim1': 150.0, 'hidden_dim2': 180.0, 'hidden_dim3': 135.0}
# Best trial final validation score: 0.4590728623140502
# Best trial test set score: 0.48834464376376696
